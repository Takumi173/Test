# %% [markdown]
# <a href="https://colab.research.google.com/github/Takumi173/Test/blob/main/%E8%96%AC%E5%89%A4%E5%B8%AB%E8%A9%A6%E9%A8%93%E3%82%92%E8%A7%A3%E3%81%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.mhlw.go.jp/content/001455149.pdf
# !wget https://www.mhlw.go.jp/content/001455152.pdf
# !wget https://www.mhlw.go.jp/content/001455159.pdf
# !wget https://www.mhlw.go.jp/content/001455160.pdf
# !wget https://www.mhlw.go.jp/content/001455161.pdf
# !wget https://www.mhlw.go.jp/content/001455162.pdf

# !pip install pymupdf pypdf
# Out:
# --2025-04-16 13:11:00--  https://www.mhlw.go.jp/content/001455149.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1485988 (1.4M) [application/pdf]
# Saving to: ‘001455149.pdf’
#
# 001455149.pdf       100%[===================>]   1.42M  6.69MB/s    in 0.2s
#
# 2025-04-16 13:11:01 (6.69 MB/s) - ‘001455149.pdf’ saved [1485988/1485988]
#
# --2025-04-16 13:11:01--  https://www.mhlw.go.jp/content/001455152.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1992687 (1.9M) [application/pdf]
# Saving to: ‘001455152.pdf’
#
# 001455152.pdf       100%[===================>]   1.90M  4.78MB/s    in 0.4s
#
# 2025-04-16 13:11:02 (4.78 MB/s) - ‘001455152.pdf’ saved [1992687/1992687]
#
# --2025-04-16 13:11:02--  https://www.mhlw.go.jp/content/001455159.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1210424 (1.2M) [application/pdf]
# Saving to: ‘001455159.pdf’
#
# 001455159.pdf       100%[===================>]   1.15M  6.87MB/s    in 0.2s
#
# 2025-04-16 13:11:03 (6.87 MB/s) - ‘001455159.pdf’ saved [1210424/1210424]
#
# --2025-04-16 13:11:03--  https://www.mhlw.go.jp/content/001455160.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2768490 (2.6M) [application/pdf]
# Saving to: ‘001455160.pdf’
#
# 001455160.pdf       100%[===================>]   2.64M  14.5MB/s    in 0.2s
#
# 2025-04-16 13:11:03 (14.5 MB/s) - ‘001455160.pdf’ saved [2768490/2768490]
#
# --2025-04-16 13:11:03--  https://www.mhlw.go.jp/content/001455161.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330607 (1.3M) [application/pdf]
# Saving to: ‘001455161.pdf’
#
# 001455161.pdf       100%[===================>]   1.27M  8.14MB/s    in 0.2s
#
# 2025-04-16 13:11:04 (8.14 MB/s) - ‘001455161.pdf’ saved [1330607/1330607]
#
# --2025-04-16 13:11:04--  https://www.mhlw.go.jp/content/001455162.pdf
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 23.223.173.47, 2600:1407:1800:48f::3194, 2600:1407:1800:486::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|23.223.173.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1695881 (1.6M) [application/pdf]
# Saving to: ‘001455162.pdf’
#
# 001455162.pdf       100%[===================>]   1.62M  4.84MB/s    in 0.3s
#
# 2025-04-16 13:11:04 (4.84 MB/s) - ‘001455162.pdf’ saved [1695881/1695881]
#
# Collecting pymupdf
#   Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 28.0 MB/s eta 0:00:00
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 19.6 MB/s eta 0:00:00
# Installing collected packages: pypdf, pymupdf
# Successfully installed pymupdf-1.25.5 pypdf-5.4.0

# %%
from pypdf import PdfReader, PdfWriter

def split_pdf_pages(input_pdf_path, split_page):
    reader = PdfReader(input_pdf_path)
    writer = PdfWriter()

    output_filename = input_pdf_path.split(".")[0]

    start_index = 0
    end_index = len(reader.pages)


    # 前半ページを作成
    for i in range(start_index, split_page):
        writer.add_page(reader.pages[i])

    # 新しいPDFファイルとして保存
    with open(output_filename+"_1.pdf", "wb") as output_file:
        writer.write(output_file)


    writer = PdfWriter()

    # 後半ページを作成
    for i in range(split_page, end_index):
        writer.add_page(reader.pages[i])

    # 新しいPDFファイルとして保存
    with open(output_filename+"_2.pdf", "wb") as output_file:
        writer.write(output_file)


    print(f"'{output_filename}_1.pdf' と '{output_filename}_2.pdf' に分割しました 。")


split_pdf_pages("001455152.pdf", 26)
split_pdf_pages("001455159.pdf", 17)
split_pdf_pages("001455160.pdf", 25)
split_pdf_pages("001455161.pdf", 21)
split_pdf_pages("001455162.pdf", 31)
# Out:
# '001455152_1.pdf' と '001455152_2.pdf' に分割しました 。
# '001455159_1.pdf' と '001455159_2.pdf' に分割しました 。
# '001455160_1.pdf' と '001455160_2.pdf' に分割しました 。
# '001455161_1.pdf' と '001455161_2.pdf' に分割しました 。
# '001455162_1.pdf' と '001455162_2.pdf' に分割しました 。

# %%
from google.colab import userdata
import os
import google.generativeai as genai
from PIL import Image
import sys
import json
import math
from typing import List, Dict, Any, Optional, Union
import fitz  # PyMuPDF
import time
from google.api_core import exceptions as core_exceptions # タイムアウトエラーなどを捕捉するため

#api_key = userdata.get('GOOGLE_API_KEY_88')
api_key = userdata.get('GOOGLE_API_KEY_27')

#MODEL_NAME = "gemini-2.0-flash"
#MODEL_NAME = "gemini-2.0-flash-thinking-exp"
MODEL_NAME = 'gemini-2.5-pro-exp-03-25'

# Input PDF file
pdf_files = [
"001455149",
"001455152_1",
"001455152_2",
"001455159_1",
"001455159_2",
"001455160_1",
"001455160_2",
"001455161_1",
"001455161_2",
"001455162_1",
"001455162_2",
]

# %%
genai.configure(api_key=api_key)

# 生成パラメータ
GENERATION_CONFIG = genai.types.GenerationConfig(
    # APIからのレスポンス形式をJSONに指定
    response_mime_type="application/json",
    # 生成されるテキストのランダム性を制御 (0.0-1.0)
    temperature=0.2,
    # 生成に使用するトークンの累積確率を制御 (0.0-1.0)
    top_p=0.8
)


# 出力ファイル名
OUTPUT_FILENAME = "gemini_vision_combined_output.json"


# プロンプト (JSON形式とスキーマの指示を含む)
PROMPT = """これらの画像に含まれる問題とその選択肢を分析し、解答を導き出してください。回答はJSON形式で出力してください。

最上位の階層はリスト形式とし、リストの各要素は一つの問題を表すオブジェクトとします。
各問題オブジェクトは、キーとして問+連番（例: "問1", "問2"）を一つだけ持ちます。
そのキーに対応する値はオブジェクトとし、以下のキーを持ちます:
- "理由": 解答に至る思考プロセスと詳細な解説（他の選択肢がなぜ誤りかの説明も含む）を文章で示してください。理由の中で改行をする場合は\nの代わりに\\nを使用してください。箇条書きや表は使用しないでください。
- "回答": 解答番号（選択肢の番号）を含む配列。解答が1つの場合も配列形式にしてください（例: [1] や [2, 4]）。

出力形式の例：
[
  {
    "問1": {
      "理由": "選択肢1が正解である根拠。選択肢2, 3, 4が不正解である理由...",
      "回答": [1]
    }
  },
  {
    "問2": {
      "理由": "XXXXXから、選択肢2が適切であると判断。他の選択肢が不適切な理由...",
      "回答": [2]
    }
  },
  {
    "問3": {
      "理由": "ZZZZZのYYYに着目し、複数の条件を満たす選択肢1と3が解答となる。\\n他の選択肢が不適切な理由...",
      "回答": [1, 3]
    }
  }
]

上記JSON形式に従って、与えられた画像に対する解答のみを出力してください。他の余計なテキスト（例: ```json ``` マークダウンなど）は含めないでください。
"""

# %%
def load_image(image_path: str) -> Optional[Image.Image]:
    """画像ファイルを安全に読み込む"""
    try:
        img = Image.open(image_path)
        # 必要であればここで画像形式やサイズのチェックを追加
        return img
    except FileNotFoundError:
        print(f"エラー: 画像ファイルが見つかりません: {image_path}", file=sys.stderr)
        return None
    except Exception as e:
        print(f"エラー: 画像読み込み中に予期せぬエラー ({image_path}): {e}", file=sys.stderr)
        return None

def clean_json_string(raw_string: str) -> str:
    """API応答文字列からJSONマークダウンを除去し、前後の空白を削除する"""
    cleaned = raw_string.strip()
    if cleaned.startswith("```json"):
        cleaned = cleaned[7:]
    if cleaned.endswith("```"):
        cleaned = cleaned[:-3]
    return cleaned.strip()


def call_gemini_vision_api(
    image_paths: List[str],
    prompt: str,
    model_name: str,
    generation_config: genai.types.GenerationConfig
) -> Union[str, Dict[str, Any]]:
    """
    画像パスのリストを受け取り、画像をロードしてGemini Vision APIを呼び出す。
    成功時はAPIからの応答テキスト(JSON文字列を期待)、失敗時はエラー情報を含む辞書を返す。
    """
    loaded_images: List[Image.Image] = []
    failed_loads: List[str] = []

    print(f"  チャンク内の画像 {len(image_paths)} 個を読み込み中...")
    for path in image_paths:
        img = load_image(path)
        if img:
            loaded_images.append(img)
        else:
            failed_loads.append(path)

    if not loaded_images:
        return {"error": "チャンク内で読み込める画像がありませんでした。", "failed_paths": failed_loads}

    if failed_loads:
        print(f"  警告: このチャンクで {len(failed_loads)} 個の画像の読み込みに失敗しました。", file=sys.stderr)
        # 失敗したパスを表示（必要であれば）
        # print(f"  失敗したパス: {failed_loads}", file=sys.stderr)

    try:
        model = genai.GenerativeModel(model_name)
        # プロンプトとロードした画像をリストとして結合
        content = [prompt] + loaded_images
        print(f"  Gemini API ({model_name}) に {len(loaded_images)} 個の画像を送信しています...")

        # API呼び出し
        response = model.generate_content(
            content,
            generation_config=generation_config,
            request_options=genai.types.RequestOptions(timeout=1200) # タイムアウト時間を1200秒に指定 ← どうも伸ばしても600秒で503が返ってくるらしいのでファイルを分割するしかない
        )

        return response

    except Exception as e:
        print(f"エラー: Gemini APIリクエスト中にエラーが発生しました: {e}", file=sys.stderr)
        # エラーレスポンスの詳細情報を取得試行 (元のコードより)
        error_details = f"APIリクエスト失敗 - {type(e).__name__}: {e}"
        if hasattr(e, 'response'):
            try:
                 # APIからのエラーレスポンス本文など、より詳細な情報を取得
                 error_details += f"\n  API Response: {e.response}"
                 # 安全性フィルターによるブロックなどの情報を確認
                 if hasattr(e.response, 'prompt_feedback'):
                     error_details += f"\n  プロンプトフィードバック: {e.response.prompt_feedback}"
                 if hasattr(e.response, 'candidates') and e.response.candidates:
                     candidate = e.response.candidates[0]
                     if hasattr(candidate, 'finish_reason'):
                         error_details += f"\n  完了理由: {candidate.finish_reason}"
                     if hasattr(candidate, 'safety_ratings'):
                         error_details += f"\n  安全性評価: {candidate.safety_ratings}"
            except Exception as inner_e:
                 error_details += f"\n  エラーレスポンス解析中の追加エラー: {inner_e}"
        # print(error_details, file=sys.stderr) # 詳細すぎる場合はコメントアウト
        return {"error": f"APIリクエスト失敗 - {type(e).__name__}", "details": str(e)}

    finally:
        # 読み込んだ画像オブジェクトのメモリを解放
        if loaded_images:
             print(f"  チャンクの画像オブジェクト {len(loaded_images)} 個を解放します。")
             for img in loaded_images:
                 try:
                     img.close()
                 except Exception as e_close:
                     # 解放時のエラーは警告にとどめる
                     print(f"  警告: 画像解放中にエラーが発生しました: {e_close}", file=sys.stderr)
             # リスト自体の参照も削除（ガベージコレクションを助ける）
             del loaded_images

def merge_question_lists_indexed(list_of_lists):
  """
  リストのリストとして提供される複数の質問リストを結合します。
  重複する問がある場合、最初に現れたリストの問を保持し、
  重複した問の情報（どのリストに含まれていたか）をエラーリストとして返します。

  Args:
    list_of_lists (list): 結合したい質問リストを含むリスト。
                          例: [[リストA], [リストB], ...]
                          各内部リストは {"問X": {"理由": "...", "回答": [...]}}
                          形式の辞書のリスト。

  Returns:
    tuple: (merged_list, error_list)
      - merged_list (list): 重複を除いて結合された質問リスト。
      - error_list (list): 重複していた問の情報を含む辞書のリスト。
                             各辞書は {"list_index": int, "question_id": str} の形式。
                             list_index は重複が見つかった要素が含まれるリストの、
                             list_of_lists 内でのインデックス（0始まり）。
  """
  merged_data = {}  # 結合結果を一時的に格納する辞書 {問ID: 内容}
  errors = []       # 重複エラー情報を格納するリスト

  # 入力がリストのリストであることを確認（任意）
  if not isinstance(list_of_lists, list) or not all(isinstance(sublist, list) for sublist in list_of_lists):
      raise TypeError("入力はリストのリストである必要があります。例: [[...], [...]]")

  for list_index, current_list in enumerate(list_of_lists):
    for item in current_list:
      # 各辞書アイテムから問ID（キー）と内容（バリュー）を取得
      if not isinstance(item, dict) or not item: # アイテムが辞書でない、または空の辞書はスキップ
          print(f"警告: リスト {list_index} に不正な形式のアイテムが見つかりました。スキップします: {item}")
          continue
      try:
          # 辞書が {"問X": ...} の形式であることを想定
          if len(item) != 1:
              raise ValueError("各アイテムの辞書はキーを1つだけ持つ必要があります。")
          question_id = list(item.keys())[0]
          question_content = item[question_id]
          # 内容が辞書で、'理由'と'回答'キーを持つことを確認（より厳密にする場合）
          if not isinstance(question_content, dict) or '理由' not in question_content or '回答' not in question_content:
               raise ValueError(f"問 '{question_id}' の内容の形式が不正です。")

      except (IndexError, ValueError, KeyError) as e:
          print(f"警告: リスト {list_index} のアイテム処理中にエラーが発生しました。スキップします: {item} (エラー: {e})")
          continue

      # 既に同じ問IDが登録されているかチェック
      if question_id in merged_data:
        # 重複している場合、エラーリストに追加
        # この問がどのリストに含まれていたかの情報を記録
        errors.append({
            "list_index": list_index,
            "question_id": question_id
        })
        # merged_data は更新しない（既存のものが保持される）
      else:
        # 新しい問IDの場合、結合結果辞書に追加
        merged_data[question_id] = question_content

  # 結合結果辞書を元のリスト形式（辞書のリスト）に戻す
  # 順序は保証されないが、通常は問題ない。もし順序維持が必要ならOrderedDictを使う
  final_merged_list = [{qid: data} for qid, data in merged_data.items()]

  return final_merged_list, errors

# %%
print("--- Gemini Vision APIによる画像処理を開始します ---")


all_api_responses: List[Union[str, Dict[str, Any]]] = []


for i, pdf_file in enumerate(pdf_files):
    doc = fitz.open(pdf_file+'.pdf')

    Num = 0
    PicsPath = []

    # Output directory
    output_dir = pdf_file

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    print(f"\n[ファイル {i+1}/{len(pdf_files)} の処理開始]")
    print(f"PDF converted to images in '{output_dir}' directory.")

    for page_num in range(doc.page_count):
        page = doc[page_num]
        # Render the page to an image (PNG format)
        pix = page.get_pixmap()
        # Generate the output filename with zero-padded page number
        output_filename = os.path.join(output_dir, f"{Num:03d}.png")
        # Save the image
        pix.save(output_filename)
        Num += 1
        PicsPath.append(output_filename)

    print(f"画像 {len(PicsPath)} 個の処理開始")
    print("-" * 30)
    start_time = time.time()

    # API呼び出し関数を実行
    response = call_gemini_vision_api(
        PicsPath,
        PROMPT,
        MODEL_NAME,
        GENERATION_CONFIG
    )
    all_api_responses.append(json.loads(response.text))

    end_time = time.time()
    elapsed_time = end_time - start_time

    print(f"  ファイル {i+1} の結果が生成されました。")
    print(f"\n  所要時間: {elapsed_time:.4f} 秒")
    if hasattr(response, 'usage_metadata') and response.usage_metadata:
        print(f"  Prompt Token Count: {response.usage_metadata.prompt_token_count}")
        # print(f"Candidates Token Count: {response.usage_metadata.candidates_token_count}")
        print(f"  Total Token Count: {response.usage_metadata.total_token_count}")
    else:
        print("  Token usage metadata not available.")
    print("-" * 30)

# 全てのチャンクの応答を統合・整形
merged_list, error_info = merge_question_lists_indexed(all_api_responses)

print("--- 結合結果 ---")
print("結合されたリスト:")
# 見やすくするためにjson形式で出力
# sort_keys=True を追加すると、辞書内のキーの順序がソートされ、
# 実行ごとに結果が安定しやすくなります（必須ではない）。
# また、最終的なリスト内の要素の順序は辞書のキー（問ID）に依存します。
marged = json.dumps(merged_list, indent=2, ensure_ascii=False, sort_keys=True)

print(marged)

print("\n--- 重複エラー情報 ---")
if error_info:
  print("以下の問が重複していました（最初に現れたものが保持されます）：")
  for error in error_info:
    print(f"- リスト {error['list_index']} に含まれる '{error['question_id']}'")
else:
  print("重複エラーはありませんでした。")

with open(OUTPUT_FILENAME, "w", encoding="utf-8") as f:
    f.write(marged)
print(f"\n最終結果を '{OUTPUT_FILENAME}' に保存しました。")

print("\n--- 全ての処理が完了しました ---")
# Out:
# --- Gemini Vision APIによる画像処理を開始します ---
#
# [ファイル 1/11 の処理開始]
# PDF converted to images in '001455149' directory.
# 画像 38 個の処理開始
# ------------------------------
#   チャンク内の画像 38 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 38 個の画像を送信しています...
#   チャンクの画像オブジェクト 38 個を解放します。
#   ファイル 1 の結果が生成されました。
#
#   所要時間: 331.9580 秒
#   Prompt Token Count: 10222
#   Total Token Count: 40195
# ------------------------------
#
# [ファイル 2/11 の処理開始]
# PDF converted to images in '001455152_1' directory.
# 画像 26 個の処理開始
# ------------------------------
#   チャンク内の画像 26 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 26 個の画像を送信しています...
#   チャンクの画像オブジェクト 26 個を解放します。
#   ファイル 2 の結果が生成されました。
#
#   所要時間: 422.7094 秒
#   Prompt Token Count: 7126
#   Total Token Count: 45288
# ------------------------------
#
# [ファイル 3/11 の処理開始]
# PDF converted to images in '001455152_2' directory.
# 画像 24 個の処理開始
# ------------------------------
#   チャンク内の画像 24 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 24 個の画像を送信しています...
#   チャンクの画像オブジェクト 24 個を解放します。
#   ファイル 3 の結果が生成されました。
#
#   所要時間: 372.8258 秒
#   Prompt Token Count: 6610
#   Total Token Count: 38627
# ------------------------------
#
# [ファイル 4/11 の処理開始]
# PDF converted to images in '001455159_1' directory.
# 画像 17 個の処理開始
# ------------------------------
#   チャンク内の画像 17 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 17 個の画像を送信しています...
#   チャンクの画像オブジェクト 17 個を解放します。
#   ファイル 4 の結果が生成されました。
#
#   所要時間: 230.6707 秒
#   Prompt Token Count: 4804
#   Total Token Count: 29042
# ------------------------------
#
# [ファイル 5/11 の処理開始]
# PDF converted to images in '001455159_2' directory.
# 画像 14 個の処理開始
# ------------------------------
#   チャンク内の画像 14 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 14 個の画像を送信しています...
#   チャンクの画像オブジェクト 14 個を解放します。
#   ファイル 5 の結果が生成されました。
#
#   所要時間: 253.7089 秒
#   Prompt Token Count: 4030
#   Total Token Count: 30712
# ------------------------------
#
# [ファイル 6/11 の処理開始]
# PDF converted to images in '001455160_1' directory.
# 画像 25 個の処理開始
# ------------------------------
#   チャンク内の画像 25 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 25 個の画像を送信しています...
#   チャンクの画像オブジェクト 25 個を解放します。
#   ファイル 6 の結果が生成されました。
#
#   所要時間: 329.9888 秒
#   Prompt Token Count: 6868
#   Total Token Count: 35338
# ------------------------------
#
# [ファイル 7/11 の処理開始]
# PDF converted to images in '001455160_2' directory.
# 画像 26 個の処理開始
# ------------------------------
#   チャンク内の画像 26 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 26 個の画像を送信しています...
#   チャンクの画像オブジェクト 26 個を解放します。
#   ファイル 7 の結果が生成されました。
#
#   所要時間: 225.7988 秒
#   Prompt Token Count: 7126
#   Total Token Count: 28829
# ------------------------------
#
# [ファイル 8/11 の処理開始]
# PDF converted to images in '001455161_1' directory.
# 画像 21 個の処理開始
# ------------------------------
#   チャンク内の画像 21 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 21 個の画像を送信しています...
#   チャンクの画像オブジェクト 21 個を解放します。
#   ファイル 8 の結果が生成されました。
#
#   所要時間: 274.7863 秒
#   Prompt Token Count: 5836
#   Total Token Count: 32213
# ------------------------------
#
# [ファイル 9/11 の処理開始]
# PDF converted to images in '001455161_2' directory.
# 画像 22 個の処理開始
# ------------------------------
#   チャンク内の画像 22 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 22 個の画像を送信しています...
#   チャンクの画像オブジェクト 22 個を解放します。
#   ファイル 9 の結果が生成されました。
#
#   所要時間: 139.8029 秒
#   Prompt Token Count: 6094
#   Total Token Count: 18089
# ------------------------------
#
# [ファイル 10/11 の処理開始]
# PDF converted to images in '001455162_1' directory.
# 画像 31 個の処理開始
# ------------------------------
#   チャンク内の画像 31 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 31 個の画像を送信しています...
#   チャンクの画像オブジェクト 31 個を解放します。
#   ファイル 10 の結果が生成されました。
#
#   所要時間: 450.4263 秒
#   Prompt Token Count: 8416
#   Total Token Count: 45640
# ------------------------------
#
# [ファイル 11/11 の処理開始]
# PDF converted to images in '001455162_2' directory.
# 画像 31 個の処理開始
# ------------------------------
#   チャンク内の画像 31 個を読み込み中...
#   Gemini API (gemini-2.5-pro-exp-03-25) に 31 個の画像を送信しています...
#   チャンクの画像オブジェクト 31 個を解放します。
#   ファイル 11 の結果が生成されました。
#
#   所要時間: 399.3015 秒
#   Prompt Token Count: 8416
#   Total Token Count: 40170
# ------------------------------
# --- 結合結果 ---
# 結合されたリスト:
# [
#   {
#     "問1": {
#       "回答": [
#         3
#       ],
#       "理由": "ダニエル電池の起電力は、正極（銅）の標準電極電位から負極（亜鉛）の標準電極電位を引いて求める。正極の電位は+0.337 V、負極の電位は-0.763 Vであるため、起電力 = (+0.337 V) - (-0.763 V) = +1.100 V となる。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問2": {
#       "回答": [
#         4
#       ],
#       "理由": "熱力学における閉じた系とは、外界との間で物質の移動はないが、エネルギー（熱や仕事）のやりとりは可能な系を指す。選択肢の中で、熱と仕事はエネルギーの形態であり、閉じた系で外界とやりとりできる。物質はやりとりできない。したがって、熱と仕事の組み合わせである選択肢4が正しい。"
#     }
#   },
#   {
#     "問3": {
#       "回答": [
#         5
#       ],
#       "理由": "難溶性塩である水酸化鉄(III) Fe(OH)₃ の溶解平衡は Fe(OH)₃ ⇌ Fe³⁺ + 3OH⁻ で表される。純水中での溶解度を S [mol/L] とすると、平衡時のイオン濃度は [Fe³⁺] = S [mol/L]、[OH⁻] = 3S [mol/L] となる。溶解度積 Ksp は、これらのイオン濃度の積で表され、Ksp = [Fe³⁺][OH⁻]³ = (S) * (3S)³ = S * 27S³ = 27S⁴ [(mol/L)⁴] となる。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問4": {
#       "回答": [
#         5
#       ],
#       "理由": "スピン量子数が1/2である原子核（例: ¹H, ¹³C）が外部磁場中に置かれると、核スピンの磁気モーメントと外部磁場の相互作用により、エネルギー準位が分裂する。この現象はゼーマン効果（ゼーマン分裂）と呼ばれる。これにより、NMR（核磁気共鳴）分光法が可能となる。化学シフトは核周囲の電子環境による共鳴周波数の差、McLafferty転位やラジカル開裂は質量分析におけるイオンの開裂様式、超微細分裂は電子スピンと核スピンなどの相互作用による分裂である。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問5": {
#       "回答": [
#         1
#       ],
#       "理由": "初期の薬物Xの物質量は 50 mmol。水相の体積は 100 mL。酢酸エチル相（体積 V mL）に抽出後、酢酸エチル相中のXは 45 mmol。したがって、水相に残ったXは 50 - 45 = 5 mmol。分配係数 K は (酢酸エチル相中の濃度) / (水相中の濃度) で定義される。酢酸エチル相中の濃度は 45/V [mmol/mL]、水相中の濃度は 5/100 [mmol/mL]。分配係数は 18 なので、K = (45/V) / (5/100) = 18。これを解くと、(45/V) * (100/5) = 18 => (45/V) * 20 = 18 => 900/V = 18 => V = 900 / 18 = 50 [mL]。したがって、酢酸エチル相の体積は 50 mL であり、選択肢1が正しい。"
#     }
#   },
#   {
#     "問6": {
#       "回答": [
#         1
#       ],
#       "理由": "アノマーとは、環状構造を持つ糖において、ヘミアセタール（またはヘミケタール）炭素（アノマー炭素、通常は1位または2位）の立体配置のみが異なる異性体のこと。化合物Aはβ-D-グルコピラノースである（1位のOH基が上向き）。選択肢1はα-D-グルコピラノース（1位のOH基が下向き）であり、化合物Aのアノマーである。選択肢2はD-マンノース（2位のエピマー）、選択肢3はD-ガラクトース（4位のエピマー）、選択肢4はL-グルコース（鏡像異性体）、選択肢5はD-フルクトフラノース（構造異性体）である。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問7": {
#       "回答": [
#         5
#       ],
#       "理由": "示された薬物の構造は、スルホンアミド基(-SO₂NH₂)とアミド基(-CONH₂)を持つ。この構造は、炭酸脱水酵素阻害薬であるアセタゾラミドに類似している。炭酸脱水酵素は活性中心に亜鉛(Zn)イオンを持つ金属酵素である。この種の阻害薬は、活性中心のZnイオンに配位することで酵素活性を阻害する。したがって、この薬物に含まれる金属元素Mとして最も可能性が高いのは亜鉛(Zn)である。選択肢5が正しい。"
#     }
#   },
#   {
#     "問8": {
#       "回答": [
#         5
#       ],
#       "理由": "化合物の酸性度は、プロトンを放出した後の共役塩基の安定性に依存する。選択肢1はシクロヘキサノールで脂肪族アルコールであり、酸性度は非常に低い。選択肢2-5はフェノール誘導体であり、フェノール性水酸基を持つため、1より酸性度が高い。フェノール(2)と比較して、置換基が共役塩基（フェノキシドイオン）を安定化させるほど酸性度は高くなる。アミノ基(-NH₂)は電子供与基であり、共役塩基を不安定化させるため酸性度は低い(3)。塩素原子(-Cl)は誘起効果により電子求引性を示し、共役塩基をやや安定化させるため酸性度は2より高い(4)。ニトロ基(-NO₂)は誘起効果および共鳴効果により強い電子求引性を示し、共役塩基の負電荷を非局在化させて最も安定化させるため、酸性度が最も高い(5)。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問9": {
#       "回答": [
#         4
#       ],
#       "理由": "ベンジルカチオンの安定性は、カチオン中心の正電荷を非局在化させる置換基によって向上する。メトキシ基(-OCH₃)は、酸素原子の非共有電子対による共鳴効果（電子供与性）を持ち、ベンゼン環のオルト位およびパラ位に付くとカチオンを強く安定化させる。メタ位では共鳴効果による安定化は起こりにくい。選択肢1はオルト位、選択肢2はメタ位、選択肢3はパラ位に-OCH₃が1つ。選択肢4はオルト位とパラ位に-OCH₃が1つずつ。選択肢5はメタ位に2つ。ベンジルカチオンの正電荷は、カチオン中心の炭素、オルト位、パラ位に非局在化する。したがって、オルト位とパラ位の両方に電子供与性の-OCH₃基を持つ選択肢4が、最も効果的に正電荷を非局在化させ、カチオンを安定化する。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問10": {
#       "回答": [
#         3
#       ],
#       "理由": "ビンクリスチンは、インドール環を含む複雑な構造を持つインドールアルカロイドである。インドールアルカロイドの生合成における基本的な前駆体は、インドール環を持つアミノ酸であるトリプトファンである。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問11": {
#       "回答": [
#         3
#       ],
#       "理由": "血管の中で、血管平滑筋細胞を持たず、血管内皮細胞とその外側の基底膜のみから構成されるのは毛細血管である。この薄い構造により、血液と組織の間で栄養成分、酸素、二酸化炭素、老廃物などの物質交換が効率的に行われる。大動脈、細動脈、大静脈は平滑筋層を持つ。胸管はリンパ管である。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問12": {
#       "回答": [
#         5
#       ],
#       "理由": "ヒトにおいて、核酸に含まれるプリン塩基（アデニンとグアニン）は、代謝されて最終的に尿酸となる。アデニンはヒポキサンチンを経てキサンチンに、グアニンは直接キサンチンに変換され、キサンチンはキサンチンオキシダーゼによって尿酸に酸化される。構造式1はヒポキサンチン、2はグアニン、3はアデニン、4はキサンチン、5は尿酸である。したがって、最終代謝産物は尿酸であり、選択肢5が正しい。"
#     }
#   },
#   {
#     "問13": {
#       "回答": [
#         3
#       ],
#       "理由": "真核生物において、遺伝子の転写を開始するためには、RNAポリメラーゼIIがDNA上の特定の領域に結合する必要がある。この転写開始点を制御するDNA領域をプロモーターと呼ぶ。プロモーターにはTATAボックスなどの配列が含まれ、基本転写因子群とともにRNAポリメラーゼIIが結合する複合体を形成する。イントロンとエクソンは転写される領域、テロメアは染色体末端の保護構造、ターミネーターは転写終結シグナル領域である。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問14": {
#       "回答": [
#         5
#       ],
#       "理由": "オステオカルシンは骨基質タンパク質の一つであり、カルシウムイオンと結合する能力を持つ。この結合能は、タンパク質合成後の翻訳後修飾によって獲得される。具体的には、オステオカルシン中の特定のグルタミン酸残基が、ビタミンK依存性の酵素によってγ位がカルボキシル化され、γ-カルボキシグルタミン酸(Gla)残基となる。このGla残基が2価の負電荷を持つため、カルシウムイオンと強く結合できるようになる。この修飾はカルボキシル化である。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問15": {
#       "回答": [
#         2
#       ],
#       "理由": "ウイルス粒子において、中心にあるウイルスゲノム（核酸）を取り囲んでいるタンパク質の殻構造をカプシドと呼ぶ。カプシドは、カプソメアと呼ばれるタンパク質サブユニットから構成される。エンベロープは一部のウイルスが持つ脂質二重膜の外被、コアはゲノムとカプシドを合わせた内部構造、スパイクはエンベロープ表面の突起状タンパク質、ビリオンは感染性を有する完全なウイルス粒子全体を指す。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問16": {
#       "回答": [
#         2
#       ],
#       "理由": "提示されたグラフは、1950年代に高い値を示した後、急激に低下し、1970年代半ばに最低値を記録した後、緩やかに上昇し、近年再び低下傾向にある日本の人口動態指標を示している。この特徴的な推移は、合計特殊出生率（一人の女性が生涯に産む子供の数の平均）の変動パターンと一致する。出生率はより高い値を示し、戦後一貫して低下傾向（多少の変動はある）。総再生産率は合計特殊出生率と似た動きだが値が異なる。粗死亡率は戦後低下したが近年高齢化により上昇。年齢調整死亡率は医学の進歩などにより低下傾向。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問17": {
#       "回答": [
#         1
#       ],
#       "理由": "再興感染症とは、過去に流行し公衆衛生上の問題とならなくなったと考えられていたが、近年再び感染者数が増加したり、新たな地域で流行したりしている感染症のこと。結核は、治療法の開発などで一時は減少したが、薬剤耐性菌の出現や社会経済的要因の変化などにより、依然として世界的な問題であり、日本でも再興感染症と位置づけられている。他の選択肢は新興感染症（SARS、レジオネラ症）やその他の感染症。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問18": {
#       "回答": [
#         3
#       ],
#       "理由": "労働安全衛生における衛生管理は、作業環境管理、作業管理、健康管理の3つが基本となる。有害物質の経皮曝露を防ぐために化学防護手袋を使用することは、作業方法の改善や保護具の使用に該当し、作業管理に含まれる。作業環境管理は作業場所の有害物質濃度低減など、健康管理は健康診断など、労働衛生教育は知識の付与、作業環境管理は環境改善、総括管理は全体の管理体制を指す。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問19": {
#       "回答": [
#         3
#       ],
#       "理由": "提示された構造式は、イミダゾール環を持つアミンであり、ヒスタミンである。ヒスタミンは、生体内でアミノ酸のヒスチジンが、ヒスチジン脱炭酸酵素によって脱炭酸されることによって生成される腐敗アミン（生体アミン）の一種である。したがって、前駆体となるアミノ酸はヒスチジンであり、選択肢3が正しい。"
#     }
#   },
#   {
#     "問20": {
#       "回答": [
#         3
#       ],
#       "理由": "コウジカビの一種である Aspergillus flavus や Aspergillus parasiticus が産生するカビ毒（マイコトキシン）の中で、特に毒性が強く、主要な肝発がん物質として知られているのはアフラトキシン類である。特にアフラトキシンB₁は天然物の中で最も強力な発がん物質の一つとされる。シトリニン、パツリン、フモニシン、デオキシニバレノールもカビ毒だが、産生菌や主な毒性が異なる。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問21": {
#       "回答": [
#         1
#       ],
#       "理由": "化審法（化学物質の審査及び製造等の規制に関する法律）は、主に意図的に製造・輸入される新規化学物質や既存化学物質の性状等に応じた規制を行う法律である。ポリ塩化ジベンゾ-p-ジオキシン（ダイオキシン類）は、主に燃焼過程などで非意図的に生成される物質であり、化審法の直接的な規制対象ではない（ただし、ダイオキシン類対策特別措置法などで厳しく規制されている）。ポリ塩化ビフェニル(PCB)も非意図的生成物を含むが、化審法で第一種特定化学物質に指定されている。ペルフルオロ（オクタン-1-スルホン酸）(PFOS)、ヘキサブロモビフェニル、ビス（トリブチルスズ）＝オキシド(TBTO)は意図的に製造・使用された経緯があり、化審法等で規制されている（PFOS、ヘキサブロモビフェニルは第一種特定化学物質）。したがって、「主に非意図的に生成することから化審法で規制されていない」ものとしては、選択肢1が最も適切と考えられる（ただし、別の法律で規制されている点に注意）。"
#     }
#   },
#   {
#     "問22": {
#       "回答": [
#         4
#       ],
#       "理由": "ガラス工白内障（熱白内障）は、高温の炉などを扱うガラス工や溶接工などにみられる職業性の白内障であり、長期間にわたる赤外線の曝露が原因とされる。赤外線は非電離放射線であり、その熱作用によって水晶体タンパク質が変性し、混濁すると考えられている。紫外線（UVA, UVB, UVC）は主に紫外線白内障の原因となる。可視光線は通常、白内障の直接的な原因とは考えにくい。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問23": {
#       "回答": [
#         5
#       ],
#       "理由": "水道水質基準における大腸菌の検査では、大腸菌が特異的に持つ酵素であるβ-グルクロニダーゼを利用する方法が一般的である。この酵素は、β-グルクロニド結合を持つ基質を加水分解する。選択肢の中で、β-D-グルクロニド構造を持つ基質は5である。この種の基質（例: X-Gluc）は、酵素反応によって発色団や蛍光物質を遊離し、大腸菌の存在を検出するために用いられる。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問24": {
#       "回答": [
#         2
#       ],
#       "理由": "湖沼などで富栄養化が起こると、藍藻類や放線菌が異常増殖し、カビ臭の原因物質を産生することがある。代表的なカビ臭物質として、ジェオスミンと2-メチルイソボルネオール(2-MIB)が知られている。選択肢の中ではジェオスミンが該当する。クロラミン、トリハロメタンは水道水の消毒副生成物。クロロフェノールは異臭味の原因物質。ミクロシスチンは藍藻が産生する肝毒素。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問25": {
#       "回答": [
#         2
#       ],
#       "理由": "逆転層とは、高度が上昇するにつれて気温が上昇する層のことであり、大気の鉛直混合が抑制されるため、地表付近の大気汚染物質が拡散しにくくなり、滞留を引き起こす。盆地や谷間などの地形では、夜間に山腹から冷たい空気が下降・流入して底に溜まり、地表付近に冷気層が形成されることがある。これが地形性逆転層であり、汚染物質の滞留の原因となる。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問26": {
#       "回答": [
#         2
#       ],
#       "理由": "図はアセチルコリン(ACh)の用量反応曲線を示す。破線（ACh単独）と比較して、実線（薬物X存在下）では、同じ反応を得るために必要なACh濃度が高濃度側にシフトしており、最大反応高さは変化していない。これは、薬物XがAChの作用に対して競合的に拮抗していることを示す。選択肢の中で、AChのムスカリン受容体に対する競合的拮抗薬はアトロピンである。ヒスタミンは作動薬、ピリドスチグミンはコリンエステラーゼ阻害薬（ACh作用増強）、パパベリンは非特異的平滑筋弛緩薬、ベタネコールはムスカリン作動薬である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問27": {
#       "回答": [
#         1
#       ],
#       "理由": "フェニレフリンは、アドレナリンα₁受容体を選択的に刺激する作動薬である。血管平滑筋に存在するα₁受容体が刺激されると、血管が収縮し、末梢血管抵抗が増大するため、血圧が上昇する。したがって、フェニレフリンの昇圧作用の機序はアドレナリンα₁受容体刺激である。選択肢1が正しい。"
#     }
#   },
#   {
#     "問28": {
#       "回答": [
#         5
#       ],
#       "理由": "ピロカルピンは、ムスカリン性アセチルコリン受容体作動薬である。眼の毛様体筋にはムスカリンM₃受容体が存在し、ピロカルピンがこれを刺激すると毛様体筋が収縮する。毛様体筋の収縮により、線維柱帯が広がり、房水の流出が促進され、眼圧が下降する。また、瞳孔括約筋も収縮し、縮瞳が起こる。したがって、ピロカルピンが毛様体筋を収縮させる機序はアセチルコリンM₃受容体刺激である。選択肢5が正しい。"
#     }
#   },
#   {
#     "問29": {
#       "回答": [
#         1
#       ],
#       "理由": "ロクロニウムは、非脱分極性の神経筋遮断薬（筋弛緩薬）である。神経筋接合部において、骨格筋の終板上に存在するニコチン性アセチルコリン(N<0xE2><0x82><0x99>)受容体に対して、アセチルコリンと競合的に結合し、アセチルコリンによる筋収縮を阻害する。これにより筋弛緩作用を示す。したがって、作用点はアセチルコリンN<0xE2><0x82><0x99>受容体である。選択肢1が正しい。"
#     }
#   },
#   {
#     "問30": {
#       "回答": [
#         3
#       ],
#       "理由": "オレキシンは、視床下部から分泌される神経ペプチドであり、覚醒状態の維持に重要な役割を果たしている。オレキシン受容体（OX₁R, OX₂R）を遮断すると、オレキシンの覚醒促進作用が抑制され、睡眠が誘導される。レンボレキサントは、オレキシン受容体拮抗薬であり、不眠症の治療に用いられる。ヒドロキシジンは抗ヒスタミン薬、リルマザホンとゾピクロンはGABA<0xE2><0x82><0x90>受容体作動薬、ペントバルビタールはバルビツール酸系薬である。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問31": {
#       "回答": [
#         4
#       ],
#       "理由": "タンドスピロンは、アザピロン系の抗不安薬である。その主な作用機序は、脳内のセロトニン神経系に作用し、シナプス前部に存在するセロトニン5-HT₁<0xE2><0x82><0x90>自己受容体を部分作動薬として刺激することである。これにより、セロトニンの放出が抑制され、抗不安作用や抗うつ作用を示すと考えられている。したがって、作用点はセロトニン5-HT₁<0xE2><0x82><0x90>受容体である。選択肢4が正しい。"
#     }
#   },
#   {
#     "問32": {
#       "回答": [
#         4
#       ],
#       "理由": "アルツハイマー型認知症では、グルタミン酸神経系の機能異常が関与していると考えられている。グルタミン酸受容体の一つであるNMDA受容体が過剰に活性化されると、神経細胞死につながる可能性がある。メマンチンは、NMDA受容体に対して低親和性の非競合的拮抗薬であり、過剰なグルタミン酸による神経細胞毒性を抑制することで、アルツハイマー型認知症の症状進行を抑制する。リバスチグミン、ドネペジル、ガランタミンはコリンエステラーゼ阻害薬。エダラボンはフリーラジカルスカベンジャー。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問33": {
#       "回答": [
#         5
#       ],
#       "理由": "セクキヌマブは、ヒト型抗ヒトインターロイキン(IL)-17Aモノクローナル抗体である。IL-17Aは、Th17細胞などから産生される炎症性サイトカインであり、尋常性乾癬や強直性脊椎炎などの自己免疫疾患の病態形成に深く関与している。セクキヌマブはIL-17Aに結合してその作用を中和することで、これらの疾患の症状を改善する。したがって、標的分子はIL-17Aである。選択肢5が正しい。"
#     }
#   },
#   {
#     "問34": {
#       "回答": [
#         1
#       ],
#       "理由": "ニコランジルは、狭心症治療薬であり、二つの主要な作用機序を持つ。一つは、ニトログリセリンなどの硝酸薬と同様に、血管平滑筋細胞内でグアニル酸シクラーゼを活性化し、サイクリックGMP (cGMP) 濃度を上昇させて血管を拡張させる作用。もう一つは、血管平滑筋細胞膜のATP感受性K⁺チャネルを開口させ、細胞膜を過分極させることにより、電位依存性Ca²⁺チャネルからのCa²⁺流入を抑制し、血管を拡張させる作用である。したがって、cGMP濃度上昇作用とK⁺チャネル開口作用を併せ持つのはニコランジルである。選択肢1が正しい。"
#     }
#   },
#   {
#     "問35": {
#       "回答": [
#         5
#       ],
#       "理由": "血液凝固カスケードにおいて、第Xa因子はプロトロンビンをトロンビンに変換する重要な酵素である。アンチトロンビンは、ヘパリン類の存在下で第Xa因子やトロンビンを不活性化する生理的な凝固制御因子である。直接経口抗凝固薬(DOAC)の中には、アンチトロンビンを介さずに直接第Xa因子を阻害するものがある。これらにはリバーロキサバン、アピキサバン、エドキサバンが含まれる。選択肢の中ではエドキサバンが該当する。エノキサパリン（低分子ヘパリン）やフォンダパリヌクス（選択的Xa阻害薬）はアンチトロンビン依存的に作用する。ダビガトランは直接トロンビン阻害薬。ワルファリンはビタミンK依存性凝固因子の合成を阻害する。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問36": {
#       "回答": [
#         3
#       ],
#       "理由": "抗悪性腫瘍薬（化学療法）による悪心・嘔吐には、急性のものと遅発性のものがある。セロトニン(5-HT)は主に急性の嘔吐に関与し、サブスタンスPは主に遅発性の嘔吐に関与すると考えられている。サブスタンスPは、脳の嘔吐中枢などに存在するタキキニンNK₁受容体に結合して作用を発現する。アプレピタントは、選択的なNK₁受容体拮抗薬であり、サブスタンスPの結合を阻害することで、特に化学療法による遅発性の悪心・嘔吐を抑制する。オンダンセトロンは5-HT₃受容体拮抗薬。ドンペリドン、メトクロプラミドはドパミンD₂受容体拮抗薬。ジメンヒドリナートは抗ヒスタミン薬。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問37": {
#       "回答": [
#         2
#       ],
#       "理由": "トピロキソスタットは、高尿酸血症治療薬であり、尿酸の生成を抑制する作用を持つ。生体内では、プリン体が代謝されてヒポキサンチン、キサンチンを経て、最終的にキサンチンオキシダーゼ（またはキサンチンデヒドロゲナーゼ）という酵素によって尿酸に変換される。トピロキソスタットは、このキサンチンオキシダーゼを選択的に阻害することで、尿酸の生成を抑制し、血中尿酸値を低下させる。したがって、阻害するのはキサンチンオキシダーゼである。選択肢2が正しい。"
#     }
#   },
#   {
#     "問38": {
#       "回答": [
#         3
#       ],
#       "理由": "プロゲステロン（黄体ホルモン）は、子宮内膜の増殖を抑制する作用を持つ。ジエノゲストは、選択的なプロゲステロン受容体作動薬であり、プロゲステロン受容体を刺激することで、子宮内膜細胞の増殖を抑制し、子宮内膜症や月経困難症の治療に用いられる。リュープロレリンはGnRHアゴニスト、タモキシフェンはSERM、エンザルタミドは抗アンドロゲン薬、デュタステリドは5α還元酵素阻害薬である。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問39": {
#       "回答": [
#         3
#       ],
#       "理由": "バンコマイシンは、グリコペプチド系の抗菌薬であり、細菌の細胞壁合成を阻害する。その作用機序は、細胞壁の構成成分であるペプチドグリカンの前駆体（リピド中間体）に含まれるペンタペプチド鎖の末端部分、D-アラニル-D-アラニン(D-Ala-D-Ala)に特異的に結合することである。これにより、ペプチドグリカンの伸長反応（トランスグリコシル化）と架橋反応（トランスペプチダーゼ反応）の両方が阻害され、細胞壁合成が停止する。アミカシンはアミノグリコシド系、セファゾリンはセフェム系、メロペネムはカルバペネム系、ミカファンギンは抗真菌薬であり、作用機序が異なる。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問40": {
#       "回答": [
#         2
#       ],
#       "理由": "HER2（ヒト上皮増殖因子受容体2型）は、一部の乳がん細胞で過剰に発現しており、がん細胞の増殖に関与している。トラスツズマブは、HER2に対するヒト化モノクローナル抗体であり、HER2に特異的に結合する。これにより、HER2を介した増殖シグナルを阻害したり、抗体依存性細胞傷害(ADCC)活性を誘導したりすることで、HER2陽性乳がん細胞の増殖を抑制する。エキセメスタンはアロマターゼ阻害薬、ベバシズマブは抗VEGF抗体、ダウノルビシンとブスルファンは細胞傷害性の抗がん剤である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問41": {
#       "回答": [
#         5
#       ],
#       "理由": "図は、細胞外の高分子医薬品が細胞膜の陥入によって小胞に取り込まれ、細胞内に輸送される過程を示している。これはエンドサイトーシスの一種であり、特に液体成分を取り込む場合は飲作用（ピノサイトーシス）と呼ばれる。この過程は細胞膜の形態変化を伴い、エネルギーを必要とする能動的な輸送機構である。選択肢の中では膜動輸送が最も広い概念として適切であるが、具体的なプロセスとしては飲作用が考えられる。選択肢に飲作用がないため、より広範な膜動輸送（エンドサイトーシスやエキソサイトーシスを含む）を示す選択肢5が最も適切である。単純拡散、促進拡散、一次性能動輸送、二次性能動輸送は主に低分子物質の膜透過機構である。"
#     }
#   },
#   {
#     "問42": {
#       "回答": [
#         4
#       ],
#       "理由": "経口投与された薬物の多くは、主に小腸から吸収される。小腸で吸収された薬物は、毛細血管に入り、門脈と呼ばれる血管に集められる。門脈は肝臓に直接つながっており、吸収された薬物はまず肝臓を通過する（初回通過効果を受ける）。肝臓を通過した後、大静脈を経て心臓に入り、全身循環へと移行する。したがって、正しい経路は「小腸 → 門脈 → 肝臓 → 全身循環系」である。選択肢4がこれに合致する。リンパ管へ吸収される経路もあるが、門脈経由が主要経路である。胆管は肝臓から十二指腸への胆汁の経路。"
#     }
#   },
#   {
#     "問43": {
#       "回答": [
#         5
#       ],
#       "理由": "プロプラノロールは塩基性薬物であり、血漿中では主にα₁-酸性糖タンパク質(AAG)とアルブミンに結合するが、AAGへの親和性が高い。AAGは、炎症性疾患、感染症、悪性腫瘍、心筋梗塞などの際に血中濃度が上昇する急性期タンパク質の一つである。したがって、炎症性疾患時にはAAGの濃度が増加するため、プロプラノロールの結合率が変動する可能性がある。最も強く結合するのはα₁-酸性糖タンパク質である。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問44": {
#       "回答": [
#         2
#       ],
#       "理由": "薬物代謝は、主に第I相反応（酸化、還元、加水分解など）と第II相反応（抱合反応）に分けられる。第II相反応では、薬物またはその第I相代謝物に、グルクロン酸、硫酸、アセチル基、グリシンなどの内因性物質が付加（抱合）され、水溶性が増して排泄されやすくなる。UDP-グルクロン酸転移酵素は、グルクロン酸抱合を触媒する代表的な第II相反応酵素である。シトクロムP450、フラビン含有モノオキシゲナーゼ、アルコール脱水素酵素、モノアミン酸化酵素は、主に第I相反応に関与する酵素である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問45": {
#       "回答": [
#         2
#       ],
#       "理由": "図は腎臓のネフロンにおける物質輸送を示している。有機アニオントランスポーター(OAT)は、薬物などの有機アニオンの尿中への分泌（血液→尿細管腔）に関与する。特にOAT1とOAT3は、主に近位尿細管の基底膜側（血液側）に発現しており、血液中の有機アニオンを尿細管細胞内に取り込む輸送を担っている。図中の矢印は血液から尿細管腔への物質の移動方向を示している。近位尿細管において、血液側から細胞内への取り込みを示すのはステップ2である。ステップ3は細胞内から尿細管腔への排出を示す。したがって、OAT1, OAT3を介した薬物の輸送（取り込み）を示すのは2である。選択肢2が正しい。"
#     }
#   },
#   {
#     "問46": {
#       "回答": [
#         2
#       ],
#       "理由": "線形1-コンパートメントモデルに従う薬物を経口投与した場合、最高血中濃度到達時間(t_max)は、吸収速度定数(ka)と消失速度定数(ke)によって決まる。一般に、吸収が速いほど（kaが大きいほど）、t_maxは短縮する。逆に、吸収が遅いほど（kaが小さいほど）、t_maxは延長する。消失速度定数(ke)が小さい（消失が遅い）ほど、t_maxは延長する傾向がある。投与量の変化は最高血中濃度(C_max)に影響するが、t_maxには直接影響しない（線形の場合）。分布容積の増大はkeを小さくする可能性があり、t_maxを延長させる方向に働く。したがって、t_maxが短縮する要因は吸収速度の上昇である。選択肢2が正しい。"
#     }
#   },
#   {
#     "問47": {
#       "回答": [
#         4
#       ],
#       "理由": "静脈内定速注入を開始後、血中濃度が定常状態(Css)に達するまでの時間は、消失半減期(t₁/₂)に依存する。血中濃度がCssの50%に達するのに t₁/₂、75%に達するのに 2 * t₁/₂、87.5%に達するのに 3 * t₁/₂、約94%に達するのに 4 * t₁/₂ かかる。問題では消失半減期が2時間であり、定常状態の75%に到達する時間を問われているため、2 * t₁/₂ = 2 * 2時間 = 4時間となる。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問48": {
#       "回答": [
#         4
#       ],
#       "理由": "肝クリアランス(CLh)は、肝臓を通過する血液から薬物が除去される効率を示す指標である。Well-stirred model によると、CLh = (Qh * fu * CLint) / (Qh + fu * CLint) で表される。ここで、Qhは肝血流量、fuは血漿タンパク非結合形分率、CLintは肝固有クリアランス（肝細胞自体の代謝・排泄能力）である。肝固有クリアランス(CLint)が肝血流量(Qh)と比較して十分に小さい薬物（低クリアランス薬）の場合、fu * CLint << Qh とみなせる。このとき、分母の (Qh + fu * CLint) は Qh と近似できるため、CLh ≈ (Qh * fu * CLint) / Qh = fu * CLint となる。したがって、肝クリアランスは fu * CLint に近似できる。選択肢4が正しい。"
#     }
#   },
#   {
#     "問49": {
#       "回答": [
#         5
#       ],
#       "理由": "界面活性剤は、水中で解離した際にイオン性を示す部分の電荷によって分類される。陽イオン性界面活性剤は、親水基部分が陽電荷（プラス）を帯びるもの。選択肢の中で、ベンゼトニウム塩化物は第4級アンモニウム塩であり、水中で陽イオンとなるため、陽イオン性界面活性剤である。ステアリン酸ナトリウムとラウリル硫酸ナトリウムは、カルボキシ基や硫酸エステル基が陰イオンとなるため、陰イオン性界面活性剤。ポリソルベート80はポリオキシエチレン鎖を持ち、非イオン性界面活性剤。レシチンはリン脂質であり、分子内に正電荷と負電荷の両方を持つ両性イオン性界面活性剤。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問50": {
#       "回答": [
#         1
#       ],
#       "理由": "流動層造粒乾燥機は、粉末原料を装置内で空気によって流動させながら、結合剤溶液を噴霧して粒子を凝集・成長させて造粒し、同時に熱風で乾燥までを行うことができる装置である。混合、造粒、乾燥の主要な工程を一つの装置内で完結できるため、工程の短縮やコンタミネーション防止に有利である。他の選択肢の装置（転動造粒機、押出し造粒機、噴霧乾燥造粒機、破砕造粒機）は、通常、混合や乾燥は別の装置や工程で行う必要がある。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問51": {
#       "回答": [
#         2
#       ],
#       "理由": "提示されたレオグラムは、せん断速度を上昇させたとき（上昇曲線）と下降させたとき（下降曲線）で、せん断応力とせん断速度の関係が異なる経路をたどり、ループ（ヒステリシスループ）を描いている。これは、せん断を加えることによって内部構造が破壊されて粘度が低下し、せん断を止めると時間とともに構造が再構築されて粘度が回復する性質を示すものであり、チキソトロピーと呼ばれる現象である。クリープは一定応力下での変形の時間依存性、応力緩和は一定ひずみ下での応力の時間依存性、ダイラタンシーはせん断速度の増加とともに粘度が増加する現象、コアセルベーションは相分離現象である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問52": {
#       "回答": [
#         2
#       ],
#       "理由": "透析用剤は、体内に大量に注入されるため、その安全性、特に発熱性物質の混入がないことが極めて重要である。エンドトキシンは、グラム陰性菌の細胞壁成分であり、強力な発熱性物質であるため、透析液中のエンドトキシン濃度は厳しく管理されなければならない。そのため、日本薬局方の一般試験法であるエンドトキシン試験法が適用される。アルコール数測定法はエタノール濃度、重金属試験法は重金属不純物、制酸力試験法は制酸剤、溶出試験法は固形製剤からの薬物放出性を評価する試験であり、透析用剤の主要な試験法ではない。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問53": {
#       "回答": [
#         1
#       ],
#       "理由": "図は、カプセル内に速放性の顆粒と、放出速度が異なる複数の徐放性顆粒（コーティングの厚みを変えるなどして放出速度を制御）を混合して充填した製剤の模式図である。このような設計により、薬物の放出を持続させ、血中濃度を長時間維持することを目的としている。このタイプの放出制御型カプセル剤は、スパンズル(Spansule)型と呼ばれる。ロンタブ型は有核錠、グラデュメット型は不溶性マトリックス錠、スパスタブ型はワックスマトリックス錠、レジネート型はイオン交換樹脂を利用した製剤である。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問54": {
#       "回答": [
#         3
#       ],
#       "理由": "薬物の直腸からの吸収を改善するために、吸収促進剤が用いられることがある。カプリン酸ナトリウムは、炭素数10の中鎖脂肪酸ナトリウム塩であり、界面活性作用を持つ。直腸粘膜に対する作用により、薬物の透過性を高め、吸収を促進する効果が期待され、坐剤などの吸収改善に用いられることがある。アルギン酸ナトリウムは基剤、安息香酸ナトリウムは保存剤、チオグリコール酸は還元剤（脱毛剤など）、プロカイン塩酸塩は局所麻酔薬である。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問55": {
#       "回答": [
#         1
#       ],
#       "理由": "能動的ターゲティングは、薬物やそのキャリア（リポソームなど）を特定の細胞や組織に選択的に送達する技術である。レクチンは、特定の糖鎖構造を認識して結合するタンパク質の総称であり、細胞表面にも様々なレクチンが存在する。したがって、薬物やキャリアに特定の糖鎖を修飾基として導入することで、標的細胞上のレクチンに認識させて結合させ、選択的な取り込み（ターゲティング）を達成することができる。ポリペプチド、長鎖不飽和脂肪酸、オリゴヌクレオチド、ポリエチレングリコールも修飾に用いられることがあるが、レクチンによる認識機構を利用する場合は糖鎖がリガンドとなる。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問56": {
#       "回答": [
#         2
#       ],
#       "理由": "ドキソルビシンは、アントラサイクリン系の抗悪性腫瘍薬であり、強力な抗がん作用を持つ一方で、用量依存的な心毒性が重大な副作用として知られている。ドキソルビシンは心筋細胞に蓄積し、フリーラジカル産生やミトコンドリア機能障害などを介して心筋細胞の壊死を引き起こし、心筋症やうっ血性心不全を誘発する可能性がある。アミオダロン、エナラプリル、ビソプロロールは心不全治療にも用いられる薬物（副作用に注意は必要）。ピオグリタゾンは糖尿病治療薬で、副作用として心不全のリスクがあるが、直接的な心筋壊死が主たる機序ではない。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問57": {
#       "回答": [
#         2
#       ],
#       "理由": "デキストラン硫酸を固定化したカラムを用いたアフェレシス（LDL吸着療法など）では、血液が体外循環中にデキストラン硫酸と接触する。デキストラン硫酸は負に荷電しており、血液凝固系のカリクレイン-キニン系を活性化し、ブラジキニンの産生を促進する可能性がある。一方、ACE（アンジオテンシン変換酵素）阻害薬（例：エナラプリルマレイン酸塩）は、ブラジキニンの分解を抑制する作用を持つ。そのため、デキストラン硫酸を用いたアフェレシス施行中にACE阻害薬を投与すると、血中のブラジキニン濃度が急激に上昇し、アナフィラキシー様症状（血圧低下、ショックなど）を引き起こす危険性が高いため、投与は禁忌とされている。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問58": {
#       "回答": [
#         4
#       ],
#       "理由": "WPW (Wolff-Parkinson-White) 症候群は、心房と心室の間に正常な房室結節（刺激伝導を遅らせる）を迂回する副伝導路（ケント束）が存在する先天性の疾患である。この副伝導路を通って心房からの興奮が心室へ早期に伝わるため、心室の早期興奮が生じる。心電図上では、PQ時間の短縮とデルタ波（QRS波の立ち上がりのなまり）が特徴的である。Adams-Stokes症候群は徐脈性不整脈による失神、Brugada症候群やQT延長症候群は致死性不整脈のリスク、洞不全症候群は洞結節の機能不全である。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問59": {
#       "回答": [
#         1
#       ],
#       "理由": "急性心筋梗塞(AMI)は、冠動脈の閉塞により心筋への血流が途絶え、心筋が壊死する疾患である。多くの場合、冠動脈内のアテローム硬化プラークの破綻とそれに伴う血栓形成が原因となる。AMIの初期治療では、心筋壊死の範囲を最小限に抑えるために、可及的速やかに冠動脈の再灌流（血流再開）を図るとともに、血栓の拡大や再閉塞を予防することが重要である。アスピリンは、血小板のシクロオキシゲナーゼを阻害してトロンボキサンA₂の産生を抑制し、血小板凝集を抑制する抗血小板薬であり、AMIの初期治療において不可欠な薬剤の一つである。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問60": {
#       "回答": [
#         3
#       ],
#       "理由": "重症筋無力症(MG)は、神経筋接合部におけるアセチルコリン受容体に対する自己抗体によって、神経から筋肉への信号伝達が障害される自己免疫疾患である。主な症状は、骨格筋の易疲労性（反復運動や時間の経過とともに筋力が低下し、休息により回復する）と筋力低下である。特に、眼瞼下垂や複視（物が二重に見える）といった眼症状が高頻度にみられ、初期症状となることも多い。また、嚥下障害、構音障害、四肢の筋力低下なども起こりうる。したがって、選択肢3の嚥下障害はMGで認められる症状である。（他の選択肢：突発性発熱、前向性健忘、振戦、構音障害はMGの典型的症状ではないか、嚥下障害の方がより代表的）"
#     }
#   },
#   {
#     "問61": {
#       "回答": [
#         1
#       ],
#       "理由": "喀血とは、気道（喉頭、気管、気管支、肺）からの出血が、咳とともに排出されることである。気管支拡張症は、気管支壁の破壊と不可逆的な拡張を特徴とする疾患であり、拡張した気管支壁には異常な血管新生が見られることがある。これらの血管は脆弱で破れやすく、喀血の原因となる。出血性腸炎、くも膜下出血、胃潰瘍、食道逆流症は、それぞれ消化管、脳、消化管、消化管の疾患であり、喀血ではなく、吐血、下血、脳出血などを引き起こす。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問62": {
#       "回答": [
#         3
#       ],
#       "理由": "痛風発作は、関節内に析出した尿酸ナトリウム結晶に対する急性の炎症反応であり、激しい痛みを伴う関節炎を引き起こす。痛風発作の治療の目的は、この急性の炎症と痛みを速やかに鎮静化することである。治療薬としては、非ステロイド性抗炎症薬(NSAIDs)、コルヒチン、副腎皮質ステロイドが用いられる。ナプロキセンはNSAIDsの一つであり、痛風発作の治療に適応がある。アロプリノールやフェブキソスタットなどの尿酸降下薬は、発作時には原則として新規に開始したり増量したりしない（炎症を増悪させる可能性があるため）。ラスブリカーゼは腫瘍崩壊症候群など、クエン酸カリウム・クエン酸ナトリウムは尿路結石予防などに用いる。ダパグリフロジンは糖尿病治療薬。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問63": {
#       "回答": [
#         1
#       ],
#       "理由": "慢性甲状腺炎（橋本病）は、甲状腺に対する自己免疫反応によって甲状腺組織が破壊され、甲状腺機能低下症を引き起こす代表的な自己免疫疾患である。診断においては、甲状腺腫大や甲状腺機能低下の所見に加え、自己抗体の検出が重要となる。橋本病に特異的な自己抗体として、抗甲状腺ペルオキシダーゼ(TPO)抗体と抗サイログロブリン抗体がある。これらの抗体が陽性であれば、橋本病の診断的価値が高い。抗TSH受容体抗体はバセドウ病、抗GAD抗体は1型糖尿病、抗アセチルコリン受容体抗体は重症筋無力症、抗CCP抗体は関節リウマチで陽性となることが多い。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問64": {
#       "回答": [
#         2
#       ],
#       "理由": "シクロスポリンは、カルシニューリン阻害薬であり、T細胞の活性化を抑制する免疫抑制薬である。その点眼液は、眼のアレルギー性疾患や炎症性疾患の治療に用いられる。特に、アトピー性角結膜炎や春季カタルといった、難治性のアレルギー性結膜疾患において、ステロイド抵抗性または依存性の症例に対して有効性が示されている。白内障、感染性角膜炎、加齢黄斑変性、緑内障は、シクロスポリン点眼液の主な適応疾患ではない。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問65": {
#       "回答": [
#         1
#       ],
#       "理由": "感染症の伝播経路には、接触感染、飛沫感染、空気感染（飛沫核感染）、媒介物感染などがある。空気感染は、感染者の咳やくしゃみなどによって放出された病原体を含む微粒子（飛沫核、5μm以下）が、空気中に長時間浮遊し、それを吸い込むことによって感染する経路である。空気感染する代表的なウイルス感染症として、麻疹（はしか）、水痘（みずぼうそう）、結核（細菌感染症だが）が挙げられる。風しん、流行性耳下腺炎（ムンプス）、インフルエンザは主に飛沫感染。HIV感染症は血液・体液感染。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問66": {
#       "回答": [
#         1
#       ],
#       "理由": "播種性血管内凝固症候群(DIC)は、様々な基礎疾患により、全身の細小血管内で微小血栓が多発し、凝固因子と血小板が過剰に消費される病態である。その結果、凝固系の亢進と抑制（消費による）、線溶系の亢進が同時に起こる。検査所見としては、①血小板数の減少、②フィブリノーゲンの減少、③プロトロンビン時間(PT)および活性化部分トロンボプラスチン時間(APTT)の延長、④フィブリン/フィブリノーゲン分解産物(FDP)およびD-ダイマーの増加、⑤アンチトロンビンの減少などが認められる。選択肢1のアンチトロンビンの減少はDICで認められる所見である。選択肢2はFDPの減少（正しくは増加）、選択肢3は血小板数の増加（正しくは減少）、選択肢4はプラスミノゲンの増加（正しくは消費により減少傾向）、選択肢5はPTの短縮（正しくは延長）であり、誤り。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問67": {
#       "回答": [
#         4
#       ],
#       "理由": "特発性肺線維症(IPF)は、原因不明の進行性の肺線維化を特徴とする予後不良な間質性肺炎である。IPFの治療薬として、病態の進行を抑制する効果が認められている抗線維化薬が用いられる。現在、IPFに適応を持つ抗線維化薬として、ピルフェニドンとニンテダニブがある。選択肢の中ではピルフェニドンが該当する。アペマシクリブ、ゲフィチニブ、ブレオマイシンは抗悪性腫瘍薬。インターフェロンアルファは抗ウイルス薬や抗腫瘍薬として用いられる。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問68": {
#       "回答": [
#         3
#       ],
#       "理由": "胆石症による疝痛発作は、胆嚢や胆管の平滑筋が痙攣することによって引き起こされる激しい痛みである。疼痛緩和のためには、鎮痛薬とともに、平滑筋の痙攣を抑える鎮痙薬が用いられる。ブチルスコポラミン臭化物は、抗コリン作用を持つ鎮痙薬であり、消化管や胆道系の平滑筋を弛緩させる作用があるため、胆石疝痛の治療に用いられる。ウルソデオキシコール酸は胆石溶解薬であり、発作時の対症療法ではない。エストラジオールはホルモン剤、ベザフィブラートは脂質異常症治療薬。モルヒネは強力な鎮痛薬だが、Oddi括約筋を収縮させる作用があるため、胆石疝痛には慎重に使用される。NSAIDsも鎮痛目的で用いられる。選択肢の中では、鎮痙薬であるブチルスコポラミン臭化物が最も適切と考えられる。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問69": {
#       "回答": [
#         4
#       ],
#       "理由": "医薬品情報源は、情報の種類や加工の程度によって、一次資料、二次資料、三次資料に分類される。一次資料は、オリジナルの研究成果や報告が直接記載されたものであり、学術雑誌に掲載された原著論文などが代表例である。二次資料は、一次資料を検索しやすいように整理・加工したもので、索引誌や抄録誌（例: PubMed, MEDLINE, 医中誌Web）などが該当する。三次資料は、一次資料や二次資料から情報を収集・評価・要約して作成されたもので、教科書、レビュー論文、ガイドライン、医薬品添付文書、医薬品インタビューフォームなどが含まれる。したがって、一次資料は原著論文である。選択肢4が正しい。"
#     }
#   },
#   {
#     "問70": {
#       "回答": [
#         1
#       ],
#       "理由": "レジオネラ・ニューモフィラは、細胞内寄生性細菌であり、レジオネラ肺炎を引き起こす。細胞内に侵入して増殖するため、治療には細胞内移行性の高い抗菌薬が必要となる。レジオネラ肺炎に対して有効性が高いとされる抗菌薬は、ニューキノロン系（レボフロキサシン、シプロフロキサシン、モキシフロキサシンなど）、マクロライド系（アジスロマイシン、エリスロマイシンなど）、およびリファンピシンである。選択肢の中では、シプロフロキサシンがニューキノロン系抗菌薬であり、レジオネラ肺炎に対して有効性が期待できる。タゾバクタム・ピペラシリン、メロペネム、アミカシン、バンコマイシンは、レジオネラに対する抗菌活性が低いか、細胞内移行性が悪いため、通常は第一選択とはならない。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問71": {
#       "回答": [
#         2
#       ],
#       "理由": "薬剤師法第9条第1項に基づき、薬剤師は、厚生労働省令で定める2年ごとの年の12月31日現在における氏名、住所その他厚生労働省令で定める事項を、翌年1月15日までに、その住所地の都道府県知事を経由して厚生労働大臣に届け出なければならない。薬剤師法施行規則第6条で定められている届出事項には、氏名、生年月日、性別、登録番号・年月日、住所、従事場所、業務種別などが含まれる。選択肢の中では住所が該当する。個人番号（マイナンバー）、認定薬剤師の資格、国家試験合格の年、再教育研修の受講の有無は、この届出事項には含まれていない。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問72": {
#       "回答": [
#         3
#       ],
#       "理由": "医薬品、医療機器等の品質、有効性及び安全性の確保等に関する法律（医薬品医療機器等法）において、薬局で購入できる医薬品は、処方箋に基づいて調剤される「医療用医薬品」と、処方箋なしで購入できる「要指導医薬品」および「一般用医薬品」に大別される。同法第36条の10第1項では、「薬局医薬品」の定義として「要指導医薬品及び一般用医薬品以外の医薬品（専ら動物のために使用されることが目的とされているものを除く。）をいう。」と規定されている。これは実質的に医療用医薬品を指している。しかし、問題文の「薬局医薬品」が、薬局で取り扱う医薬品全体を指し、その分類として「要指導医薬品」と「A」と「それ以外の医薬品（医療用医薬品）」がある、という文脈で解釈すると、Aには「一般用医薬品」が入る。設問の「『薬局医薬品』とは、『要指導医薬品及び【A】以外の医薬品をいう。』」という定義は、法第36条の10第1項の定義そのものであり、この文脈では「薬局医薬品」＝「医療用医薬品」を指すため、Aには「一般用医薬品」が入る。したがって、選択肢3が正しい。"
#     }
#   },
#   {
#     "問73": {
#       "回答": [
#         2
#       ],
#       "理由": "医薬品の製造販売承認申請のために行われる非臨床試験（動物を用いた毒性試験、薬理試験、薬物動態試験など）の信頼性を確保するための基準として、「医薬品の安全性に関する非臨床試験の実施の基準に関する省令」（GLP省令）が定められている。GLP (Good Laboratory Practice) は、試験施設、操作手順、記録、報告などに関する基準を定めており、試験結果の信頼性を保証するものである。GCP (Good Clinical Practice) は臨床試験（治験）の基準、GMP (Good Manufacturing Practice) は医薬品の製造管理・品質管理基準、GQP (Good Quality Practice) は医薬品の品質管理基準、GVP (Good Vigilance Practice) は製造販売後安全管理基準である。したがって、一般毒性試験の実施に際して遵守すべき基準はGLPである。選択肢2が正しい。"
#     }
#   },
#   {
#     "問74": {
#       "回答": [
#         1
#       ],
#       "理由": "毒物及び劇物取締法第12条第1項及び同法施行規則第11条により、毒物を収めた容器及び被包には、「医薬用外」の文字と、「毒物」の文字を表示しなければならないと定められている。さらに、「毒物」の文字の表示方法として、「地は白色、文字は赤色」と規定されている。したがって、白地に赤色をもって「毒物」の文字を表示する必要がある。選択肢1が正しい。"
#     }
#   },
#   {
#     "問75": {
#       "回答": [
#         5
#       ],
#       "理由": "医薬品副作用被害救済制度は、医薬品を適正に使用したにもかかわらず発生した副作用による健康被害（入院治療が必要な程度の疾病や障害など）を受けた人に対して、医療費、障害年金、遺族年金などの給付を行う公的な制度である。この制度に基づく給付の請求は、健康被害を受けた本人またはその遺族が、独立行政法人医薬品医療機器総合機構(PMDA)に対して行う。PMDAが請求内容を審査・判定し、その結果に基づき厚生労働大臣が給付の可否を決定し、PMDAが給付業務を実施する。したがって、図中のA、すなわち健康被害者が給付を請求する先は、独立行政法人医薬品医療機器総合機構(PMDA)である。選択肢5が正しい。"
#     }
#   },
#   {
#     "問76": {
#       "回答": [
#         2
#       ],
#       "理由": "保険診療と保険外診療の併用（混合診療）は原則として禁止されているが、例外的に認められているものとして「保険外併用療養費」制度がある。これには「評価療養」と「選定療養」が含まれる。評価療養は、将来的に保険適用とするかどうかの評価を行うものであり、先進医療や、医薬品・医療機器の治験に係る診療、薬事承認後で保険収載前の医薬品・医療機器の使用などが該当する。選定療養は、患者の選択によるもので、特別の療養環境（差額ベッド）、予約診療、時間外診療、紹介状なしでの大病院受診などが該当する。出産（正常分娩）は原則として保険適用外である。したがって、評価療養の対象となるのは、医薬品の治験に係る診療である。選択肢2が正しい。"
#     }
#   },
#   {
#     "問77": {
#       "回答": [
#         1
#       ],
#       "理由": "介護保険制度において、第2号被保険者（40歳以上65歳未満の医療保険加入者）が要介護（要支援）認定を受けることができるのは、老化に起因する特定の疾病（特定疾病）が原因である場合に限られる。特定疾病は、がん（末期）、関節リウマチ、筋萎縮性側索硬化症(ALS)、後縦靱帯骨化症、骨折を伴う骨粗鬆症、初老期における認知症、進行性核上性麻痺・大脳皮質基底核変性症・パーキンソン病、脊髄小脳変性症、脊柱管狭窄症、早老症、多系統萎縮症、糖尿病性神経障害・腎症・網膜症、脳血管疾患、閉塞性動脈硬化症、慢性閉塞性肺疾患(COPD)、両側の膝関節又は股関節に著しい変形を伴う変形性関節症の16種類が定められている。選択肢の中では、関節リウマチが特定疾病に該当する。結核、C型肝炎、高血圧症、脂質異常症は特定疾病ではない。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問78": {
#       "回答": [
#         1
#       ],
#       "理由": "ジュネーブ宣言は、1948年に世界医師会(WMA)で採択された、現代における医師の倫理規範を示す宣言であり、「ヒポクラテスの誓い」の現代版とされる。その内容は、医師が専門職としての責務を果たす上での倫理的な原則を述べたものであり、患者の健康と福祉を第一に考えること、患者の秘密を守ること、人種・宗教・国籍・社会的地位などによって差別しないことなどが盛り込まれている。宣言全体を通じて、患者の利益と尊厳を守ることが医師の最も重要な義務であることが強調されており、その根幹は「患者の権利」や「患者の最善の利益」を尊重する姿勢にあると言える。生命倫理の4原則や医師の遵守すべき倫理も関連するが、宣言の核心は患者中心の倫理である。したがって、選択肢1が最も適切である。"
#     }
#   },
#   {
#     "問79": {
#       "回答": [
#         2
#       ],
#       "理由": "1980年代後半以降、脳外科手術などで用いられたヒト乾燥硬膜（ライオデュラなど）を介して、プリオン病であるクロイツフェルト・ヤコブ病(CJD)に感染する事例が世界的に多発し、日本でも多数の患者が発生した。この薬害CJD問題は、生物由来の原料を用いた医薬品や医療機器の安全性確保の重要性を改めて認識させ、その後の安全対策強化や、被害者救済制度の整備につながった。生物由来製品感染等被害救済制度は、薬害エイズや薬害CJDなどの教訓を踏まえ、生物由来製品による感染被害者の迅速な救済を図るために創設された。したがって、乾燥硬膜による感染で制度創設の契機となったのはクロイツフェルト・ヤコブ病である。選択肢2が正しい。"
#     }
#   },
#   {
#     "問80": {
#       "回答": [
#         2
#       ],
#       "理由": "傾聴は、相手の話を注意深く、共感的に聴くコミュニケーション技法であり、円滑な人間関係の構築に不可欠である。傾聴の基本的な技能や態度には、受容（相手を評価せず受け入れる）、共感（相手の感情を理解しようとする）、繰り返し（相手の言葉を繰り返す）、言い換え、要約、質問、そして非言語的な要素（相槌、うなずき、視線、姿勢など）が含まれる。ミラーリングは、相手の言葉や感情、非言語的なしぐさなどを鏡のように模倣したり、繰り返したりする技法であり、相手への共感や理解を示す効果があるとされる。ブロッキングは話を遮ること、エンコーディングは話し手側の情報記号化、パターナリズムは一方的な指導的態度、デコーディングは聞き手側の情報解読であり、傾聴の技法・態度としてはミラーリングが適切である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問81": {
#       "回答": [
#         5
#       ],
#       "理由": "イコサペント酸エチル(EPA)は、ω-3系多価不飽和脂肪酸であり、血中の中性脂肪を低下させる作用のほか、血小板凝集抑制作用を持つ。そのため、血液を固まりにくくし、出血傾向を助長する可能性がある。特に、抗凝固薬や他の抗血小板薬と併用する場合には注意が必要である。センノシドは刺激性下剤、ロペラミド塩酸塩は止瀉薬、ミノキシジルは血管拡張作用を持つ発毛剤、フェキソフェナジン塩酸塩は抗ヒスタミン薬であり、これらは直接的な出血リスクの増加とは関連が薄い。したがって、出血傾向に最も注意が必要なのはイコサペント酸エチルである。選択肢5が正しい。"
#     }
#   },
#   {
#     "問82": {
#       "回答": [
#         4
#       ],
#       "理由": "薬剤の服用時点は、薬物動態や薬力学的な特性、食事の影響などを考慮して決められる。食前服用が指示される薬剤には、食事によって吸収が低下するもの（一部の抗菌薬など）、食後の血糖上昇を抑える目的の薬剤（α-GI、速効型インスリン分泌促進薬など）、胃酸の影響を避けるもの、食前に効果を発揮させたいもの（一部の消化機能改善薬など）がある。選択肢の中で、エパルレスタットはアルドース還元酵素阻害薬であり、糖尿病性末梢神経障害に用いられる。食事による吸収への影響は少ないとされるが、食後の高血糖に伴うソルビトール蓄積を抑制する目的で、通常、毎食前に服用する。セレコキシブ(NSAIDs)、イマチニブ(分子標的薬)、メナテトレノン(ビタミンK₂)、イトラコナゾール(抗真菌薬)は、一般的に食後または食直後に服用されることが多い。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問83": {
#       "回答": [
#         2
#       ],
#       "理由": "居宅療養管理指導は、通院が困難な在宅患者に対して、医師、歯科医師、薬剤師、管理栄養士などが居宅を訪問して療養上の管理や指導を行う介護保険サービスである。薬剤師が行う居宅療養管理指導では、服薬管理、副作用モニタリング、薬に関する相談・指導などを行う。ケアプラン（居宅サービス計画）は、利用者の心身の状況や希望に基づき、必要なサービスの種類や内容を定めた計画であり、主に介護支援専門員（ケアマネジャー）が作成する。薬剤師は、ケアプラン作成に必要な情報（患者の服薬状況、薬学的評価、副作用リスク、服薬に関する留意点など）を、介護支援専門員に提供する義務がある。これにより、多職種が連携して適切なケアを提供することが可能となる。したがって、情報提供しなければならない職種は介護支援専門員である。選択肢2が正しい。"
#     }
#   },
#   {
#     "問84": {
#       "回答": [
#         1
#       ],
#       "理由": "災害派遣医療チーム(DMAT: Disaster Medical Assistance Team)は、大規模な災害や事故が発生した際に、被災地に迅速に駆けつけ、災害急性期（概ね発災から48時間以内）に救命医療を中心とした医療活動を行う専門的な訓練を受けた医療チームである。DMATの主な活動内容は、①現場での情報収集と伝達、②トリアージ（傷病者の重症度・緊急度判定と選別）、③現場や域内搬送拠点での応急治療、④患者の広域医療搬送などである。これらの活動の中で、限られた医療資源を最大限に活用し、一人でも多くの命を救うためのトリアージと、それに基づく応急治療や搬送の判断・実施が最も優先されるべき活動である。広域医療搬送対象患者の選出は、トリアージと搬送判断の中核となる活動である。PTSDの診療や長期的な医療支援、一般用医薬品の販売、復興支援は、急性期以降の活動や他の組織の役割となる。したがって、選択肢1が正しい。"
#     }
#   },
#   {
#     "問85": {
#       "回答": [
#         5
#       ],
#       "理由": "透析療法を受けている患者は、腎機能が著しく低下しているため、腎臓から排泄される薬物や、体内に蓄積しやすいミネラル成分の投与には注意が必要である。特に、マグネシウムやアルミニウムを含む製剤は、体内に蓄積して高マグネシウム血症やアルミニウム骨症・脳症などの重篤な副作用を引き起こすリスクがあるため、原則として避けるべきである。スクラルファートは、消化性潰瘍治療薬であり、その成分にアルミニウムが含まれているため、透析患者への投与は禁忌または慎重投与とされていることが多い。一般用医薬品としてもアルミニウムを含む胃腸薬などが存在するため、販売時には注意が必要である。ロペラミド塩酸塩（止瀉薬）、テプレノン（胃粘膜保護薬）、乾燥酵母（整腸薬、ただしリン含有に注意）、トリメブチンマレイン酸塩（消化管運動調整薬）は、アルミニウムやマグネシウムを含まないが、個々の患者の状態に応じて医師への相談が推奨される。したがって、販売を避けるべき成分としてスクラルファートが挙げられる。選択肢5が正しい。"
#     }
#   },
#   {
#     "問86": {
#       "回答": [
#         5
#       ],
#       "理由": "学校薬剤師は、学校保健安全法に基づき、学校における保健管理に関する専門的事項に関し、技術及び指導に従事する。その職務内容は、学校保健安全法施行規則第24条に定められており、主に①学校環境衛生（教室等の空気、飲料水、プール水、給食施設、排水などの検査や指導助言）、②医薬品その他環境衛生に関する物資及び用具の管理に関する指導助言、③健康相談、④保健指導（薬物乱用防止教育、感染症予防、アレルギー対応など）である。保健室内での調剤、医薬品の販売、ワクチンの投与は医師や看護師の業務であり、学校薬剤師の職務ではない。土壌の放射能汚染検査は専門機関が行う。薬物乱用防止のための教育は、学校薬剤師の重要な職務の一つである。したがって、選択肢5が正しい。"
#     }
#   },
#   {
#     "問87": {
#       "回答": [
#         4
#       ],
#       "理由": "周術期（手術前後）は、手術侵襲や術後の安静臥床などにより、静脈血栓塞栓症（深部静脈血栓症や肺血栓塞栓症）のリスクが高まる時期である。薬剤の中には、血液凝固能を亢進させ、血栓塞栓症のリスクをさらに高めるものがある。特に、エストロゲン（卵胞ホルモン）を含む薬剤（経口避妊薬やホルモン補充療法薬）は、凝固因子を増加させ、線溶系を抑制する作用があり、血栓リスクを有意に上昇させることが知られている。ドロスピレノン・エチニルエストラジオールは、黄体ホルモン（ドロスピレノン）と卵胞ホルモン（エチニルエストラジオール）の配合剤であり、経口避妊薬として用いられる。したがって、この薬剤は周術期の血栓塞栓症リスクを最も高める可能性がある。メトホルミン、サクビトリルバルサルタン、ダパグリフロジン、セマグルチドは、主に糖尿病や心不全の治療薬であり、血栓リスクを直接的に高める作用は知られていない。したがって、選択肢4が正しい。"
#     }
#   },
#   {
#     "問88": {
#       "回答": [
#         4
#       ],
#       "理由": "CTCAE (Common Terminology Criteria for Adverse Events) は、米国国立がん研究所(NCI)が作成・公開している、がん治療などの臨床試験において発生する有害事象（副作用）の重症度（グレード）を、客観的かつ統一的に評価・記録するための基準である。グレード1（軽症）からグレード5（死亡）までの5段階で評価される。臨床試験だけでなく、市販後の安全性評価など、医学研究や診療において広く用いられている。したがって、CTCAEが用いられる指標は、医薬品による有害事象の重症度である。選択肢4が正しい。"
#     }
#   },
#   {
#     "問89": {
#       "回答": [
#         3
#       ],
#       "理由": "医薬品医療機器等法第68条の10に基づき、医薬関係者（医師、歯科医師、薬剤師など）は、医薬品の副作用によるものと疑われる健康被害の発生を知った場合、厚生労働大臣（実際にはPMDA）に報告することが求められている（医薬品安全性情報報告制度）。報告書に記載すべき項目は、報告様式で定められており、①患者に関する情報（イニシャル、年齢、性別など、個人を特定できない範囲で）、②副作用に関する情報（症状、発現日、転帰、重篤度、因果関係評価など）、③被疑薬に関する情報（医薬品名、投与量、投与期間、投与理由など）、④報告者に関する情報などが含まれる。患者のプライバシー保護のため、氏名は記載しない。副作用の発現期間は重要な情報である。患者の生年月日も年齢確認のために記載されることが多い。家族の副作用歴や被疑薬の製造番号は、必須項目ではない場合が多いが、関連性が疑われる場合には記載が推奨される。したがって、記載項目として必須または重要なのは、患者の生年月日、副作用の発現期間である。選択肢の中で必須項目として挙げられるのは、患者の生年月日と副作用の発現期間。問題は「記載項目はどれか」であり、複数正解の可能性もあるが、一般的に副作用報告で必須とされる情報として、患者の生年月日(1)と副作用の発現期間(3)が挙げられる。しかし、1つ選ぶ形式であれば、副作用の詳細な経過を示す「副作用の発現期間」がより重要と考えられる場合もあるし、患者を識別するための「生年月日」も重要。ここでは、副作用の具体的な状況を示す「副作用の発現期間」を選択する。ただし、生年月日も記載項目である。設問の意図を汲み、最も基本的な患者情報である生年月日を選択する。いや、副作用報告において、いつからいつまで副作用が続いたかという「発現期間」は極めて重要な情報である。生年月日も重要だが、副作用自体の情報として発現期間は欠かせない。よって3を選択する。"
#     }
#   },
#   {
#     "問90": {
#       "回答": [
#         2
#       ],
#       "理由": "腫瘍崩壊症候群(TLS: Tumor Lysis Syndrome)は、化学療法や放射線治療などにより感受性の高い腫瘍細胞が急速に破壊され、細胞内の成分（カリウム、リン、核酸など）が大量に血液中に放出されることによって生じる代謝異常の総称である。放出された核酸は代謝されて尿酸となり、高尿酸血症を引き起こす。高尿酸血症は、尿酸結晶の析出による急性腎障害（尿酸腎症）の原因となる。TLSの予防および治療においては、十分な輸液による体液管理とともに、高尿酸血症対策が重要となる。高尿酸血症の予防・治療には、尿酸生成抑制薬であるキサンチンオキシダーゼ阻害薬（アロプリノール、フェブキソスタット）や、尿酸分解酵素製剤（ラスブリカーゼ）が用いられる。選択肢の中では、フェブキソスタットが該当する。ウルソデオキシコール酸は胆汁酸製剤、メトトレキサートは抗がん剤・免疫抑制薬、ラモセトロン塩酸塩は制吐薬、タクロリムスは免疫抑制薬である。したがって、選択肢2が正しい。"
#     }
#   },
#   {
#     "問91": {
#       "回答": [
#         1,
#         2
#       ],
#       "理由": "熱力学第一法則 ΔU = Q + W (W: 系がされた仕事) または ΔU = Q - W' (W': 系がした仕事) に基づいて判断する。\n1. 理想気体の定温過程では内部エネルギー変化 ΔU = 0。よって Q = -W = W' となり、系に加えられた熱量は系がする仕事に等しい。正しい。\n2. 熱力学第一法則の定義 ΔU = Q + W そのものである。Q は系に加えられた熱量、W は系がされた仕事。正しい。\n3. 断熱過程では Q = 0。ΔU = W。体積が増加する場合、系は外部に仕事をする (W' > 0) ため、系がされる仕事 W は負 (W < 0)。よって ΔU < 0 となり、内部エネルギーは減少する。誤り。\n4. 内部エネルギー U は状態量であり、経路に依存しない。熱 Q と仕事 W は経路関数である。誤り。\n5. 系が外部に対してする仕事は、可逆過程において最大となる。不可逆過程での仕事は可逆過程より小さい。誤り。"
#     }
#   },
#   {
#     "問92": {
#       "回答": [
#         1,
#         4
#       ],
#       "理由": "ファントホッフの式は d(ln K)/d(1/T) = -ΔH°/R で表され、ln K を 1/T に対してプロットすると直線関係が得られる (ΔH° と ΔS° が温度によらず一定と仮定した場合)。\n1. 横軸に温度の逆数 (1/T)、縦軸に平衡定数の自然対数 (ln K) をプロットしたものがファントホッフプロットである。正しい。\n2. プロットの式は ln K = (-ΔH°/R)(1/T) + (ΔS°/R)。傾きは -ΔH°/R、切片 (1/T = 0 の外挿値) は ΔS°/R である。切片からは標準反応エントロピー ΔS° が求まり、傾きから標準反応エンタルピー ΔH° が求まる。誤り。\n3. 傾き (-ΔH°/R) からは標準反応エンタルピー ΔH° が求まる。誤り。\n4. 吸熱反応では ΔH° > 0。したがって、傾き -ΔH°/R は負となる。正しい。\n5. 傾きが正 (-ΔH°/R > 0) ということは、ΔH° < 0 (発熱反応) である。温度が上がる (T が増加する、1/T が減少する) と、ln K は傾きが正なので減少する。つまり平衡定数は小さくなる。誤り。"
#     }
#   },
#   {
#     "問93": {
#       "回答": [
#         3
#       ],
#       "理由": "ボルツマン分布によると、エネルギー準位 E₁ にある分子数 N₁ とエネルギー準位 E₂ にある分子数 N₂ の比 R = N₂/N₁ は、R = exp(-(E₂ - E₁)/kT) = exp(-ΔE/kT) で与えられる。ここで k はボルツマン定数、T は絶対温度、ΔE = E₂ - E₁ はエネルギー差である。\nΔE = 0 のとき、R = exp(0) = 1 となる。\nΔE が増加すると、指数部分 -ΔE/kT は負の方向に大きくなるため、R は指数関数的に減少し、0 に漸近する。\nしたがって、グラフは ΔE = 0 で R = 1 となり、ΔE の増加とともに指数関数的に減少する曲線を描く。選択肢3のグラフがこの関係を正しく表している。"
#     }
#   },
#   {
#     "問94": {
#       "回答": [
#         1,
#         2
#       ],
#       "理由": "ミカエリス・メンテン式 v = Vmax[S] / (Km + [S]) に関する記述を評価する。\n1. 酵素反応速度 v は、生成物 P の濃度増加速度 d[P]/dt、または基質 S の濃度減少速度 -d[S]/dt として定義される。正しい。\n2. ミカエリス・メンテン式は、酵素基質複合体 ES の濃度が時間的に変化しないという定常状態近似 (d[ES]/dt = 0) を用いて導出される。この近似のもとでの反応速度が v である。正しい。\n3. [S] = 2Km をミカエリス・メンテン式に代入すると、v = Vmax(2Km) / (Km + 2Km) = Vmax(2Km) / (3Km) = (2/3)Vmax となる。1/4 Vmax ではない。誤り。\n4. Km はミカエリス定数であり、複数の速度定数 (k₁, k₋₁, k₂) から構成される (Km = (k₋₁ + k₂)/k₁)。速度定数は温度に依存するため (アレニウスの式など)、Km も温度に依存する。誤り。\n5. Km は酵素と基質の親和性の指標として用いられることがある。Km が小さいほど、低い基質濃度で反応速度が Vmax/2 に達することを意味し、一般に酵素と基質の親和性が高いことを示す。記述は逆。誤り。"
#     }
#   },
#   {
#     "問95": {
#       "回答": [
#         1,
#         3
#       ],
#       "理由": "⁹⁹Mo/⁹⁹ᵐTc ジェネレーターに関する記述を評価する。⁹⁹Mo (親核種、半減期 T₁ ≈ 66 h) は β⁻ 壊変して ⁹⁹ᵐTc (娘核種、半減期 T₂ ≈ 6 h) になる。\n1. 放射平衡は親核種の半減期 T₁ が娘核種の半減期 T₂ より長い (T₁ > T₂) 場合に起こる。特に T₁ が T₂ より「十分長い」(T₁ >> T₂) 場合を永続平衡、T₁ は T₂ より長いが差がそれほど大きくない場合を過渡平衡という。⁹⁹Mo/⁹⁹ᵐTc は T₁ > T₂ なので放射平衡（特に過渡平衡）が成り立つ。記述は永続平衡の条件に近いが、広義の放射平衡の成立条件 (T₁ > T₂) を含むと解釈すれば正しい。\n2. ⁹⁹Mo と ⁹⁹ᵐTc の半減期比は約 11 であり、「十分長い」とは言えないため、永続平衡ではなく過渡平衡が成り立つ。誤り。\n3. ⁹⁹ᵐTc の「m」は準安定核異性体 (metastable isomer) を意味する。⁹⁹ᵐTc はガンマ線放出を伴う核異性体転移 (IT) によって、より安定な ⁹⁹Tc に壊変する。正しい。\n4. ミルキングとは、ジェネレーターから娘核種 (⁹⁹ᵐTc) を溶出液で選択的に回収する操作のこと。親核種 (⁹⁹Mo) を溶出するのではない。誤り。\n5. ⁹⁹Mo/⁹⁹ᵐTc ジェネレーターのカラム担体には通常、アルミナ (Al₂O₃) が用いられる。Tl 添加 NaI 単結晶は放射線検出器（シンチレーター）の材料。誤り。"
#     }
#   },
#   {
#     "問96": {
#       "回答": [
#         4
#       ],
#       "理由": "最終的なアンモニア水溶液の pH から逆算して、最初に採取した 28% アンモニア水の体積を求める。\n1. 最終溶液のアンモニア濃度 C の計算：pH = 11.0 より pOH = 14.0 - 11.0 = 3.0。[OH⁻] = 10⁻³·⁰ mol/L。アンモニアの塩基解離平衡 NH₃ + H₂O ⇄ NH₄⁺ + OH⁻ において、Kb = [NH₄⁺][OH⁻] / [NH₃] = 1.7 × 10⁻⁵。解離度 α が小さいと仮定し、[NH₄⁺] ≈ [OH⁻] = 10⁻³、[NH₃] ≈ C とすると、Kb ≈ (10⁻³)² / C。C ≈ 10⁻⁶ / (1.7 × 10⁻⁵) ≈ 0.0588 mol/L。\n2. 中間溶液 (500 mL に希釈後) の濃度 C' の計算：最終溶液は中間溶液 20 mL を 1000 mL に希釈したものなので、希釈倍率は 1000/20 = 50 倍。C' = C × 50 ≈ 0.0588 mol/L × 50 ≈ 2.94 mol/L。\n3. 28% アンモニア水 (比重 0.90) のモル濃度 C₀ の計算：1 L (1000 mL) の質量は 1000 mL × 0.90 g/mL = 900 g。含まれる NH₃ (分子量 17) の質量は 900 g × 0.28 = 252 g。モル数は 252 g / 17 g/mol ≈ 14.82 mol。よって C₀ ≈ 14.82 mol/L。\n4. 採取した体積 V (mL) の計算：採取したアンモニア水 V mL を 500 mL に希釈して中間溶液としたので、モル数について (V/1000) × C₀ = (500/1000) × C' が成り立つ。V × 14.82 = 500 × 2.94。V = (500 × 2.94) / 14.82 ≈ 1470 / 14.82 ≈ 99.2 mL。\n5. 最も近い選択肢：計算結果は約 99.2 mL なので、選択肢の中で最も近いのは 100 mL。"
#     }
#   },
#   {
#     "問97": {
#       "回答": [
#         2
#       ],
#       "理由": "純度試験における芳香族第一アミンの許容限度を計算する。\n1. 測定溶液の調製：試料 0.20 g から最終的に 50 mL の測定溶液を調製。\n2. 吸光度の許容限度：A ≤ 0.15 (波長 485 nm, 層長 l = 1 cm)。\n3. 比吸光度：E¹%₁cm = 475。\n4. ランベルト・ベールの法則の応用：A = E¹%₁cm × C × l より、測定溶液中の芳香族第一アミンの濃度 C (% w/v) を求める。C = A / (E¹%₁cm × l) = 0.15 / (475 × 1) ≈ 0.0003158 % w/v。\n5. 測定溶液 50 mL 中の芳香族第一アミンの質量を計算：質量 = (C / 100) × 50 mL = (0.0003158 / 100) g/mL × 50 mL ≈ 0.0001579 g。\n6. 試料 0.20 g に対する質量パーセント濃度（許容限度）を計算：許容限度 (%) = (芳香族第一アミンの質量 / 試料の質量) × 100 = (0.0001579 g / 0.20 g) × 100 ≈ 0.07895 %。\n7. 最も近い選択肢：計算結果は約 0.079 %。選択肢 2 の 0.079% が最も近い。"
#     }
#   },
#   {
#     "問98": {
#       "回答": [
#         5
#       ],
#       "理由": "アミドトリゾ酸の定量法に関する記述を評価する。この定量法は、亜鉛による還元的脱ヨウ素化で生じたヨウ化物イオン (I⁻) を硝酸銀 (AgNO₃) 標準液で滴定する沈殿滴定（ファヤンス法）である。\n1. Volhard 法は過剰の Ag⁺ をチオシアン酸標準液で逆滴定する方法であり、本法（直接滴定）とは異なる。誤り。\n2. ア (0.1 mol/L 硝酸銀液) は滴定剤であり、その標定には通常 NaCl が用いられる。チオシアン酸アンモニウム液の標定に硝酸銀液が用いられる。記述が逆。誤り。\n3. イ (テトラブロモフェノールフタレインエチルエステル) は酸性条件下での I⁻ 滴定に適した吸着指示薬。フルオレセインナトリウムは中性～弱アルカリ性での Cl⁻, Br⁻ 滴定に用いられる吸着指示薬であり、本滴定条件には不適切。誤り。\n4. ウ に入る色。AgI 沈殿は黄色。指示薬は終点で Ag⁺ が吸着した沈殿表面に吸着し変色する。テトラブロモフェノールフタレインエチルエステルの場合、青緑～紫色などに変色すると考えられる。橙色ではない。誤り。\n5. エ に入る数値（ファクター）の計算。アミドトリゾ酸 (C₁₁H₉I₃N₂O₅, 分子量 613.91) 1 mol は 3 個の I を含み、3 mol の Ag⁺ と反応する。0.1 mol/L AgNO₃ 液 1 mL 中の Ag⁺ は 0.0001 mol。これと反応するアミドトリゾ酸は (0.0001 / 3) mol。質量は (0.0001 / 3) mol × 613.91 g/mol ≈ 0.0204636 g = 20.4636 mg。よって エ は 20.46。正しい。\n注記：正しい記述は5のみであるが、問題文では2つ選ぶよう指示されている。他の選択肢は明確に誤りであるため、問題に不備がある可能性が高い。しかし、指示に従う場合、消去法で最も疑わしさが残る（色の判断など主観が入りうる）4を選ぶことも考えられるが、学術的には5のみが正しい。"
#     }
#   },
#   {
#     "問99": {
#       "回答": [
#         1,
#         4
#       ],
#       "理由": "原子吸光光度法 (AAS) による金 (Au) の定量に関する記述を評価する。\n1. ア に入る可燃性ガス。金 (Au) のフレーム原子吸光分析では、一般的に空気-アセチレンフレームが用いられる。したがって、可燃性ガスはアセチレンである。正しい。\n2. イ に入るランプ。原子吸光分析では、測定対象元素の輝線スペクトルを光源として用いる。金 (Au) の測定には、金の中空陰極ランプ (HCL) が用いられる。重水素放電管はバックグラウンド補正用の連続光源。誤り。\n3. 原子化法。空気-アセチレンガスを用いることから、フレーム原子化法が用いられている。冷蒸気方式は主に水銀 (Hg) の測定に用いられる。誤り。\n4. 原子吸光光度法では、原子蒸気層中の基底状態原子による光吸収を利用する。吸光度と原子濃度（試料濃度）の間には、一定の濃度範囲でランベルト・ベールの法則が成り立つ。正しい。\n5. 原子スペクトルは、原子に固有のエネルギー準位間の電子遷移に基づく不連続な線スペクトルである。連続スペクトルではない。誤り。"
#     }
#   },
#   {
#     "問100": {
#       "回答": [
#         2,
#         4
#       ],
#       "理由": "逆相 HPLC によるフェノール、パラオキシ安息香酸、トルエンの分離に関する記述を評価する。固定相は ODS (非極性)、移動相は緩衝液/メタノール (極性)。極性の低い物質ほど保持時間が長くなる。極性は パラオキシ安息香酸 (pH 7 でイオン化) > フェノール > トルエン (非極性)。溶出順は パラオキシ安息香酸 < フェノール < トルエン。\n1. 固定相が非極性 (ODS)、移動相が極性 (水系/有機溶媒) なので、逆相クロマトグラフィーである。順相ではない。誤り。\n2. 溶出順は極性の高い順。最も非極性であるトルエンが最後に溶出する。正しい。\n3. カラム温度を上げると、一般に保持時間は短くなり、ピーク幅は狭くなり、ピーク高さは高くなる。ピーク面積は理論的には変化しない。ピーク面積が減少するというのは誤り。\n4. パラオキシ安息香酸は pH 7.0 ではカルボキシ基が解離 (-COO⁻) して極性が高い。移動相の pH を低くすると、解離が抑制され分子型 (-COOH) が増える。分子型はイオン型より極性が低いので、非極性の固定相との相互作用が強まり、保持時間は長くなる。正しい。\n5. トルエン (非極性) の保持時間を長くするには、移動相の極性を高くする（溶出力を弱める）必要がある。移動相中のメタノール（緩衝液より極性が低い）の比率を高くすると、移動相の極性が下がり（溶出力が強くなり）、保持時間は短くなる。誤り。"
#     }
#   },
#   {
#     "問101": {
#       "回答": [
#         6
#       ],
#       "理由": "酸塩基抽出による化合物 A (アニソール, 中性), B (安息香酸, 酸性), C (アニリン, 塩基性), D (フェノール, 弱酸性) の分離。\n操作試薬：ア (HCl, 強酸), イ (NaOH, 強塩基), ウ (NaHCO₃, 弱塩基)。\n分液操作②で D (フェノール) の塩が水層に抽出された。フェノールは弱酸性であり、強塩基 (NaOH) によって塩 (フェノキシド) となって水層に抽出される。弱塩基 (NaHCO₃) ではほとんど抽出されない。よって操作② = イ (NaOH)。\n操作②の段階でエーテル層に D が存在したということは、操作①では D は抽出されなかったことを意味する。\n分離の一般的な順序は、(1) 塩基性物質を酸で抽出、(2) 強酸性物質を弱塩基で抽出、(3) 弱酸性物質を強塩基で抽出。\nこの順序に従うと、操作①で塩基性物質 C (アニリン) を ア (HCl) で抽出するか、または強酸性物質 B (安息香酸) を ウ (NaHCO₃) で抽出する。\nもし操作① = ア (HCl) なら、エーテル層には A, B, D が残る。次に操作② = イ (NaOH) を行うと、B と D の両方が水層に抽出されてしまい、「D の塩が主に含まれていた」という条件に合わない。\nもし操作① = ウ (NaHCO₃) なら、B (安息香酸) が水層へ。エーテル層には A, C, D が残る。次に操作② = イ (NaOH) を行うと、D (フェノール) が水層へ抽出される。これは条件に合う。\nこの場合、残りのエーテル層には A (中性) と C (アミン) が含まれる。操作③で C を抽出するには ア (HCl) を用いる。\nしたがって、最適な操作の組み合わせは 操作①=ウ, 操作②=イ, 操作③=ア。これは選択肢6に対応する。"
#     }
#   },
#   {
#     "問102": {
#       "回答": [
#         5
#       ],
#       "理由": "各反応の主生成物が正しいか評価する。\n1. 末端アルキン + NaNH₂ → アセチリド。+ CH₃CH₂Br → SN2反応でアルキル化。正しい。\n2. 末端アルキン + (sia)₂BH (ヒドロホウ素化、逆マルコフニコフ型) → H₂O₂/NaOH (酸化) → アルデヒド生成。正しい。\n3. 内部アルキン + HgSO₄/H₂O⁺ (水和反応、マルコフニコフ型) → ケトン生成。図のケトンは可能な生成物の一つ。正しい。\n4. 内部アルキン + H₂/リンドラー触媒 → シス-アルケン生成。図の生成物はアルケンであり、シス型として解釈可能。正しい。\n5. 末端アルキン + HCl (2当量) → マルコフニコフ付加。1当量目で内部炭素に Cl が付加したビニルクロリド、2当量目で同じ内部炭素にもう一つの Cl が付加したジェミナルジクロリド (例: R-CCl₂-CH₃) が生成する。図の生成物は隣接する炭素に Cl が付加したビシナルジクロリドであり、これは誤り。"
#     }
#   },
#   {
#     "問103": {
#       "回答": [
#         1,
#         3
#       ],
#       "理由": "電子移動を示す矢印（巻き矢印）の正しさを評価する。\n1. NaBH₄ によるケトン還元：BH₄⁻ からのヒドリド (H:⁻) がカルボニル炭素を求核攻撃し、同時に C=O の π 電子が酸素原子上に移動する。矢印はこれを正しく示している。正しい。\n2. アミンによるカルボニルへの求核付加（イミン生成の第一段階）：アミンの非共有電子対がカルボニル炭素を攻撃し、C=O の π 電子が酸素へ移動する。図の矢印は全く異なる動きを示しており、誤り。\n3. ウィリアムソンエーテル合成 (SN2)：アルコキシドの酸素原子の非共有電子対がハロゲン化アルキルの炭素原子を背面攻撃し、同時にハロゲン原子が脱離基として結合電子対とともに離れる。図の矢印はこれを正しく示している。正しい。\n4. ニトロ化 (芳香族求電子置換)：ベンゼン環の π 電子がニトロニウムイオン (⁺NO₂) の窒素原子を攻撃し、σ 錯体 (アレニウムイオン) を形成する。図の最初の矢印 (π 電子 → N) は攻撃を示しているが、同時に N=O → O の矢印があるのは σ 錯体形成の標準的な描写ではなく、不適切。後半の脱プロトンによる芳香環再生の矢印は正しいが、一連の矢印としては最初の部分に問題がある。誤り。\n5. アルケンへの HBr 付加 (求電子付加)：アルケンの π 電子が HBr の H を攻撃してカルボカチオン中間体 (より安定な方が生成) を形成し、次に Br⁻ がカルボカチオンを攻撃する。図の矢印はこれらのステップを正しく示している。正しい。\n正しいものは 1, 3, 5 であるが、2つ選ぶ必要がある。1, 3, 5 はいずれも基本的な反応機構を正しく示している。4は最初の矢印が不適切。2は全く異なる。最も疑いのない 1 と 3 を選ぶ。"
#     }
#   },
#   {
#     "問104": {
#       "回答": [
#         4,
#         5
#       ],
#       "理由": "DNA 二重らせん構造に関する記述を評価する。\n1. 塩基アはアデニン (A)。アデニンはプリン塩基であり、ピリミジン環とイミダゾール環が縮合した構造を持つ。ピラジン環ではない。誤り。\n2. 塩基イはチミン (T)。チミンはピリミジン塩基。ウリジンはヌクレオシド（塩基+糖）であり、塩基部分はウラシル (U)。DNA にはチミンが含まれ、ウラシルは通常 RNA に含まれる。誤り。\n3. 矢印Aはポリヌクレオチド鎖の方向を示す。DNA 鎖は 5' 末端から 3' 末端への方向性を持つ。図において、リン酸ジエステル結合は下のヌクレオチドの 3' 位から上のヌクレオチドの 5' 位へ伸びているように見える。したがって、矢印Aは 5'→3' 方向を指している。記述は 3'→5' なので誤り。\n4. 酸素原子エはグアニン (G) の C=O 基の酸素。これはシトシン (C) の -NH₂ 基の水素との間で水素結合 (O...H-N) を形成している。水素結合において、電気陰性度の高い原子上の非共有電子対が水素を受け入れる側が受容体。酸素原子エは水素結合受容体として機能している。正しい。\n5. 相補的な塩基対 (A-T, G-C) は、水素結合によって形成され、各塩基はほぼ同一平面上に配置される。これらの塩基対平面が積み重なって二重らせん構造を形成する。塩基対は平面状である。正しい。"
#     }
#   },
#   {
#     "問105": {
#       "回答": [
#         1,
#         4
#       ],
#       "理由": "アセチルCoA の生合成（ピルビン酸デヒドロゲナーゼ複合体反応）に関する記述を評価する。\n1. 構造式アは補酵素 TPP。Mg²⁺ は TPP を要求する酵素で必要とされ、ピロリン酸部分の負電荷を中和し構造安定化や酵素結合に関与する。リン原子の求電子性を高めるという記述は、TPP の触媒機構における主要な役割ではない。疑わしい。\n2. 矢印イはアセチル基のカルボニル酸素。これはピルビン酸 (CH₃COCOOH) のカルボニル基由来。酢酸イオン由来ではない。誤り。\n3. アセチルCoA (ウ) はチオエステル (-S-CO-)。対応するオキソエステル (-O-CO-) と比較すると、硫黄の電気陰性度が酸素より小さいため、カルボニル炭素の電子密度が相対的に低くなり、求電子性はチオエステルの方が高い。記述は逆。誤り。\n4. 矢印エは CoA の ADP 部分の β-リン酸原子。このリン原子は Pα, Pγ, 5'リボース酸素, O⁻ の4つの異なる基に結合しており、キラル中心である。構造は四面体 (4配位)。酸化数は+5。「5価4配位」という表現は不正確だが、キラル中心であることは正しい。\n5. CoA-SH のチオール基 (オ) は、リポアミドに結合したアセチル基のカルボニル炭素を求核攻撃し、アセチル基転移反応（求核アシル置換）によってアセチルCoA を生成する。これは SN2 反応ではない。誤り。\n明確な誤りは 2, 3, 5。残る 1 と 4 のうち、4 はキラル中心であるという事実が正しい（表現に難あり）。1 の記述は役割として不適切。よって 4 を正しいと判断。2つ選ぶ必要があり、1 も部分的に正しい（電荷中和）ため、1 と 4 を選ぶ。"
#     }
#   },
#   {
#     "問106": {
#       "回答": [
#         1
#       ],
#       "理由": "ブレオマイシン A₂ による DNA 切断に必要な化学的性質を問うている。ブレオマイシンは Fe(II) イオンとキレート錯体を形成し、酸素を活性化して DNA を切断する。\n1. 部分構造アは β-アミノアラニン部位、ピリミジン環、イミダゾール環を含み、これらは Fe(II) との配位に関与する主要な部位である。正しい。\n2. 部分構造イは糖部分。Mg(II) との配位が DNA 切断に必須とは考えられない。誤り。\n3. 部分構造ウはリンカー部分。一部配位に関与する可能性はあるが、Mg(II) との関連は低い。誤り。\n4. 部分構造エはビチアゾール部分。DNA へのインターカレーションに関与するとされるが、光増感作用は主要な作用機序ではない。誤り。\n5. 部分構造オは末端アミン部分。Fe(II) キレートの中心ではない。誤り。\nしたがって、DNA 切断に最も重要なのは、主要な金属キレート部位を含む部分構造アにおける Fe(II) との配位能である。"
#     }
#   },
#   {
#     "問107": {
#       "回答": [
#         2
#       ],
#       "理由": "インスリンアナログのうち、等電点 (pI) をインスリン (pI 約 5.4) から中性付近 (pI 約 6.7) に上昇させることで、生理的 pH で沈殿し作用を持続化させるものを探す。pI を上昇させるには、分子全体の正電荷を増やす（塩基性アミノ酸導入）か、負電荷を減らす（酸性アミノ酸除去）改変が必要。\n1. B28 Pro→Lys, B29 Lys→Pro, A21 Asn→Gly, B3 Asn→Lys。Lys が1つ増える。pI 上昇。\n2. A21 Asn→Gly, B鎖 C末端に Arg-Arg 付加。塩基性の Arg が2つ付加されるため、pI が大幅に上昇する。これはインスリングラルギンの特徴であり、pI が約 6.7 になる。正しい。\n3. B3 Asn→Lys, B29 Lys→Glu。塩基性残基が1つ増え、1つが酸性残基に置換。pI 変化は小さいか低下。\n4. B29 Lys に脂肪酸結合, A21 Asn→Gly, B30 Thr 欠失。pI への影響は小さい。\n5. B28 Asp 置換?, B10 His→Asp? 酸性残基導入/増加。pI 低下。\nしたがって、pI を中性付近にシフトさせる改変は選択肢2。"
#     }
#   },
#   {
#     "問108": {
#       "回答": [
#         2,
#         5
#       ],
# ...
#     }
#   },
#   {
#     "問319": {
#       "回答": [
#         4,
#         5
#       ],
#       "理由": "高額療養費制度に関する記述について。高額療養費制度は、年齢に関わらず適用される（ただし、自己負担限度額は年齢や所得区分によって異なる）（選択肢4）。また、同一世帯内で、同一の医療保険に加入している複数の人が、同月内にそれぞれ一定額（通常21,000円以上）以上の自己負担をした場合、それらを合算して世帯の自己負担限度額を超えた分が払い戻される「世帯合算」の仕組みがある。この患者は79歳男性、妻は75歳であり、同一世帯・同一保険（後期高齢者医療制度など）に加入していると考えられるため、合算を利用できる可能性がある（選択肢5）。\n選択肢1について、高額療養費の自己負担限度額は月単位で計算される。半年単位ではない。\n選択肢2について、高額療養費制度の運用（支給決定など）は、患者が加入している医療保険者（国民健康保険組合、協会けんぽ、後期高齢者医療広域連合など）が行う。PMDA（医薬品医療機器総合機構）ではない。\n選択肢3について、患者が国民健康保険組合に加入していれば正しいが、79歳であれば後期高齢者医療制度に加入している可能性が高く、断定はできない。制度自体はどの保険でも利用可能だが、運営主体が異なる。"
#     }
#   },
#   {
#     "問320": {
#       "回答": [
#         3,
#         4
#       ],
#       "理由": "薬剤師の居宅療養管理指導（介護保険）に関する記述について。保険薬局として指定を受けていることは、医療保険・介護保険のサービスを提供する前提となる。介護保険の居宅療養管理指導を行う事業者として指定を受けていれば、個々の指導実施について、あらかじめ行政機関等へ届け出る必要はない（ケアプランに基づき実施される）（選択肢3）。また、介護保険における居宅療養管理指導費は、原則として月4回まで算定可能という制限がある（医療保険の在宅患者訪問薬剤管理指導料も同様に回数制限がある）（選択肢4）。\n選択肢1について、患者が介護保険を利用して費用を請求する場合、算定するのは「居宅療養管理指導費」であり、「在宅患者訪問薬剤管理指導料」は医療保険の名称であるため誤り。\n選択肢2について、管理指導を行う薬剤師に5年以上の実務経験は要件とされていない。\n選択肢5について、訪問時に得た情報（特に他のサービスに影響しうる情報）は、医師だけでなく、ケアマネジャー等、連携する他の関係職種にも必要に応じて情報提供・報告する必要がある。"
#     }
#   },
#   {
#     "問321": {
#       "回答": [
#         5
#       ],
#       "理由": "患者は酸化マグネシウムを服用しているにも関わらず便秘が続いている。考えられる原因として、①酸化マグネシウムの効果不十分、②他の薬剤（ガランタミン、ファモチジン等）による副作用、③水分摂取不足や活動量低下などが挙げられる。選択肢の中で最も適切な提案を選ぶ。\n選択肢1は水分摂取を控えるよう指導するものであり、便秘を悪化させるため不適切。\n選択肢2は便秘薬である酸化マグネシウムの減量を提案するものであり、症状が改善していない状況では不適切。\n選択肢3は市販薬の使用を指示するものであり、医師への相談・提案が適切な状況では不適切。\n選択肢4はファモチジンの増量を提案するものであり、便秘改善にはつながらない（ファモチジンは便秘を引き起こす可能性もある）。\n選択肢5はガランタミンの増量を提案するもの。ガランタミンはコリンエステラーゼ阻害薬であり、アセチルコリンを増やすことで理論的には消化管運動を亢進させる可能性がある（副作用としては下痢が多いが、便秘も報告されている）。認知症治療薬であり、認知機能改善による活動性向上なども期待できるかもしれない。他の選択肢が明らかに不適切なため、消去法的に、あるいはコリン作動性効果による腸管運動改善を期待して、これが最も可能性のある提案と判断される。ただし、通常は酸化マグネシウムの増量や他の便秘薬への変更・追加をまず検討するべき状況である。"
#     }
#   },
#   {
#     "問322": {
#       "回答": [
#         3,
#         5
#       ],
#       "理由": "患者は夕食後の服用が困難であり、処方1（ロスバスタチン）の飲み残しが多い状況。ロスバスタチンは服用時間に制限がないため、患者の生活スタイルに合わせて朝食後などに変更することは、アドヒアランス向上のための適切な提案である（選択肢3）。また、腹部不快感は処方2（サキサグリプチン）が開始されてから約1週間半後に発現している。サキサグリプチンは副作用として腹部症状（腹部膨満、腹痛、便秘、下痢など）が報告されており（頻度は低いが）、処方1（ロスバスタチン）よりも時間的な関連性が高いと考えられるため、処方2の副作用の可能性が高いと判断し、医師に情報提供することは適切である（選択肢5）。\n選択肢1について、薬剤師が自己判断で処方薬の中止を指示することはできない。\n選択肢2について、服薬支援（コンプライアンス・エイド）で解決しないアドヒアランスの問題は、処方医に相談・提案すべきであり、薬局で医師に相談するというのは不適切。\n選択肢4について、ロスバスタチンも腹部症状を起こしうるが、長年服用しており最近発現した症状であること、新規薬剤開始のタイミングを考慮すると、処方1の副作用の可能性が高いとは言えない。"
#     }
#   },
#   {
#     "問323": {
#       "回答": [
#         4,
#         5
#       ],
#       "理由": "地域連携薬局の認定要件に関する記述について。地域連携薬局は、地域包括ケアシステムの中で多職種と連携し、地域住民による主体的な健康の維持・増進を支援する機能を持つ薬局である。その要件として、地域の介護・医療・福祉関係者等が参加する研修会へ継続的に参加している体制があること（選択肢4）、そして、地域の他の医療提供施設（病院、診療所等）に対し、患者の入退院時などに服薬情報等を一元的・継続的に把握し、情報提供できる体制（連携体制）を有することが求められる（選択肢5）。\n選択肢1について、在宅医療の実績（一定数以上の実施）が要件の一つであり、「実績に関わらず」ではない。また、24時間対応体制も求められる。\n選択肢2について、営業年数に関する要件はない。\n選択肢3について、オンライン服薬指導の体制は、地域連携薬局の必須要件ではない（専門医療機関連携薬局では要件の一つ）。"
#     }
#   },
#   {
#     "問324": {
#       "回答": [
#         1,
#         2
#       ],
#       "理由": "研究に関する情報を掲示（ポスター等）により公開し、対象者が拒否（オプトアウト）する機会を保障する場合に必要な記載内容について。ヘルシンキ宣言や人を対象とする生命科学・医学系研究に関する倫理指針に基づき、研究対象者への説明事項が定められている。これには、研究の目的（選択肢1）、研究の方法、対象となる個人の情報の内容、情報の利用目的、研究への協力を拒否する方法（オプトアウトの方法）（選択肢2）、研究組織、問い合わせ先などが含まれる。\n選択肢3について、問い合わせ先（代表者や事務局）は必要だが、関与する研究者全員の連絡先を記載する必要はない。\n選択肢4について、倫理審査委員会の委員名を公開する必要はない（委員会の名称や承認を受けた旨は記載することがある）。\n選択肢5について、研究費用に関する詳細（誰が負担するか、具体的な金額など）をポスターに記載する必要はない（資金源の開示は論文発表時などに求められる）。"
#     }
#   },
#   {
#     "問325": {
#       "回答": [
#         2
#       ],
#       "理由": "実施する研究（過去5年間の降圧薬の服薬アドヒアランスに関する後ろ向き調査）に関する倫理審査委員会への申請にあたり遵守すべき指針・法律について。本研究は、人を対象とする観察研究に該当する。日本における人を対象とする医学系研究（臨床研究）は、「人を対象とする生命科学・医学系研究に関する倫理指針」に従って実施する必要がある（選択肢2）。\n選択肢1のGCP（医薬品の臨床試験の実施の基準に関する省令）は、医薬品の承認申請を目的とした臨床試験（治験）に適用される。\n選択肢3のGVP（医薬品、医薬部外品、化粧品、医療機器及び再生医療等製品の製造販売後安全管理の基準に関する省令）は、製造販売業者が行う製造販売後の安全管理体制に関する基準である。\n選択肢4の薬機法（医薬品、医療機器等の品質、有効性及び安全性の確保等に関する法律）は、医薬品等の製造販売、表示、広告などを規制する法律であり、研究倫理の細則は含まない。\n選択肢5の臨床研究法は、特定臨床研究（未承認・適応外薬の使用や製薬企業等から資金提供を受ける介入研究など）を対象とする法律であり、本研究は該当しない。"
#     }
#   },
#   {
#     "問326": {
#       "回答": [
#         3
#       ],
#       "理由": "造血幹細胞移植後の免疫抑制療法中の患者が下痢を訴えている状況。下痢の原因として、薬剤性（特にミコフェノール酸モフェチル（MMF）やタクロリムス）、感染症、移植片対宿主病（GVHD）などが考えられる。薬剤師の薬学的管理として不適切なものを選択する。\n選択肢1：下痢の性状（回数、水様便か泥状便か、血液の混入など）を確認することは、原因検索や重症度評価の基本であり、適切な行動である。\n選択肢2：MMFは血中濃度（活性代謝物MPA）と副作用（特に消化器症状）の関連が指摘されており、TDM（薬物血中濃度モニタリング）を提案することは原因特定や用量調節のために適切である。\n選択肢3：メチルプレドニゾロンは移植後の免疫抑制やGVHD治療に重要な薬剤であり、自己判断での中止提案は極めて危険であり不適切である。中止や減量は医師の慎重な判断が必要である。\n選択肢4：半夏瀉心湯は消化器症状に用いられる漢方薬であり、医師への処方提案として考慮する可能性はある（ただし有効性や相互作用は要確認）。提案自体が不適切とは言えない。\n選択肢5：免疫抑制状態では感染性腸炎のリスクが高いため、便培養による原因検索を提案することは適切である。\nしたがって、最も不適切な行動は選択肢3である。"
#     }
#   },
#   {
#     "問327": {
#       "回答": [
#         2
#       ],
#       "理由": "大腿骨頸部骨折で手術予定の患者の術前中止薬について。手術に伴うリスク（出血、血栓塞栓症など）を考慮して、術前に中止すべき薬剤を判断する。\n選択肢2のラロキシフェンは、選択的エストロゲン受容体モジュレーター（SERM）であり、静脈血栓塞栓症（VTE）のリスクを増加させることが知られている。手術（特に下肢の整形外科手術）はVTEのリスクを高めるため、ラロキシフェンは術前に（通常は数週間前、少なくとも72時間前には）中止することが推奨される。\n選択肢1のエルデカルシトール（活性型ビタミンD3誘導体）、選択肢3のアムロジピン（カルシウム拮抗薬）、選択肢4のロスバスタチン（HMG-CoA還元酵素阻害薬）は、通常、周術期に継続されることが多い。\n選択肢5のスピロノラクトン（抗アルドステロン薬、カリウム保持性利尿薬）は、電解質や循環血液量に影響するため、手術当日に中止されることがあるが、VTEリスクのあるラロキシフェンの中止の方が優先度は高い。\nしたがって、術前に中止すべき薬剤として最も重要なのはラロキシフェンである。"
#     }
#   },
#   {
#     "問328": {
#       "回答": [
#         2,
#         4
#       ],
#       "理由": "川崎病で治療を受け退院する患児の家族への説明内容について。川崎病の治療では、急性期に免疫グロブリン大量療法（IVIG）とアスピリンが用いられ、解熱後も冠動脈瘤の合併がある場合やリスクが高い場合には、血栓予防のために低用量アスピリンの内服が継続される。したがって、退院後もアスピリンを継続する理由（血栓予防）を説明することは重要である（選択肢2）。また、アスピリン内服中にインフルエンザや水痘（水ぼうそう）に罹患すると、ライ症候群を発症するリスクがあるため、これらの感染症が疑われる場合には速やかに医師に連絡するよう指導する必要がある（選択肢4）。\n選択肢1について、IVIGは急性期の治療であり、退院後に定期的に行うものではない。\n選択肢3について、アスピリンは急性期（高用量）と回復期（低用量）で用法・用量が異なるため、「入院中と同じ用法・用量」という説明は誤りである可能性が高い。\n選択肢5について、IVIG投与後は、含有される抗体の影響で生ワクチン（麻疹、風疹、水痘、おたふくかぜ等）の効果が減弱する可能性があるため、一定期間（通常11ヶ月程度）接種を延期する必要がある。"
#     }
#   },
#   {
#     "問329": {
#       "回答": [
#         3
#       ],
#       "理由": "医薬品とサプリメント成分含有食品との相互作用に関する記述の正誤を判断する。誤っているものを選択する。\n選択肢1：レボドパは鉄剤とキレートを形成し吸収が低下するため、作用減弱のおそれがある。正しい記述。\n選択肢2：パロキセチン（SSRI）とセント・ジョーンズ・ワートはともにセロトニン作用を増強するため、併用によりセロトニン症候群のリスクが高まる。正しい記述。\n選択肢3：アレンドロン酸（ビスホスホネート製剤）は、カルシウム（Ca）などの多価陽イオンとキレートを形成し、吸収が著しく低下する。記述では「吸収が**促進**されるおそれがある」と記載されており、これが誤りである。\n選択肢4：レボフロキサシン（ニューキノロン系抗菌薬）は、マグネシウム（Mg）などの多価陽イオンとキレートを形成し、吸収が低下するため、効果減弱のおそれがある。正しい記述。\n選択肢5：アミノフィリンとカフェインはともにキサンチン誘導体であり、中枢神経刺激作用や心刺激作用などを有するため、併用によりこれらの作用が増強し、副作用（頭痛、不眠、動悸など）が現れることがある。正しい記述。\nしたがって、誤っている記述は選択肢3である。"
#     }
#   },
#   {
#     "問330": {
#       "回答": [
#         2,
#         4
#       ],
#       "理由": "アファチニブ（EGFRチロシンキナーゼ阻害薬）を服用中の患者に対する薬物治療の評価と指導計画について。アファチニブの重大な副作用として間質性肺疾患、重度の下痢、皮膚障害（ざ瘡様皮疹、皮膚乾燥、爪囲炎など）、肝機能障害などが知られている。特に皮膚障害は高頻度に見られるため、発疹、皮膚の乾燥、かゆみなどが現れる可能性があることを伝え、対処法（保湿、刺激を避けるなど）を指導することは適切である（選択肢4）。また、がん患者であり、化学療法や分子標的治療薬による骨髄抑制のリスクは常に考慮すべきである。血小板減少も可能性のある副作用の一つとして評価・観察項目に挙げることは適切である（選択肢2）。\n選択肢1について、アファチニブはEGFR遺伝子変異陽性の非小細胞肺癌に対して一次治療から用いられることも多く、「化学療法**施行後**に開始された」とは限らないため、断定的な評価は不適切。\n選択肢3について、アファチニブによる下痢は重症化することもあり、自然に治るとは限らない。適切な対症療法（止痢剤など）や、場合によっては休薬・減量が必要となるため、この説明は不適切。\n選択肢5について、頓服薬（この場合はロキソプロフェン）を飲み忘れた場合に、翌日に倍量服用するような指示は誤りである。"
#     }
#   },
#   {
#     "問331": {
#       "回答": [
#         2,
#         5
#       ],
#       "理由": "心原性脳塞栓症（左中大脳動脈領域）の急性期治療に関する医師との共有事項について。患者は発症から約14時間経過しており、血栓溶解療法（t-PA）の適応時間（通常4.5時間以内）は過ぎている。また、主幹動脈閉塞はないため血管内治療の適応もない。\n選択肢2のエダラボンは、脳保護作用を期待して発症後24時間以内に投与が開始される薬剤であり、この患者には適応となりうる。適切な検討事項である。\n選択肢5のDOAC（直接経口抗凝固薬）は、心原性脳塞栓症の再発予防に標準的に用いられるが、急性期（特に発症早期）の開始は出血性梗塞のリスクを考慮し、梗塞の大きさや患者の状態に応じて開始時期を慎重に判断する必要がある（例：1-3-6-12 day rule）。しかし、再発予防のための抗凝固療法導入は必須であり、DOACの使用（開始時期を含め）は重要な検討事項となる。\n選択肢1のヘパリンナトリウム持続静注は、急性期脳梗塞に対するルーチンの治療としては推奨されていない（出血リスクのため）。特定の状況（例：進行性脳梗塞、塞栓源の評価・治療までのブリッジングなど）で考慮される場合もあるが、一般的ではない。\n選択肢3のトリプタンは片頭痛治療薬であり、脳浮腫には用いない。\n選択肢4の抗血小板療法は、非心原性脳梗塞の再発予防が主であり、心原性脳塞栓症では抗凝固療法が優先される。急性期に一時的に使用されることもあるが、DOAC等の抗凝固療法への移行が前提となる。\nしたがって、急性期治療として適切な検討事項はエダラボン投与（2）と、再発予防を見据えたDOACの使用（開始時期の検討を含む）（5）である。"
#     }
#   },
#   {
#     "問332": {
#       "回答": [
#         1,
#         4
#       ],
#       "理由": "ドーピング禁止物質に関する知識を問う問題。陸上競技の国際大会に出場予定の選手が使用できる一般用医薬品の成分を選択する。\n選択肢1のブチルスコポラミン臭化物は、鎮痙薬であり、WADAの禁止表国際基準において禁止物質としてリストされていないため、使用可能である。\n選択肢4のロラタジンは、第二世代抗ヒスタミン薬であり、禁止物質としてリストされていないため、使用可能である。\n選択肢2のストリキニーネは、興奮薬であり、常に禁止されている（S6. 興奮薬）。\n選択肢3のマオウ（麻黄）は、エフェドリン等を含み、興奮薬として競技会（時）に禁止されている（S6. 興奮薬）。\n選択肢5のプソイドエフェドリンは、興奮薬であり、競技会（時）において尿中濃度が150μg/mLを超えた場合に禁止される（S6. 興奮薬）。閾値以下なら問題ないが、リスクを伴うため推奨は慎重になるべきであり、明確に使用可能な1, 4と比較すると適切性が劣る。\nしたがって、明確に使用可能な成分は1と4である。"
#     }
#   },
#   {
#     "問333": {
#       "回答": [
#         5
#       ],
#       "理由": "ペムブロリズマブ（抗PD-1抗体）投与中の患者に見られる免疫関連有害事象（irAE）に関する問題。患者は倦怠感、体重増加、脈拍42/分（徐脈）を呈している。これらの症状は甲状腺機能低下症を強く示唆する。甲状腺機能低下症は、ペムブロリズマブなどの免疫チェックポイント阻害薬によるirAEとして知られている（甲状腺炎や下垂体機能障害に伴うもの）。甲状腺機能低下症の診断に最も重要な検査項目は、甲状腺刺激ホルモン（TSH）である（選択肢5）。原発性甲状腺機能低下症ではTSHは高値となり、下垂体性（中枢性）ではTSHは低値～基準範囲内でFT4が低値となる。いずれにしてもTSHの測定は必須である。\n選択肢1のプロラクチン、選択肢2のテストステロン、選択肢4のゴナドトロピンは、下垂体機能障害の評価項目ではあるが、提示された症状（倦怠感、体重増加、徐脈）から第一に疑われる甲状腺機能低下症の直接的な指標ではない。\n選択肢3の抗甲状腺抗体は、甲状腺機能異常の原因を探る上で有用な場合があるが、機能低下の診断自体はホルモン測定（TSH, FT4）で行う。"
#     }
#   },
#   {
#     "問334": {
#       "回答": [
#         4,
#         5
#       ],
#       "理由": "深部静脈血栓症（DVT）と診断された患者の初期治療薬について。急性期のDVT治療では、迅速な抗凝固療法の開始が必要である。選択肢の中で、DVTの初期治療として適切なのは、経口投与可能で即効性のある直接経口抗凝固薬（DOAC）であるアピキサバン（選択肢4）や、注射薬で即効性のある低分子量ヘパリン（LMWH）であるダルテパリン（選択肢5）である。これらは、単独またはワルファリンへの橋渡し（ブリッジング）として用いられる標準的な初期治療薬である。\n選択肢1のシロスタゾール、選択肢2のクロピドグレルは抗血小板薬であり、DVTの治療には用いられない。\n選択肢3のワルファリンは有効な抗凝固薬であるが、効果発現までに数日を要するため、初期治療としてはヘパリン類との併用（ブリッジング）が必要であり、単独での初期治療には適さない。"
#     }
#   },
#   {
#     "問335": {
#       "回答": [
#         3
#       ],
#       "理由": "アジソン病（原発性副腎皮質機能低下症）の患者で、ヒドロコルチゾン（糖質コルチコイド補充）を開始したが、低血圧と低ナトリウム血症が改善しない状況。これは、鉱質コルチコイド（アルドステロン）の欠乏症状が残存していることを示唆する（検査値でもNa 134 mEq/L, K 5.3 mEq/Lと鉱質コルチコイド作用不足を示唆）。したがって、鉱質コルチコイド作用を持つ薬剤の追加が必要である。選択肢の中で、強力な鉱質コルチコイド作用を持ち、アジソン病の鉱質コルチコイド補充に用いられる標準的な薬剤はフルドロコルチゾン（選択肢3）である。\n選択肢1のデキサメタゾン、選択肢2のベタメタゾンは強力な糖質コルチコイドであるが、鉱質コルチコイド作用はほとんどない。\n選択肢4のスピロノラクトン、選択肢5のエプレレノンは抗アルドステロン薬であり、鉱質コルチコイド作用を阻害するため、この患者には禁忌である。"
#     }
#   },
#   {
#     "問336": {
#       "回答": [
#         1,
#         5
#       ],
#       "理由": "薬剤の粉砕・脱カプセルを避けるべき理由について、正しい組み合わせを選択する。\n選択肢1：ダビガトランエテキシラートメタンスルホン酸塩カプセルは、特殊なコーティングが施されたペレットを含み、特定のpH環境下で溶けて吸収されるように設計されている。脱カプセルや粉砕によりバイオアベイラビリティが過度に上昇し、出血リスクが高まる。放出部位・吸収速度を制御する製剤であり、「放出制御製剤であるため」という理由は、広い意味で正しいと解釈できる。\n選択肢5：リセドロン酸ナトリウム錠（ビスホスホネート製剤）は、食道に長時間接触すると、びらんや潰瘍などの粘膜刺激作用（口腔咽頭刺激）を引き起こす可能性がある。粉砕すると薬剤が口腔や食道に付着しやすくなり、リスクが高まるため、避けるべきである。理由は正しい。\n選択肢2：ポマリドミドカプセルは、催奇形性があるため、曝露リスク回避の観点から脱カプセルは避けるべきである。「光で分解するため」は主たる理由ではない。\n選択肢3：バルプロ酸ナトリウム徐放錠は、徐放性を失い急激な血中濃度上昇（ドーズダンピング）を招くため、粉砕は避けるべきである。「苦味が出るため」は主たる理由ではない。\n選択肢4：ランソプラゾール口腔内崩壊錠（OD錠）は、口の中で速やかに溶けるように設計されている。ランソプラゾール自体は酸に不安定なため、カプセル剤などでは腸溶性のコーティングが施されているが、OD錠を粉砕するという操作自体が通常想定されず、「腸溶錠であるため」という理由はOD錠には当てはまらない。\nしたがって、理由として正しい、あるいは最も適切と考えられるのは1と5である。"
#     }
#   },
#   {
#     "問337": {
#       "回答": [
#         1,
#         3
#       ],
#       "理由": "発熱性好中球減少症（Febrile Neutropenia: FN）に対する抗菌薬の選択。FNは重篤な感染症のリスクが高い状態であり、特に好中球数500/μL未満は重症とされる。経験的治療として、緑膿菌を含む広域グラム陰性菌およびグラム陽性菌をカバーする、殺菌的な抗菌薬の速やかな静脈内投与が必要である。\n選択肢1のセフェピムは、第4世代セファロスポリンであり、緑膿菌を含む広域スペクトラムを持ち、FNの標準的な初期治療薬の一つである。\n選択肢3のメロペネムは、カルバペネム系抗菌薬であり、緑膿菌を含む非常に広範なスペクトラム（嫌気性菌もカバー）を持ち、重症例や耐性菌リスクが高い場合などに用いられる。これもFNの適切な治療選択肢である。\n選択肢2のエリスロマイシン（マクロライド系）、選択肢4のミノサイクリン（テトラサイクリン系）は、スペクトラムや殺菌活性の面でFNの初期治療には不適切である。\n選択肢5のダプトマイシンは、グラム陽性菌（特にMRSAやVRE）に有効であるが、グラム陰性菌には無効であり、FNの単独での初期治療には用いられない。\nしたがって、適切な抗菌薬は1と3である。"
#     }
#   },
#   {
#     "問338": {
#       "回答": [
#         3
#       ],
#       "理由": "感染対策としての滅菌手袋の外し方について、誤っている手順を選択する。手袋を外す際は、汚染されている可能性のある手袋の外面に、素手が触れないようにすることが原則である。\n手順1：片方の手袋の外面（手首付近）を、もう片方の手袋をした手でつまむ（正しい）。\n手順2：つまんだ手袋を裏返しながら外し、外した手袋はまだ手袋をしている方の手で保持する（正しい）。\n手順3：次に、手袋を外した素手の指を、まだ手袋が装着されている方の手首の内側（皮膚と手袋の間）に滑り込ませるのが正しい方法である。選択肢3の図と説明「素手になった手で反対側の手袋の**外面**をつまむ」は、素手で汚染された手袋の外面に触れてしまうため、誤った手順である。\n手順4：指を滑り込ませた後、手袋を裏返しながら（内面が外側になるように）外していく（正しい）。\n手順5：外した手袋は内側に包み込むようにして廃棄し、手指衛生を行う（正しい）。\nしたがって、誤っているのは選択肢3である。"
#     }
#   },
#   {
#     "問339": {
#       "回答": [
#         4
#       ],
#       "理由": "次亜塩素酸ナトリウムの希釈計算問題。最終的に1L (1000mL) の0.01% (100ppm) 溶液を作成する。必要な次亜塩素酸ナトリウムの純量 = 1000mL * 0.01% = 0.1mL。\n原液は6%なので、必要な原液量(ア) = 0.1mL / 6% = 1.67mL (約1.7mL)。\n問題は二段階希釈。(ア)mLの6%原液を水で薄めて全量を(イ)mLにし（中間液）、その中間液を(ウ)mL取って水で薄めて全量を1L (1000mL) にする。\n各選択肢を検証する。\n選択肢4：ア=5mL, イ=300mL, ウ=100mL\nStep 1: 5mLの6%原液を水で薄めて300mLにする。\n 中間液濃度 = (5mL * 6%) / 300mL = 0.3% / 3 = 0.1%\nStep 2: 0.1%の中間液を100mL取り、水で薄めて1000mLにする。\n 最終濃度 = (100mL * 0.1%) / 1000mL = 0.01%\nこの組み合わせが目的の濃度(0.01%)となるため、正しい。"
#     }
#   },
#   {
#     "問340": {
#       "回答": [
#         2,
#         5
#       ],
#       "理由": "食道がん術後の栄養療法に関する記述について。食道がん術後は、縫合不全のリスクや嚥下機能の変化により、経口摂取が困難な期間がある。栄養サポートチーム（NST）が介入している状況。\n選択肢2：術後、経口での食事摂取が困難であるが、消化管機能が維持されている場合、経腸栄養（例：術中に造設した空腸瘻からの投与）が第一選択となる。したがって、術後の栄養管理に経腸栄養法が適しているというのは正しい。\n選択肢5：経腸栄養法は、消化管の生理的な機能（バリア機能、免疫機能）を維持し、腸内細菌叢のバランスを保つ効果がある。中心静脈栄養法は、カテーテル関連血流感染症などのリスクを伴うため、消化管が使用可能な場合は、経腸栄養法の方が感染リスクは低いとされる。したがって、この記述は正しい。\n選択肢1について、術前の栄養状態が悪ければ、術前でも経腸栄養（または経口栄養補助）が行われることがある。「実施できない」は誤り。\n選択肢3について、経静脈栄養法で1日に必要な糖質量（カロリー）を摂取することは可能であるが、経腸栄養が可能であればそちらが優先される。\n選択肢4について、経腸栄養剤は通常液体であり、半固形製剤が常に適しているわけではない。"
#     }
#   },
#   {
#     "問341": {
#       "回答": [
#         4,
#         5
#       ],
#       "理由": "SOAP形式での薬剤服用歴記録に関する問題。S（Subjective: 主観的情報）、O（Objective: 客観的情報）、A（Assessment: 評価）、P（Plan: 計画）の各項目に内容を正しく分類する。\n選択肢4：「臨床検査値及び患者の状態から、処方2の薬剤の服用開始は可能と判断した」は、薬剤師がS情報（患者の状態）とO情報（検査値）を基に行った専門的な判断・評価（Assessment）に該当するため、Aとして適切である。\n選択肢5：「処方2の薬剤により体重増加のおそれがあるため、食事・運動に注意し、適度な運動を心がけるよう伝える」は、評価に基づいた今後の対応計画や患者指導（Plan）に該当するため、Pとして適切である。\n選択肢1は、モニタリング継続という計画（Plan）であり、Sではない。\n選択肢2は、母親からの報告であり、患者や家族からの訴えは主観的情報（Subjective）であるため、Sに分類すべき内容である。Oではない。\n選択肢3は、次回の来局時に確認するという計画（Plan）であり、Oではない。"
#     }
#   },
#   {
#     "問342": {
#       "回答": [
#         2,
#         5
#       ],
#       "理由": "薬剤師が患者（父）の薬剤セットを行う娘の負担を軽減するための工夫について。父は加齢黄斑変性による視力低下があるが、自己管理意欲はある。\n選択肢2：分包紙の用法等の印字のフォントサイズを大きくすることは、視力が低下した父が自分で薬剤を確認しやすくなり、自己管理を助け、結果的に娘のセット負担（確認・修正の手間など）を軽減する可能性が高い。\n選択肢5：医師に相談し、服薬回数を減らす（例：1日3回を1日1回や2回へ）ことができれば、セットする薬剤の数自体が減るため、娘の負担を直接的かつ大幅に軽減できる可能性が高い。\n選択肢1：氏名の印字をひらがなにすることは、多少読みやすくはなるかもしれないが、負担軽減効果は限定的と考えられる。\n選択肢3：効能・効果の印字を追加することは、薬剤の理解には役立つかもしれないが、セット作業の負担軽減には直接つながらない。\n選択肢4：服用時点ごとに色分けしたラインを引くことも、父の識別を助ける工夫ではあるが、フォントサイズ拡大（2）や服薬回数削減（5）ほどの直接的な負担軽減効果は期待しにくいかもしれない。"
#     }
#   },
#   {
#     "問343": {
#       "回答": [
#         2,
#         4
#       ],
#       "理由": "一般用医薬品（かぜ薬4-②）の製造販売に関する記述について。\n選択肢2：医薬品の製造においては、GMP（Good Manufacturing Practice）に基づき、原料の受入れから製品の出荷に至るまでの工程管理や品質管理に関する記録（製造記録、品質試験記録など）を作成し、保管することが義務付けられている。原料の製造番号や秤量値などを記録した製造記録の作成は必須であるため、正しい。\n選択肢4：このかぜ薬にはジヒドロコデインリン酸塩が含まれており、これは「指定第二類医薬品」に分類されることが多い。指定第二類医薬品は、薬剤師または登録販売者が販売できる。登録販売者は、薬剤師が不在の場合でも、指定第二類医薬品を含む第二類・第三類医薬品を販売することができる（ただし情報提供努力義務等あり）。したがって、この記述は正しい。\n選択肢1について、ジヒドロコデインを含む医薬品は12歳未満の小児への使用は禁忌であるため、製造できない。\n選択肢3について、かぜ薬であり、販売前に痛みがないことを確認する必要はない。\n選択肢5について、当該薬局（製造所）で製造したものを、系列の他の店舗で販売するには、卸売販売業の許可など、追加の許可が必要となる場合がある。薬局の許可だけでは通常行えない。"
#     }
#   },
#   {
#     "問344": {
#       "回答": [
#         3
#       ],
#       "理由": "家族性高コレステロール血症（FH）で脂質低下薬（エゼチミブ/アトルバスタチン配合錠）を服用中の患者が妊娠を希望（または妊娠の可能性）している場合の薬剤変更について。スタチン（アトルバスタチン、ロスバスタチン等）は催奇形性のリスクから妊娠中は禁忌である。エゼチミブも妊娠中の安全性は確立しておらず、通常は中止する。妊娠中に脂質管理が必要な場合、薬物療法としては、吸収されずに作用する陰イオン交換樹脂（胆汁酸吸着薬）が選択肢となる。選択肢の中でこれに該当するのはコレスチミド（選択肢3）である。\n選択肢1のロスバスタチンはスタチンであり禁忌。\n選択肢2のプロブコールは妊娠中の安全性が確立しておらず、組織に長く残留するため避けるべき。\n選択肢4のペマフィブラート（フィブラート系）は主に高中性脂肪血症に用いられ、妊娠中の安全性は確立していない。\n選択肢5のロミタピドはホモ接合体FH治療薬であり、妊娠中は禁忌。"
#     }
#   },
#   {
#     "問345": {
#       "回答": [
#         3,
#         4
#       ],
#       "理由": "ベバシズマブ（VEGF阻害薬）の重大な副作用である血栓塞栓症の早期発見のために患者に伝えておくべき自覚症状について。血栓塞栓症は、発生部位によって症状が異なる。肺塞栓症（PE）では突然の胸の痛みや呼吸困難、心筋梗塞（MI）では胸の痛みや圧迫感、脳梗塞では片麻痺・言語障害・意識障害、深部静脈血栓症（DVT）では片側の下肢の腫脹・疼痛などが現れる。選択肢の中で、胸の痛み（選択肢4）はPEやMIを疑う重要な症状である。また、黒色便（選択肢3）は上部消化管出血（メレナ）を示唆する症状であり、ベバシズマブのもう一つの重大な副作用である消化管穿孔や出血に関連する可能性がある。血栓塞栓症そのものの症状ではないが、ベバシズマブ投与中に注意すべき重篤な症状として挙げられる。\n選択肢1の口渇、選択肢2の苦味、選択肢5の味覚障害は、血栓塞栓症に特異的な症状ではない。\nしたがって、血栓塞栓症（胸の痛み）および関連する重篤な副作用（出血を示唆する黒色便）として、4と3が注意すべき自覚症状と考えられる。"
#     }
#   }
# ]
#
# --- 重複エラー情報 ---
# 重複エラーはありませんでした。
#
# 最終結果を 'gemini_vision_combined_output.json' に保存しました。
#
# --- 全ての処理が完了しました ---

# %%
#print(response.text)

# %%
  AnswerData = {
    "問1"  : [(3,  )],  "問2"  : [(4,  )],  "問3"  : [(5,  )],  "問4"  : [(5,  )],  "問5"  : [(1,  )],  "問6"  : [(4,  )],  "問7"  : [(3,  )],  "問8"  : [(5,  )],  "問9"  : [(4,  )],  "問10" : [(3,  )],
    "問11" : [(3,  )],  "問12" : [(5,  )],  "問13" : [(3,  )],  "問14" : [(5,  )],  "問15" : [(2,  )],  "問16" : [(4,  )],  "問17" : [(1,  )],  "問18" : [(3,  )],  "問19" : [(3,  )],  "問20" : [(3,  )],
    "問21" : [(1,  )],  "問22" : [(4,  )],  "問23" : [(4,  )],  "問24" : [(2,  )],  "問25" : [(2,  )],  "問26" : [(4,  )],  "問27" : [(1,  )],  "問28" : [(5,  )],  "問29" : [(1,  )],  "問30" : [(3,  )],
    "問31" : [(4,  )],  "問32" : [(4,  )],  "問33" : [(5,  )],  "問34" : [(1,  )],  "問35" : [(5,  )],  "問36" : [(3,  )],  "問37" : [(2,  )],  "問38" : [(3,  )],  "問39" : [(3,  )],  "問40" : [(2,  )],
    "問41" : [(5,  )],  "問42" : [(4,  )],  "問43" : [(5,  )],  "問44" : [(2,  )],  "問45" : [(3,  )],  "問46" : [(4,  )],  "問47" : [(4,  )],  "問48" : [(4,  )],  "問49" : [(5,  )],  "問50" : [(1,  )],
    "問51" : [(2,  )],  "問52" : [(2,  )],  "問53" : [(1,  )],  "問54" : [(3,  )],  "問55" : [(1,  )],  "問56" : [(2,  )],  "問57" : [(2,  )],  "問58" : [(4,  )],  "問59" : [(1,  )],  "問60" : [(5,  )],
    "問61" : [(1,  )],  "問62" : [(3,  )],  "問63" : [(1,  )],  "問64" : [(2,  )],  "問65" : [(1,  )],  "問66" : [(1,  )],  "問67" : [(4,  )],  "問68" : [(3,  )],  "問69" : [(4,  )],  "問70" : [(1,  )],
    "問71" : [(2,  )],  "問72" : [(3,  )],  "問73" : [(2,  )],  "問74" : [(3,  )],  "問75" : [(5,  )],  "問76" : [(2,  )],  "問77" : [(1,  )],  "問78" : [(3,  )],  "問79" : [(2,  )],  "問80" : [(2,  )],
    "問81" : [(5,  )],  "問82" : [(4,  )],  "問83" : [(2,  )],  "問84" : [(1,  )],  "問85" : [(5,  )],  "問86" : [(5,  )],  "問87" : [(4,  )],  "問88" : [(4,  )],  "問89" : [(3,  )],  "問90" : [(2,  )],
    "問91" : [(1, 2)],  "問92" : [(1, 4)],  "問93" : [(3,  )],  "問94" : [(1, 2)],  "問95" : [(1, 3)],  "問96" : [(4,  )],  "問97" : [(2,  )],  "問98" : [(2, 5)],  "問99" : [(1, 4)],  "問100": [(2, 4)],
    "問101": [(6,  )],  "問102": [(4,  )],  "問103": [(3, 4)],  "問104": [(4, 5)],  "問105": [(1, 2)],  "問106": [(1,  )],  "問107": [(2,  )],  "問108": [(2, 4)],  "問109": [(2, 3)],  "問110": [(4,  )],
    "問111": [(1, 3)],  "問112": [(3,  )],  "問113": [(3, 4)],  "問114": [(3, 5)],  "問115": [(2, 3)],  "問116": [(2,  )],  "問117": [(3,  )],  "問118": [(1, 4)],  "問119": [(1, 3), (1, 5), (3, 5)],  "問120": [(2, 4)],
    "問121": [(2, 3)],  "問122": [(3, 5)],  "問123": [(2, 6)],  "問124": [(4, 5)],  "問125": [(3, 5)],  "問126": [(3, 5)],  "問127": [(1, 4)],  "問128": [(1, 3)],  "問129": [(3, 4)],  "問130": [(1, 3)],
    "問131": [(1, 3)],  "問132": [(1, 4)],  "問133": [(3, 5)],  "問134": [(1, 5)],  "問135": [(1, 5)],  "問136": [(1, 4)],  "問137": [(1, 4)],  "問138": [(1, 4)],  "問139": [(2, 3)],  "問140": [(2, 5)],
    "問141": [(1, 2)],  "問142": [(3, 4)],  "問143": [(3, 4)],  "問144": [(1, 2)],  "問145": [(1, 4)],  "問146": [(4, 5)],  "問147": [(1, 2)],  "問148": [(5  ,)],  "問149": [(3, 5)],  "問150": [(3, 4)],
    "問151": [(1, 2)],  "問152": [(2, 5)],  "問153": [(3, 4)],  "問154": [(1, 4)],  "問155": [(2, 5)],  "問156": [(1, 4)],  "問157": [(2, 4)],  "問158": [(2, 4)],  "問159": [(3, 4)],  "問160": [(1, 5)],
    "問161": [(1, 2)],  "問162": [(1, 5)],  "問163": [(3, 4)],  "問164": [(1, 5)],  "問165": [(2, 4)],  "問166": [(3, 4)],  "問167": [(1, 3)],  "問168": [(1,  )],  "問169": [(5,  )],  "問170": [(3,  )],
    "問171": [(1,  )],  "問172": [(2, 4)],  "問173": [(3, 5)],  "問174": [(3, 4)],  "問175": [(1, 3)],  "問176": [(3,  )],  "問177": [(2, 5)],  "問178": [(1, 3)],  "問179": [(3, 5)],  "問180": [(1, 4)],
    "問181": [(3,  )],  "問182": [(2, 3)],  "問183": [(4, 5)],  "問184": [(2, 5)],  "問185": [(1, 3)],  "問186": [(2, 4)],  "問187": [(2, 4)],  "問188": [(2, 5)],  "問189": [(1, 3)],  "問190": [(1, 3)],
    "問191": [(1, 3)],  "問192": [(2, 5)],  "問193": [(2, 4)],  "問194": [(3,  )],  "問195": [(1, 3)],  "問196": [(4,  )],  "問197": [(3,  )],  "問198": [(1, 2)],  "問199": [(3,  )],  "問200": [(2, 4)],
    "問201": [(3,  )],  "問202": [(3,  )],  "問203": [(1, 4)],  "問204": [(2, 4)],  "問205": [(2, 3)],  "問206": [(3,  )],  "問207": [(3, 4)],  "問208": [(2, 3)],  "問209": [(1,  )],  "問210": [(4,  )],
    "問211": [(3,  )],  "問212": [(5,  )],  "問213": [(2, 4)],  "問214": [(2, 4)],  "問215": [(4,  )],  "問216": [(1, 2)],  "問217": [(4,  )],  "問218": [(3, 4)],  "問219": [(1, 4)],  "問220": [(2, 5)],
    "問221": [(2, 5)],  "問222": [(3, 5)],  "問223": [(1, 2)],  "問224": [(4,  )],  "問225": [(3,  )],  "問226": [(2, 3)],  "問227": [(5,  )],  "問228": [(3, 5)],  "問229": [(1,  )],  "問230": [(1, 3)],
    "問231": [(2, 3)],  "問232": [(1,  )],  "問233": [(4, 5)],  "問234": [(1, 3)],  "問235": [(5,  )],  "問236": [(1, 4)],  "問237": [(4,  )],  "問238": [(4,  )],  "問239": [(2, 5)],  "問240": [(1, 5)],
    "問241": [(2, 5)],  "問242": [(3,  )],  "問243": [(3, 5)],  "問244": [(2, 5)],  "問245": [(1, 3)],  "問246": [(3, 5)],  "問247": [(4,  )],  "問248": [(1, 4)],  "問249": [(4, 5)],  "問250": [(1, 5)],
    "問251": [(3, 5)],  "問252": [(2, 3)],  "問253": [(1, 3)],  "問254": [(3,  )],  "問255": [(3, 4)],  "問256": [(4, 5)],  "問257": [(4,  )],  "問258": [(3,  )],  "問259": [(2,  )],  "問260": [(2, 3)],
    "問261": [(2, 5)],  "問262": [(2, 3)],  "問263": [(2, 5)],  "問264": [(2, 5)],  "問265": [(1, 2)],  "問266": [(2,  )],  "問267": [(1, 4)],  "問268": [(1, 3)],  "問269": [(2,  )],  "問270": [(5,  )],
    "問271": [(3,  )],  "問272": [(3, 5)],  "問273": [(1, 3)],  "問274": [(4,  )],  "問275": [(2, 5)],  "問276": [(2, 3)],  "問277": [(1, 2)],  "問278": [(3, 4)],  "問279": [(4,  )],  "問280": [(1, 5)],
    "問281": [(1,  )],  "問282": [(1, 4)],  "問283": [(1, 3)],  "問284": [(2, 5)],  "問285": [(3, 5)],  "問286": [(1, 3)],  "問287": [(3, 5)],  "問288": [(1, 4)],  "問289": [(1,  )],  "問290": [(2,  )],
    "問291": [(2,  )],  "問292": [(3, 5)],  "問293": [(2, 3)],  "問294": [(1, 2)],  "問295": [(1, 5)],  "問296": [(4, 5)],  "問297": [(2, 4)],  "問298": [(1, 2)],  "問299": [(2, 4)],  "問300": [(4, 5)],
    "問301": [(4,  )],  "問302": [(1, 3)],  "問303": [(3, 4)],  "問304": [(2, 3)],  "問305": [(1, 4)],  "問306": [(1, 2)],  "問307": [(1, 5)],  "問308": [(1, 3)],  "問309": [(1, 5)],  "問310": [(2, 5)],
    "問311": [(4,  )],  "問312": [(1, 5)],  "問313": [(3, 5)],  "問314": [(2, 4)],  "問315": [(5,  )],  "問316": [(1, 3)],  "問317": [(3, 5)],  "問318": [(2, 4)],  "問319": [(4, 5)],  "問320": [(3, 4)],
    "問321": [(2,  )],  "問322": [(3, 5)],  "問323": [(4, 5)],  "問324": [(1, 2)],  "問325": [(2,  )],  "問326": [(3,  )],  "問327": [(2,  )],  "問328": [(2, 4)],  "問329": [(3,  )],  "問330": [(1, 4)],
    "問331": [(1, 2), (1, 5), (2, 5)],  "問332": [(1, 4)],  "問333": [(5,  )],  "問334": [(4, 5)],  "問335": [(3,  )],  "問336": [(4, 5)],  "問337": [(1, 3)],  "問338": [(3,  )],  "問339": [(4,  )],  "問340": [(2, 4)],
    "問341": [(4, 5)],  "問342": [(2, 4)],  "問343": [(2, 3)],  "問344": [(3,  )],  "問345": [(2, 4)]
}

# %%
Category = {
    "問1"  : "物理",  "問2"  : "物理",  "問3"  : "物理",  "問4"  : "物理",  "問5"  : "物理",  "問6"  : "化学",  "問7"  : "化学",  "問8"  : "化学",  "問9"  : "化学",  "問10" : "化学",
    "問11" : "生物",  "問12" : "生物",  "問13" : "生物",  "問14" : "生物",  "問15" : "生物",  "問16" : "衛生",  "問17" : "衛生",  "問18" : "衛生",  "問19" : "衛生",  "問20" : "衛生",
    "問21" : "衛生",  "問22" : "衛生",  "問23" : "衛生",  "問24" : "衛生",  "問25" : "衛生",  "問26" : "薬理",  "問27" : "薬理",  "問28" : "薬理",  "問29" : "薬理",  "問30" : "薬理",
    "問31" : "薬理",  "問32" : "薬理",  "問33" : "薬理",  "問34" : "薬理",  "問35" : "薬理",  "問36" : "薬理",  "問37" : "薬理",  "問38" : "薬理",  "問39" : "薬理",  "問40" : "薬理",
    "問41" : "薬剤",  "問42" : "薬剤",  "問43" : "薬剤",  "問44" : "薬剤",  "問45" : "薬剤",  "問46" : "薬剤",  "問47" : "薬剤",  "問48" : "薬剤",  "問49" : "薬剤",  "問50" : "薬剤",
    "問51" : "薬剤",  "問52" : "薬剤",  "問53" : "薬剤",  "問54" : "薬剤",  "問55" : "薬剤",  "問56" : "病態",  "問57" : "病態",  "問58" : "病態",  "問59" : "病態",  "問60" : "病態",
    "問61" : "病態",  "問62" : "病態",  "問63" : "病態",  "問64" : "病態",  "問65" : "病態",  "問66" : "病態",  "問67" : "病態",  "問68" : "病態",  "問69" : "病態",  "問70" : "病態",
    "問71" : "法規",  "問72" : "法規",  "問73" : "法規",  "問74" : "法規",  "問75" : "法規",  "問76" : "法規",  "問77" : "法規",  "問78" : "法規",  "問79" : "法規",  "問80" : "法規",
    "問81" : "実務",  "問82" : "実務",  "問83" : "実務",  "問84" : "実務",  "問85" : "実務",  "問86" : "実務",  "問87" : "実務",  "問88" : "実務",  "問89" : "実務",  "問90" : "実務",
    "問91" : "物理",  "問92" : "物理",  "問93" : "物理",  "問94" : "物理",  "問95" : "物理",  "問96" : "物理",  "問97" : "物理",  "問98" : "物理",  "問99" : "物理",  "問100": "物理",
    "問101": "化学",  "問102": "化学",  "問103": "化学",  "問104": "化学",  "問105": "化学",  "問106": "化学",  "問107": "化学",  "問108": "化学",  "問109": "化学",  "問110": "化学",
    "問111": "生物",  "問112": "生物",  "問113": "生物",  "問114": "生物",  "問115": "生物",  "問116": "生物",  "問117": "生物",  "問118": "生物",  "問119": "生物",  "問120": "衛生",
    "問121": "生物",  "問122": "衛生",  "問123": "衛生",  "問124": "衛生",  "問125": "衛生",  "問126": "衛生",  "問127": "衛生",  "問128": "衛生",  "問129": "衛生",  "問130": "衛生",
    "問131": "衛生",  "問132": "衛生",  "問133": "衛生",  "問134": "衛生",  "問135": "衛生",  "問136": "衛生",  "問137": "衛生",  "問138": "衛生",  "問139": "衛生",  "問140": "衛生",
    "問141": "法規",  "問142": "法規",  "問143": "法規",  "問144": "法規",  "問145": "法規",  "問146": "法規",  "問147": "法規",  "問148": "法規",  "問149": "法規",  "問150": "法規",
    "問151": "薬理",  "問152": "薬理",  "問153": "薬理",  "問154": "薬理",  "問155": "薬理",  "問156": "薬理",  "問157": "病態",  "問158": "薬理",  "問159": "薬理",  "問160": "薬理",
    "問161": "薬理",  "問162": "病態",  "問163": "薬理",  "問164": "薬理",  "問165": "病態",  "問166": "薬理",  "問167": "薬理",  "問168": "薬理",  "問169": "薬剤",  "問170": "薬剤",
    "問171": "薬剤",  "問172": "薬剤",  "問173": "薬剤",  "問174": "薬剤",  "問175": "薬剤",  "問176": "薬剤",  "問177": "薬剤",  "問178": "薬剤",  "問179": "薬剤",  "問180": "薬剤",
    "問181": "薬剤",  "問182": "薬剤",  "問183": "薬剤",  "問184": "病態",  "問185": "病態",  "問186": "病態",  "問187": "病態",  "問188": "病態",  "問189": "病態",  "問190": "病態",
    "問191": "病態",  "問192": "病態",  "問193": "病態",  "問194": "病態",  "問195": "病態",  "問196": "物理",  "問197": "実務",  "問198": "実務",  "問199": "物理",  "問200": "実務",
    "問201": "物理",  "問202": "物理",  "問203": "実務",  "問204": "物理",  "問205": "実務",  "問206": "衛生",  "問207": "実務",  "問208": "実務",  "問209": "化学",  "問210": "化学",
    "問211": "実務",  "問212": "化学",  "問213": "実務",  "問214": "実務",  "問215": "化学",  "問216": "実務",  "問217": "化学",  "問218": "実務",  "問219": "生物",  "問220": "実務",
    "問221": "生物",  "問222": "生物",  "問223": "実務",  "問224": "実務",  "問225": "生物",  "問226": "実務",  "問227": "生物",  "問228": "実務",  "問229": "衛生",  "問230": "衛生",
    "問231": "実務",  "問232": "実務",  "問233": "衛生",  "問234": "衛生",  "問235": "実務",  "問236": "実務",  "問237": "衛生",  "問238": "衛生",  "問239": "実務",  "問240": "実務",
    "問241": "衛生",  "問242": "衛生",  "問243": "実務",  "問244": "実務",  "問245": "衛生",  "問246": "薬理",  "問247": "実務",  "問248": "実務",  "問249": "薬理",  "問250": "薬理",
    "問251": "実務",  "問252": "実務",  "問253": "薬理",  "問254": "薬理",  "問255": "実務",  "問256": "薬理",  "問257": "実務",  "問258": "実務",  "問259": "薬理",  "問260": "実務",
    "問261": "薬理",  "問262": "実務",  "問263": "薬理",  "問264": "実務",  "問265": "薬理",  "問266": "薬剤",  "問267": "実務",  "問268": "実務",  "問269": "薬剤",  "問270": "薬剤",
    "問271": "実務",  "問272": "薬剤",  "問273": "実務",  "問274": "薬剤",  "問275": "実務",  "問276": "薬剤",  "問277": "実務",  "問278": "実務",  "問279": "薬剤",  "問280": "実務",
    "問281": "薬剤",  "問282": "薬剤",  "問283": "実務",  "問284": "薬剤",  "問285": "実務",  "問286": "病態",  "問287": "実務",  "問288": "病態",  "問289": "実務",  "問290": "実務",
    "問291": "病態",  "問292": "病態",  "問293": "実務",  "問294": "病態",  "問295": "実務",  "問296": "病態",  "問297": "実務",  "問298": "実務",  "問299": "病態",  "問300": "病態",
    "問301": "実務",  "問302": "病態",  "問303": "実務",  "問304": "病態",  "問305": "実務",  "問306": "実務",  "問307": "法規",  "問308": "実務",  "問309": "法規",  "問310": "法規",
    "問311": "実務",  "問312": "実務",  "問313": "法規",  "問314": "実務",  "問315": "法規",  "問316": "実務",  "問317": "法規",  "問318": "実務",  "問319": "法規",  "問320": "法規",
    "問321": "実務",  "問322": "実務",  "問323": "法規",  "問324": "実務",  "問325": "法規",  "問326": "実務",  "問327": "実務",  "問328": "実務",  "問329": "実務",  "問330": "実務",
    "問331": "実務",  "問332": "実務",  "問333": "実務",  "問334": "実務",  "問335": "実務",  "問336": "実務",  "問337": "実務",  "問338": "実務",  "問339": "実務",  "問340": "実務",
    "問341": "実務",  "問342": "実務",  "問343": "実務",  "問344": "実務",  "問345": "実務"
}

# %%
import pandas as pd

with open('gemini_vision_combined_output.json', 'r') as f:
  Result = json.load(f)

# Resultデータを処理しやすいように辞書形式に変換
result_dict = {}
for item in Result:
    for key, value in item.items():
        result_dict[key] = value

# データフレーム用の中間リストを作成
df_data = []

# AnswerData_sampleのキー（問題番号）を基準にループ
for question, correct_answers in AnswerData.items():
    # 各情報を取得
    subject = Category.get(question, "N/A") # カテゴリが見つからない場合のデフォルト値
    user_data = result_dict.get(question, {"回答": [], "理由": ""}) # 結果が見つからない場合
    user_answer_raw = user_data.get("回答", [])
    reason = user_data.get("理由", "")

    # ユーザー回答をソートしてタプルに変換（比較用）
    # user_answer_rawが空リストの場合も考慮
    user_answer_sorted_tuple = tuple(sorted(user_answer_raw)) if user_answer_raw else ()

    # 正解リスト内の各タプルもソート（比較用）
    correct_answers_sorted = [tuple(sorted(ans)) for ans in correct_answers]

    # 正誤判定
    is_correct = user_answer_sorted_tuple in correct_answers_sorted
    correct_status = "○" if is_correct else "×"

    # リストに追加
    df_data.append({
        "問": question,
        "科目": subject,
        "解答": correct_answers,   # 元の解答データを格納
        "正誤": correct_status,
        "回答": user_answer_raw, # 元の回答データを格納
        "理由": reason
    })

# データフレームを作成
df = pd.DataFrame(df_data)

# カラムの順序を指定
df = df[["問", "科目", "解答", "正誤", "回答", "理由"]]

# --- 結果の表示 ---
df.style.set_properties(**{'text-align': 'left'})
# Out:
# --- サンプルデータ ---
# AnswerData_sample: {'問1': [(3,)], '問2': [(4,)], '問3': [(5,)], '問4': [(5,)], '問5': [(1,)], '問6': [(4,)], '問7': [(3,)], '問8': [(5,)], '問9': [(4,)], '問10': [(3,)], '問11': [(3,)], '問12': [(5,)], '問13': [(3,)], '問14': [(5,)], '問15': [(2,)], '問16': [(4,)], '問17': [(1,)], '問18': [(3,)], '問19': [(3,)], '問20': [(3,)], '問21': [(1,)], '問22': [(4,)], '問23': [(4,)], '問24': [(2,)], '問25': [(2,)], '問26': [(4,)], '問27': [(1,)], '問28': [(5,)], '問29': [(1,)], '問30': [(3,)], '問31': [(4,)], '問32': [(4,)], '問33': [(5,)], '問34': [(1,)], '問35': [(5,)], '問36': [(3,)], '問37': [(2,)], '問38': [(3,)], '問39': [(3,)], '問40': [(2,)], '問41': [(5,)], '問42': [(4,)], '問43': [(5,)], '問44': [(2,)], '問45': [(3,)], '問46': [(4,)], '問47': [(4,)], '問48': [(4,)], '問49': [(5,)], '問50': [(1,)], '問51': [(2,)], '問52': [(2,)], '問53': [(1,)], '問54': [(3,)], '問55': [(1,)], '問56': [(2,)], '問57': [(2,)], '問58': [(4,)], '問59': [(1,)], '問60': [(5,)], '問61': [(1,)], '問62': [(3,)], '問63': [(1,)], '問64': [(2,)], '問65': [(1,)], '問66': [(1,)], '問67': [(4,)], '問68': [(3,)], '問69': [(4,)], '問70': [(1,)], '問71': [(2,)], '問72': [(3,)], '問73': [(2,)], '問74': [(3,)], '問75': [(5,)], '問76': [(2,)], '問77': [(1,)], '問78': [(3,)], '問79': [(2,)], '問80': [(2,)], '問81': [(5,)], '問82': [(4,)], '問83': [(2,)], '問84': [(1,)], '問85': [(5,)], '問86': [(5,)], '問87': [(4,)], '問88': [(4,)], '問89': [(3,)], '問90': [(2,)], '問91': [(1, 2)], '問92': [(1, 4)], '問93': [(3,)], '問94': [(1, 2)], '問95': [(1, 3)], '問96': [(4,)], '問97': [(2,)], '問98': [(2, 5)], '問99': [(1, 4)], '問100': [(2, 4)], '問101': [(6,)], '問102': [(4,)], '問103': [(3, 4)], '問104': [(4, 5)], '問105': [(1, 2)], '問106': [(1,)], '問107': [(2,)], '問108': [(2, 4)], '問109': [(2, 3)], '問110': [(4,)], '問111': [(1, 3)], '問112': [(3,)], '問113': [(3, 4)], '問114': [(3, 5)], '問115': [(2, 3)], '問116': [(2,)], '問117': [(3,)], '問118': [(1, 4)], '問119': [(1, 3), (1, 5), (3, 5)], '問120': [(2, 4)], '問121': [(2, 3)], '問122': [(3, 5)], '問123': [(2, 6)], '問124': [(4, 5)], '問125': [(3, 5)], '問126': [(3, 5)], '問127': [(1, 4)], '問128': [(1, 3)], '問129': [(3, 4)], '問130': [(1, 3)], '問131': [(1, 3)], '問132': [(1, 4)], '問133': [(3, 5)], '問134': [(1, 5)], '問135': [(1, 5)], '問136': [(1, 4)], '問137': [(1, 4)], '問138': [(1, 4)], '問139': [(2, 3)], '問140': [(2, 5)], '問141': [(1, 2)], '問142': [(3, 4)], '問143': [(3, 4)], '問144': [(1, 2)], '問145': [(1, 4)], '問146': [(4, 5)], '問147': [(1, 2)], '問148': [(5,)], '問149': [(3, 5)], '問150': [(3, 4)], '問151': [(1, 2)], '問152': [(2, 5)], '問153': [(3, 4)], '問154': [(1, 4)], '問155': [(2, 5)], '問156': [(1, 4)], '問157': [(2, 4)], '問158': [(2, 4)], '問159': [(3, 4)], '問160': [(1, 5)], '問161': [(1, 2)], '問162': [(1, 5)], '問163': [(3, 4)], '問164': [(1, 5)], '問165': [(2, 4)], '問166': [(3, 4)], '問167': [(1, 3)], '問168': [(1,)], '問169': [(5,)], '問170': [(3,)], '問171': [(1,)], '問172': [(2, 4)], '問173': [(3, 5)], '問174': [(3, 4)], '問175': [(1, 3)], '問176': [(3,)], '問177': [(2, 5)], '問178': [(1, 3)], '問179': [(3, 5)], '問180': [(1, 4)], '問181': [(3,)], '問182': [(2, 3)], '問183': [(4, 5)], '問184': [(2, 5)], '問185': [(1, 3)], '問186': [(2, 4)], '問187': [(2, 4)], '問188': [(2, 5)], '問189': [(1, 3)], '問190': [(1, 3)], '問191': [(1, 3)], '問192': [(2, 5)], '問193': [(2, 4)], '問194': [(3,)], '問195': [(1, 3)], '問196': [(4,)], '問197': [(3,)], '問198': [(1, 2)], '問199': [(3,)], '問200': [(2, 4)], '問201': [(3,)], '問202': [(3,)], '問203': [(1, 4)], '問204': [(2, 4)], '問205': [(2, 3)], '問206': [(3,)], '問207': [(3, 4)], '問208': [(2, 3)], '問209': [(1,)], '問210': [(4,)], '問211': [(3,)], '問212': [(5,)], '問213': [(2, 4)], '問214': [(2, 4)], '問215': [(4,)], '問216': [(1, 2)], '問217': [(4,)], '問218': [(3, 4)], '問219': [(1, 4)], '問220': [(2, 5)], '問221': [(2, 5)], '問222': [(3, 5)], '問223': [(1, 2)], '問224': [(4,)], '問225': [(3,)], '問226': [(2, 3)], '問227': [(5,)], '問228': [(3, 5)], '問229': [(1,)], '問230': [(1, 3)], '問231': [(2, 3)], '問232': [(1,)], '問233': [(4, 5)], '問234': [(1, 3)], '問235': [(5,)], '問236': [(1, 4)], '問237': [(4,)], '問238': [(4,)], '問239': [(2, 5)], '問240': [(1, 5)], '問241': [( ...
# Category_sample: {'問1': '物理', '問2': '物理', '問3': '物理', '問4': '物理', '問5': '物理', '問6': '化学', '問7': '化学', '問8': '化学', '問9': '化学', '問10': '化学', '問11': '生物', '問12': '生物', '問13': '生物', '問14': '生物', '問15': '生物', '問16': '衛生', '問17': '衛生', '問18': '衛生', '問19': '衛生', '問20': '衛生', '問21': '衛生', '問22': '衛生', '問23': '衛生', '問24': '衛生', '問25': '衛生', '問26': '薬理', '問27': '薬理', '問28': '薬理', '問29': '薬理', '問30': '薬理', '問31': '薬理', '問32': '薬理', '問33': '薬理', '問34': '薬理', '問35': '薬理', '問36': '薬理', '問37': '薬理', '問38': '薬理', '問39': '薬理', '問40': '薬理', '問41': '薬剤', '問42': '薬剤', '問43': '薬剤', '問44': '薬剤', '問45': '薬剤', '問46': '薬剤', '問47': '薬剤', '問48': '薬剤', '問49': '薬剤', '問50': '薬剤', '問51': '薬剤', '問52': '薬剤', '問53': '薬剤', '問54': '薬剤', '問55': '薬剤', '問56': '病態', '問57': '病態', '問58': '病態', '問59': '病態', '問60': '病態', '問61': '病態', '問62': '病態', '問63': '病態', '問64': '病態', '問65': '病態', '問66': '病態', '問67': '病態', '問68': '病態', '問69': '病態', '問70': '病態', '問71': '法規', '問72': '法規', '問73': '法規', '問74': '法規', '問75': '法規', '問76': '法規', '問77': '法規', '問78': '法規', '問79': '法規', '問80': '法規', '問81': '実務', '問82': '実務', '問83': '実務', '問84': '実務', '問85': '実務', '問86': '実務', '問87': '実務', '問88': '実務', '問89': '実務', '問90': '実務', '問91': '物理', '問92': '物理', '問93': '物理', '問94': '物理', '問95': '物理', '問96': '物理', '問97': '物理', '問98': '物理', '問99': '物理', '問100': '物理', '問101': '化学', '問102': '化学', '問103': '化学', '問104': '化学', '問105': '化学', '問106': '化学', '問107': '化学', '問108': '化学', '問109': '化学', '問110': '化学', '問111': '生物', '問112': '生物', '問113': '生物', '問114': '生物', '問115': '生物', '問116': '生物', '問117': '生物', '問118': '生物', '問119': '生物', '問120': '衛生', '問121': '生物', '問122': '衛生', '問123': '衛生', '問124': '衛生', '問125': '衛生', '問126': '衛生', '問127': '衛生', '問128': '衛生', '問129': '衛生', '問130': '衛生', '問131': '衛生', '問132': '衛生', '問133': '衛生', '問134': '衛生', '問135': '衛生', '問136': '衛生', '問137': '衛生', '問138': '衛生', '問139': '衛生', '問140': '衛生', '問141': '法規', '問142': '法規', '問143': '法規', '問144': '法規', '問145': '法規', '問146': '法規', '問147': '法規', '問148': '法規', '問149': '法規', '問150': '法規', '問151': '薬理', '問152': '薬理', '問153': '薬理', '問154': '薬理', '問155': '薬理', '問156': '薬理', '問157': '病態', '問158': '薬理', '問159': '薬理', '問160': '薬理', '問161': '薬理', '問162': '病態', '問163': '薬理', '問164': '薬理', '問165': '病態', '問166': '薬理', '問167': '薬理', '問168': '薬理', '問169': '薬剤', '問170': '薬剤', '問171': '薬剤', '問172': '薬剤', '問173': '薬剤', '問174': '薬剤', '問175': '薬剤', '問176': '薬剤', '問177': '薬剤', '問178': '薬剤', '問179': '薬剤', '問180': '薬剤', '問181': '薬剤', '問182': '薬剤', '問183': '薬剤', '問184': '病態', '問185': '病態', '問186': '病態', '問187': '病態', '問188': '病態', '問189': '病態', '問190': '病態', '問191': '病態', '問192': '病態', '問193': '病態', '問194': '病態', '問195': '病態', '問196': '物理', '問197': '実務', '問198': '実務', '問199': '物理', '問200': '実務', '問201': '物理', '問202': '物理', '問203': '実務', '問204': '物理', '問205': '実務', '問206': '衛生', '問207': '実務', '問208': '実務', '問209': '化学', '問210': '化学', '問211': '実務', '問212': '化学', '問213': '実務', '問214': '実務', '問215': '化学', '問216': '実務', '問217': '化学', '問218': '実務', '問219': '生物', '問220': '実務', '問221': '生物', '問222': '生物', '問223': '実務', '問224': '実務', '問225': '生物', '問226': '実務', '問227': '生物', '問228': '実務', '問229': '衛生', '問230': '衛生', '問231': '実務', '問232': '実務', '問233': '衛生', '問234': '衛生', '問235': '実務', '問236': '実務', '問237': '衛生', '問238': '衛生', '問239': '実務', '問240': '実務', '問241': '衛生', '問242': '衛生', '問243': '実務', '問244': '実務', '問245': '衛生', '問246': '薬理', '問247': '実務', '問248': '実務', '問249': '薬理', '問250': '薬理', '問251': '実務', '問252': '実務', '問253': '薬理', '問254': '薬理', '問255': '実務', '問256': '薬理', '問257': '実務', '問258': '実務', '問259': '薬理', '問260': '実務', '問261': '薬理', '問262': '実務', '問263': '薬理', '問264': '実務', '問265': '薬理', '問266': '薬剤', '問267': '実務', '問268': '実務', '問269': '薬剤', '問270': '薬剤', '問271': '実務', '問272': '薬剤', '問273': '実務', '問274': '薬剤', '問275': '実務', '問276': '薬剤', '問277': '実務', '問278': '実務', '問279': '薬剤', '問280': '実務', '問281': '薬剤', '問282': '薬剤', '問283': '実務', '問284': '薬剤', '問285': '実務', '問286': '病態', '問287': '実務', '問288': '病態', '問289': '実務', '問290': '実務', '問291': '病態', '問292': '病態', '問 ...
# Result_sample: [{'問1': {'回答': [3], '理由': 'ダニエル電池の起電力は、正極（銅）の標準電極電位から負極（亜鉛）の標準電極電位を引いて求める。正極の電位は+0.337 V、負極の電位は-0.763 Vであるため、起電力 = (+0.337 V) - (-0.763 V) = +1.100 V となる。したがって、選択肢3が正しい。'}}, {'問2': {'回答': [4], '理由': '熱力学における閉じた系とは、外界との間で物質の移動はないが、エネルギー（熱や仕事）のやりとりは可能な系を指す。選択肢の中で、熱と仕事はエネルギーの形態であり、閉じた系で外界とやりとりできる。物質はやりとりできない。したがって、熱と仕事の組み合わせである選択肢4が正しい。'}}, {'問3': {'回答': [5], '理由': '難溶性塩である水酸化鉄(III) Fe(OH)₃ の溶解平衡は Fe(OH)₃ ⇌ Fe³⁺ + 3OH⁻ で表される。純水中での溶解度を S [mol/L] とすると、平衡時のイオン濃度は [Fe³⁺] = S [mol/L]、[OH⁻] = 3S [mol/L] となる。溶解度積 Ksp は、これらのイオン濃度の積で表され、Ksp = [Fe³⁺][OH⁻]³ = (S) * (3S)³ = S * 27S³ = 27S⁴ [(mol/L)⁴] となる。したがって、選択肢5が正しい。'}}, {'問4': {'回答': [5], '理由': 'スピン量子数が1/2である原子核（例: ¹H, ¹³C）が外部磁場中に置かれると、核スピンの磁気モーメントと外部磁場の相互作用により、エネルギー準位が分裂する。この現象はゼーマン効果（ゼーマン分裂）と呼ばれる。これにより、NMR（核磁気共鳴）分光法が可能となる。化学シフトは核周囲の電子環境による共鳴周波数の差、McLafferty転位やラジカル開裂は質量分析におけるイオンの開裂様式、超微細分裂は電子スピンと核スピンなどの相互作用による分裂である。したがって、選択肢5が正しい。'}}, {'問5': {'回答': [1], '理由': '初期の薬物Xの物質量は 50 mmol。水相の体積は 100 mL。酢酸エチル相（体積 V mL）に抽出後、酢酸エチル相中のXは 45 mmol。したがって、水相に残ったXは 50 - 45 = 5 mmol。分配係数 K は (酢酸エチル相中の濃度) / (水相中の濃度) で定義される。酢酸エチル相中の濃度は 45/V [mmol/mL]、水相中の濃度は 5/100 [mmol/mL]。分配係数は 18 なので、K = (45/V) / (5/100) = 18。これを解くと、(45/V) * (100/5) = 18 => (45/V) * 20 = 18 => 900/V = 18 => V = 900 / 18 = 50 [mL]。したがって、酢酸エチル相の体積は 50 mL であり、選択肢1が正しい。'}}, {'問6': {'回答': [1], '理由': 'アノマーとは、環状構造を持つ糖において、ヘミアセタール（またはヘミケタール）炭素（アノマー炭素、通常は1位または2位）の立体配置のみが異なる異性体のこと。化合物Aはβ-D-グルコピラノースである（1位のOH基が上向き）。選択肢1はα-D-グルコピラノース（1位のOH基が下向き）であり、化合物Aのアノマーである。選択肢2はD-マンノース（2位のエピマー）、選択肢3はD-ガラクトース（4位のエピマー）、選択肢4はL-グルコース（鏡像異性体）、選択肢5はD-フルクトフラノース（構造異性体）である。したがって、選択肢1が正しい。'}}, {'問7': {'回答': [5], '理由': '示された薬物の構造は、スルホンアミド基(-SO₂NH₂)とアミド基(-CONH₂)を持つ。この構造は、炭酸脱水酵素阻害薬であるアセタゾラミドに類似している。炭酸脱水酵素は活性中心に亜鉛(Zn)イオンを持つ金属酵素である。この種の阻害薬は、活性中心のZnイオンに配位することで酵素活性を阻害する。したがって、この薬物に含まれる金属元素Mとして最も可能性が高いのは亜鉛(Zn)である。選択肢5が正しい。'}}, {'問8': {'回答': [5], '理由': '化合物の酸性度は、プロトンを放出した後の共役塩基の安定性に依存する。選択肢1はシクロヘキサノールで脂肪族アルコールであり、酸性度は非常に低い。選択肢2-5はフェノール誘導体であり、フェノール性水酸基を持つため、1より酸性度が高い。フェノール(2)と比較して、置換基が共役塩基（フェノキシドイオン）を安定化させるほど酸性度は高くなる。アミノ基(-NH₂)は電子供与基であり、共役塩基を不安定化させるため酸性度は低い(3)。塩素原子(-Cl)は誘起効果により電子求引性を示し、共役塩基をやや安定化させるため酸性度は2より高い(4)。ニトロ基(-NO₂)は誘起効果および共鳴効果により強い電子求引性を示し、共役塩基の負電荷を非局在化させて最も安定化させるため、酸性度が最も高い(5)。したがって、選択肢5が正しい。'}}, {'問9': {'回答': [4], '理由': 'ベンジルカチオンの安定性は、カチオン中心の正電荷を非局在化させる置換基によって向上する。メトキシ基(-OCH₃)は、酸素原子の非共有電子対による共鳴効果（電子供与性）を持ち、ベンゼン環のオルト位およびパラ位に付くとカチオンを強く安定化させる。メタ位では共鳴効果による安定化は起こりにくい。選択肢1はオルト位、選択肢2はメタ位、選択肢3はパラ位に-OCH₃が1つ。選択肢4はオルト位とパラ位に-OCH₃が1つずつ。選択肢5はメタ位に2つ。ベンジルカチオンの正電荷は、カチオン中心の炭素、オルト位、パラ位に非局在化する。したがって、オルト位とパラ位の両方に電子供与性の-OCH₃基を持つ選択肢4が、最も効果的に正電荷を非局在化させ、カチオンを安定化する。したがって、選択肢4が正しい。'}}, {'問10': {'回答': [3], '理由': 'ビンクリスチンは、インドール環を含む複雑な構造を持つインドールアルカロイドである。インドールアルカロイドの生合成における基本的な前駆体は、インドール環を持つアミノ酸であるトリプトファンである。したがって、選択肢3が正しい。'}}, {'問11': {'回答': [3], '理由': '血管の中で、血管平滑筋細胞を持たず、血管内皮細胞とその外側の基底膜のみから構成されるのは毛細血管である。この薄い構造により、血液と組織の間で栄養成分、酸素、二酸化炭素、老廃物などの物質交換が効率的に行われる。大動脈、細動脈、大静脈は平滑筋層を持つ。胸管はリンパ管である。したがって、選択肢3が正しい。'}}, {'問12': {'回答': [5], '理由': 'ヒトにおいて、核酸に含まれるプリン塩基（アデニンとグアニン）は、代謝されて最終的に尿酸となる。アデニンはヒポキサンチンを経てキサンチンに、グアニンは直接キサンチンに変換され、キサンチンはキサンチンオキシダーゼによって尿酸に酸化される。構造式1はヒポキサンチン、2はグアニン、3はアデニン、4はキサンチン、5は尿酸である。したがって、最終代謝産物は尿酸であり、選択肢5が正しい。'}}, {'問13': {'回答': [3], '理由': '真核生物において、遺伝子の転写を開始するためには、RNAポリメラーゼIIがDNA上の特定の領域に結合する必要がある。この転写開始点を制御するDNA領域をプロモーターと呼ぶ。プロモーターにはTATAボックスなどの配列が含まれ、基本転写因子群とともにRNAポリメラーゼIIが結合する複合体を形成する。イントロンとエクソンは転写される領域、テロメアは染色体末端の保護構造、ターミネーターは転写終結シグナル領域である。したがって、選択肢3が正しい。'}}, {'問14': {'回答': [5], '理由': 'オステオカルシンは骨基質タンパク質の一つであり、カルシウムイオンと結合する能力を持つ。この結合能は、タンパク質合成後の翻訳後修飾によって獲得される。具体的には、オステオカルシン中の特定のグルタミン酸残基が、ビタミンK依存性の酵素によってγ位がカルボキシル化され、γ-カルボキシグルタミン酸(Gla)残基となる。このGla残基が2価の負電荷を持つため、カルシウムイオンと強く結合できるようになる。この修飾はカルボキシル化である。したがって、選択肢5が正しい。'}}, {'問15': {'回答': [2], '理由': 'ウイルス粒子において、中心にあるウイルスゲノム（核酸）を取り囲んでいるタンパク質の殻構造をカプシドと呼ぶ。カプシドは、カプソメアと呼ばれるタンパク質サブユニットから構成される。エンベロープは一部のウイルスが持つ脂質二重膜の外被、コアはゲノムとカプシドを合わせた内部構造、スパイクはエンベロープ表面の突起状タンパク質、ビリオンは感染性を有する完全なウイルス粒子全体を指す。したがって、選択肢2が正しい。'}}, {'問16': {'回答': [2], '理由': '提示されたグラフは、1950年代に高い値を示した後、急激に低下し、1970年代半ばに最低値を記録した後、緩やかに上昇し、近年再び低下傾向にある日本の人口動態指標を示している。この特徴的な推移は、合計特殊出生率（一人の女性 ...
#
# --- 生成されたデータフレーム ---
# <style type="text/css">
# #T_6a868_row0_col0, #T_6a868_row0_col1, #T_6a868_row0_col2, #T_6a868_row0_col3, #T_6a868_row0_col4, #T_6a868_row0_col5, #T_6a868_row1_col0, #T_6a868_row1_col1, #T_6a868_row1_col2, #T_6a868_row1_col3, #T_6a868_row1_col4, #T_6a868_row1_col5, #T_6a868_row2_col0, #T_6a868_row2_col1, #T_6a868_row2_col2, #T_6a868_row2_col3, #T_6a868_row2_col4, #T_6a868_row2_col5, #T_6a868_row3_col0, #T_6a868_row3_col1, #T_6a868_row3_col2, #T_6a868_row3_col3, #T_6a868_row3_col4, #T_6a868_row3_col5, #T_6a868_row4_col0, #T_6a868_row4_col1, #T_6a868_row4_col2, #T_6a868_row4_col3, #T_6a868_row4_col4, #T_6a868_row4_col5, #T_6a868_row5_col0, #T_6a868_row5_col1, #T_6a868_row5_col2, #T_6a868_row5_col3, #T_6a868_row5_col4, #T_6a868_row5_col5, #T_6a868_row6_col0, #T_6a868_row6_col1, #T_6a868_row6_col2, #T_6a868_row6_col3, #T_6a868_row6_col4, #T_6a868_row6_col5, #T_6a868_row7_col0, #T_6a868_row7_col1, #T_6a868_row7_col2, #T_6a868_row7_col3, #T_6a868_row7_col4, #T_6a868_row7_col5, #T_6a868_row8_col0, #T_6a868_row8_col1, #T_6a868_row8_col2, #T_6a868_row8_col3, #T_6a868_row8_col4, #T_6a868_row8_col5, #T_6a868_row9_col0, #T_6a868_row9_col1, #T_6a868_row9_col2, #T_6a868_row9_col3, #T_6a868_row9_col4, #T_6a868_row9_col5, #T_6a868_row10_col0, #T_6a868_row10_col1, #T_6a868_row10_col2, #T_6a868_row10_col3, #T_6a868_row10_col4, #T_6a868_row10_col5, #T_6a868_row11_col0, #T_6a868_row11_col1, #T_6a868_row11_col2, #T_6a868_row11_col3, #T_6a868_row11_col4, #T_6a868_row11_col5, #T_6a868_row12_col0, #T_6a868_row12_col1, #T_6a868_row12_col2, #T_6a868_row12_col3, #T_6a868_row12_col4, #T_6a868_row12_col5, #T_6a868_row13_col0, #T_6a868_row13_col1, #T_6a868_row13_col2, #T_6a868_row13_col3, #T_6a868_row13_col4, #T_6a868_row13_col5, #T_6a868_row14_col0, #T_6a868_row14_col1, #T_6a868_row14_col2, #T_6a868_row14_col3, #T_6a868_row14_col4, #T_6a868_row14_col5, #T_6a868_row15_col0, #T_6a868_row15_col1, #T_6a868_row15_col2, #T_6a868_row15_col3, #T_6a868_row15_col4, #T_6a868_row15_col5, #T_6a868_row16_col0, #T_6a868_row16_col1, #T_6a868_row16_col2, #T_6a868_row16_col3, #T_6a868_row16_col4, #T_6a868_row16_col5, #T_6a868_row17_col0, #T_6a868_row17_col1, #T_6a868_row17_col2, #T_6a868_row17_col3, #T_6a868_row17_col4, #T_6a868_row17_col5, #T_6a868_row18_col0, #T_6a868_row18_col1, #T_6a868_row18_col2, #T_6a868_row18_col3, #T_6a868_row18_col4, #T_6a868_row18_col5, #T_6a868_row19_col0, #T_6a868_row19_col1, #T_6a868_row19_col2, #T_6a868_row19_col3, #T_6a868_row19_col4, #T_6a868_row19_col5, #T_6a868_row20_col0, #T_6a868_row20_col1, #T_6a868_row20_col2, #T_6a868_row20_col3, #T_6a868_row20_col4, #T_6a868_row20_col5, #T_6a868_row21_col0, #T_6a868_row21_col1, #T_6a868_row21_col2, #T_6a868_row21_col3, #T_6a868_row21_col4, #T_6a868_row21_col5, #T_6a868_row22_col0, #T_6a868_row22_col1, #T_6a868_row22_col2, #T_6a868_row22_col3, #T_6a868_row22_col4, #T_6a868_row22_col5, #T_6a868_row23_col0, #T_6a868_row23_col1, #T_6a868_row23_col2, #T_6a868_row23_col3, #T_6a868_row23_col4, #T_6a868_row23_col5, #T_6a868_row24_col0, #T_6a868_row24_col1, #T_6a868_row24_col2, #T_6a868_row24_col3, #T_6a868_row24_col4, #T_6a868_row24_col5, #T_6a868_row25_col0, #T_6a868_row25_col1, #T_6a868_row25_col2, #T_6a868_row25_col3, #T_6a868_row25_col4, #T_6a868_row25_col5, #T_6a868_row26_col0, #T_6a868_row26_col1, #T_6a868_row26_col2, #T_6a868_row26_col3, #T_6a868_row26_col4, #T_6a868_row26_col5, #T_6a868_row27_col0, #T_6a868_row27_col1, #T_6a868_row27_col2, #T_6a868_row27_col3, #T_6a868_row27_col4, #T_6a868_row27_col5, #T_6a868_row28_col0, #T_6a868_row28_col1, #T_6a868_row28_col2, #T_6a868_row28_col3, #T_6a868_row28_col4, #T_6a868_row28_col5, #T_6a868_row29_col0, #T_6a868_row29_col1, #T_6a868_row29_col2, #T_6a868_row29_col3, #T_6a868_row29_col4, #T_6a868_row29_col5, #T_6a868_row30_col0, #T_6a868_row30_col1, #T_6a868_row30_col2, #T_6a868_row30_col3, #T_6a868_row30_col4, #T_6a868_row30_col5, #T_6a868_row31_col0, #T_6a868_row31_col1, #T_6a868_row31_col2, #T_6a868_row31_col3, #T_6a868_row31_col4, #T_6a868_row31_col5, #T_6a868_row32_col0, #T_6a86 ...

# %%
# --- 全体の正答率 ---
total_correct = (df['正誤'] == '○').sum()
total_questions = len(df)
overall_accuracy = total_correct / total_questions

print(f"全体の正答率: {overall_accuracy:.2%} ({total_correct}/{total_questions})") # 正答数/問題数を追記

print("-" * 30) # 区切り線

# --- 科目ごとの正答率（正答数/問題数 付き）---
# '正誤'列が'○'であるかどうかを示すブール値の列を作成
df['is_correct'] = (df['正誤'] == '○')

# 科目ごとに集計（正答数、問題数、正答率）
# aggを使って複数の集計を一度に行う
subject_summary = df.groupby('科目').agg(
    correct_count=('is_correct', 'sum'),  # 正答数を計算 ('is_correct'列のTrueの合計)
    total_count=('is_correct', 'size'), # 問題数を計算 (各グループの行数)
    accuracy=('is_correct', 'mean')      # 正答率を計算 ('is_correct'列の平均値)
)

# 結果を整形して表示する関数
def format_subject_accuracy(row):
    # is_correct列がbool型の場合、sum()は整数を返すのでint()は不要な場合もあるが念のため
    correct = int(row['correct_count'])
    total = int(row['total_count'])
    accuracy_percent = f"{row['accuracy']:.2%}" # パーセンテージ形式
    return f"{accuracy_percent}（{correct}/{total}）"

# applyを使って各行（科目）に関数を適用し、整形後の文字列 Series を作成
formatted_accuracy = subject_summary.apply(format_subject_accuracy, axis=1)

print("科目ごとの正答率:")
print(formatted_accuracy)
# Out:
# 全体の正答率: 80.58% (278/345)
# ------------------------------
# 科目ごとの正答率:
# 科目
# 化学    55.00%（11/20）
# 実務    73.68%（70/95）
# 法規    80.00%（24/30）
# 物理    90.00%（18/20）
# 生物    90.00%（18/20）
# 病態    90.00%（36/40）
# 薬剤    82.50%（33/40）
# 薬理    90.00%（36/40）
# 衛生    80.00%（32/40）
# dtype: object

# %%
### メモ

import fitz  # PyMuPDF
import os
import time
import json
from typing import List, Union, Dict, Any, Tuple
import concurrent.futures

# --- Assume these variables and functions are defined elsewhere ---
# pdf_files: List[str] = [...] # List of PDF filenames (without .pdf extension)
# PROMPT: str = "..."
# MODEL_NAME: str = "..."
# GENERATION_CONFIG: Dict = {...}
# OUTPUT_FILENAME: str = "output.json"
# MAX_RETRIES = 1 # 最大リトライ回数
# RETRY_DELAY_SECONDS = 5 # リトライ間の待機時間（秒）

# def call_gemini_vision_api(image_paths, prompt, model_name, generation_config):
#     # Dummy implementation for example
#     # Simulate potential failures
#     if "fail_once" in os.path.basename(os.path.dirname(image_paths[0])) and not hasattr(call_gemini_vision_api, 'failed_once'):
#         setattr(call_gemini_vision_api, 'failed_once', True) # Mark as failed once
#         print(f"  Simulating API failure for {os.path.basename(os.path.dirname(image_paths[0]))}")
#         raise ConnectionError("Simulated API connection error")
#     elif hasattr(call_gemini_vision_api, 'failed_once'):
#          # Reset for next potential failure simulation if needed elsewhere
#          delattr(call_gemini_vision_api, 'failed_once')

#     print(f"  Calling API for {len(image_paths)} images from {os.path.dirname(image_paths[0])}...")
#     time.sleep(2) # Simulate API call delay
#     response_data = {
#         "text": json.dumps([{"question_id": f"Q{i+1}_{os.path.basename(os.path.dirname(image_paths[0]))}", "text": f"Answer {i+1}"} for i in range(len(image_paths))]),
#         "usage_metadata": {
#             "prompt_token_count": 100,
#             "total_token_count": 500
#         }
#     }
#     class MockResponse:
#         def __init__(self, data):
#             self.text = data["text"]
#             self.usage_metadata = type('obj', (object,), data["usage_metadata"])()
#     return MockResponse(response_data)

# def merge_question_lists_indexed(responses):
#     # (Dummy implementation - same as before)
#     print("Merging results...")
#     all_q = {}
#     errors = []
#     for idx, resp_dict in enumerate(responses):
#         try:
#             q_list = resp_dict
#             if isinstance(q_list, list):
#                 for q in q_list:
#                     q_id = q.get("question_id")
#                     if q_id:
#                         if q_id not in all_q:
#                             all_q[q_id] = q
#                         else:
#                             errors.append({"list_index": idx, "question_id": q_id})
#             else:
#                  print(f"Warning: Response at index {idx} is not a list: {type(resp_dict)}")
#         except Exception as e:
#             print(f"Error processing response at index {idx}: {e}")
#             errors.append({"list_index": idx, "error": str(e)})
#     sorted_keys = sorted(all_q.keys())
#     merged = [all_q[key] for key in sorted_keys]
#     return merged, errors
# --- End of assumed definitions ---

# 設定値
MAX_CONCURRENT_WORKERS = 2
MAX_RETRIES = 1  # 最大リトライ回数 (0ならリトライしない)
RETRY_DELAY_SECONDS = 5 # リトライ間の待機時間（秒）

# --- process_single_pdf 関数 ---
# (前回のコード例と同じ、エラー時に {"error": ..., "pdf_file": ...} を返すことを確認)
def process_single_pdf(pdf_file_base: str, index: int, total_files: int) -> Dict[str, Any]:
    """
    Processes a single PDF file: converts pages to images and calls the Gemini API.
    Returns a dictionary containing the result or error information.
    """
    pdf_path = pdf_file_base + '.pdf'
    output_dir = pdf_file_base
    run_identifier = f"[ファイル {index + 1}/{total_files}] PDF: {os.path.basename(pdf_path)}"

    print(f"\n{run_identifier} の処理開始")

    try:
        doc = fitz.open(pdf_path)
    except Exception as e:
        print(f"{run_identifier} - PDFオープンエラー: {e}")
        # index と pdf_file_base を含めて返す
        return {"index": index, "pdf_file": pdf_file_base, "error": f"Failed to open PDF: {e}"}

    Num = 0
    PicsPath = []
    os.makedirs(output_dir, exist_ok=True)
    print(f"  {run_identifier} - 画像変換中 -> '{output_dir}'")

    try:
        for page_num in range(doc.page_count):
            page = doc[page_num]
            pix = page.get_pixmap()
            output_filename = os.path.join(output_dir, f"{Num:03d}.png")
            pix.save(output_filename)
            Num += 1
            PicsPath.append(output_filename)
        doc.close()
    except Exception as e:
        print(f"  {run_identifier} - 画像変換エラー: {e}")
        try:
            doc.close()
        except:
            pass
        return {"index": index, "pdf_file": pdf_file_base, "error": f"Failed during image conversion: {e}"}

    print(f"  {run_identifier} - 画像 {len(PicsPath)} 個のAPI処理開始")
    print("  " + "-" * 28)
    start_time = time.time()

    try:
        response = call_gemini_vision_api(
            PicsPath,
            PROMPT,
            MODEL_NAME,
            GENERATION_CONFIG
        )
        parsed_response = json.loads(response.text)
        end_time = time.time()
        elapsed_time = end_time - start_time

        print(f"  {run_identifier} - 結果生成完了 ({elapsed_time:.4f} 秒)")
        if hasattr(response, 'usage_metadata') and response.usage_metadata:
            print(f"    Token Count: P={response.usage_metadata.prompt_token_count}, T={response.usage_metadata.total_token_count}")
        else:
            print("    Token usage metadata not available.")
        print("  " + "-" * 28)
        # index と response を含めて返す
        return {"index": index, "pdf_file": pdf_file_base, "response": parsed_response}

    except Exception as e:
        print(f"  {run_identifier} - API呼び出しエラー: {e}")
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"    試行時間: {elapsed_time:.4f} 秒")
        print("  " + "-" * 28)
        # index, pdf_file_base, error を含めて返す
        return {"index": index, "pdf_file": pdf_file_base, "error": f"API call failed: {e}"}

# --- メインの実行部分 ---
print("--- Gemini Vision APIによる画像処理を開始します ---")

# pdf_files = ["doc1", "doc2_fail_once", "doc3", "doc4_invalid"] # Example list

all_results_with_indices = {} # 辞書を使ってindexをキーに結果を格納（重複実行を防ぐため）
files_to_process = list(enumerate(pdf_files)) # (index, pdf_file_base) のリスト
retry_attempt = 0
failed_files_info = [] # リトライが必要なファイルの情報を格納: List[Tuple[int, str]] = (index, pdf_file_base)

while retry_attempt <= MAX_RETRIES:
    if retry_attempt > 0:
        print(f"\n--- リトライ試行 {retry_attempt}/{MAX_RETRIES} 開始 ({len(files_to_process)} 件) ---")
        if RETRY_DELAY_SECONDS > 0:
             print(f"  {RETRY_DELAY_SECONDS}秒待機...")
             time.sleep(RETRY_DELAY_SECONDS)

    current_failed_files = [] # この試行で失敗したファイル

    # ProcessPoolExecutorを使う場合はThreadPoolExecutorを置き換える
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_CONCURRENT_WORKERS) as executor:
        # 各PDFファイルに対する処理タスクを作成
        future_to_info = {executor.submit(process_single_pdf, pdf_base, idx, len(pdf_files)): (idx, pdf_base) for idx, pdf_base in files_to_process}

        # タスクの完了を待機し、結果を収集
        for future in concurrent.futures.as_completed(future_to_info):
            original_index, pdf_base = future_to_info[future]
            try:
                # タスクの結果（process_single_pdfの戻り値）を取得
                result = future.result()
                # 成功か失敗かを判断し、結果を格納
                if "error" not in result:
                    # 成功した場合、元のindexをキーとして結果を保存
                    if original_index not in all_results_with_indices:
                         all_results_with_indices[original_index] = result
                else:
                    # 失敗した場合
                    print(f"  ファイル {pdf_base}.pdf (Index: {original_index}) の処理に失敗。エラー: {result['error']}")
                    current_failed_files.append((original_index, pdf_base)) # 次のリトライ候補に追加

            except Exception as exc:
                # process_single_pdf内でキャッチされなかった予期せぬエラー
                print(f'ファイル {pdf_base}.pdf (Index: {original_index}) で予期せぬ実行時エラー発生: {exc}')
                # 予期せぬエラーもリトライ候補に追加
                current_failed_files.append((original_index, pdf_base))
                # エラー情報を記録しておく（任意）
                if original_index not in all_results_with_indices: # まだ結果がなければエラーとして記録
                    all_results_with_indices[original_index] = {"index": original_index, "pdf_file": pdf_base, "error": f"Unexpected execution error: {exc}"}


    # 次のリトライのために失敗リストを更新
    failed_files_info = current_failed_files
    files_to_process = failed_files_info # 次のループでは失敗したファイルのみ処理

    if not failed_files_info:
        print(f"\n--- 試行 {retry_attempt} で全ての処理が成功または完了 ---")
        break # 失敗がなければループを抜ける

    retry_attempt += 1

# --- ループ終了後の処理 ---

# 最終的に失敗したファイルがあれば報告
final_failed_files = failed_files_info # ループを抜けた時点での失敗リスト
if final_failed_files:
    print(f"\n--- {MAX_RETRIES}回のリトライ後もエラーが解消しなかったファイル ---")
    for index, pdf_base in final_failed_files:
         # all_results_with_indices から最後のエラーメッセージを取得試行
        last_error_info = all_results_with_indices.get(index, {})
        error_msg = last_error_info.get("error", "Unknown error during final attempt")
        print(f"  - ファイル: {pdf_base}.pdf (Index: {index}), 最終エラー: {error_msg}")

# 結果を元の順序にソートするためにインデックスでソート
# all_results_with_indices には成功した結果と、最終的に失敗したファイルのエラー情報が含まれる
sorted_indices = sorted(all_results_with_indices.keys())
sorted_results = [all_results_with_indices[i] for i in sorted_indices]

# 実際のレスポンス（エラーでないもの）だけを抽出してマージ対象とする
successful_api_responses = [r.get("response") for r in sorted_results if "response" in r and "error" not in r]

# 全ての成功したチャンクの応答を統合・整形
merged_list, merge_error_info = merge_question_lists_indexed(successful_api_responses)

print("\n--- 結合結果 (成功分) ---")
print("結合されたリスト:")
marged = json.dumps(merged_list, indent=2, ensure_ascii=False, sort_keys=True)
print(marged)

print("\n--- 重複エラー情報 (成功分) ---")
if merge_error_info:
  print("以下の問が重複していました（最初に現れたものが保持されます）：")
  for error in merge_error_info:
    print(f"- リスト {error['list_index']} に含まれる '{error['question_id']}'") # インデックスは成功リスト内でのもの
else:
  print("重複エラーはありませんでした。")

# 成功した結果のみファイルに保存
if successful_api_responses:
    with open(OUTPUT_FILENAME, "w", encoding="utf-8") as f:
        f.write(marged)
    print(f"\n成功した結果を '{OUTPUT_FILENAME}' に保存しました。")
else:
    print(f"\n成功した結果がなかったため、'{OUTPUT_FILENAME}' は作成されませんでした。")


print("\n--- 全ての処理が完了しました ---")
